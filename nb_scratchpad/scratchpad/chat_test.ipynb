# %% [markdown]
# # Client
#
# Demo of a client interacting with a remote agent.

# %% [markdown]
# You can interact with this via API directly

# %%
import requests

inputs = {"input": {"input": "what does eugene think of cats?"}}
response = requests.post("http://localhost:8000/invoke", json=inputs)

response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/miniconda3/envs/alhazen/lib/python3.11/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/miniconda3/envs/alhazen/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~/miniconda3/envs/alhazen/lib/python3.11/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~/miniconda3/envs/alhazen/lib/python3.11/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# /Users/gburns/Documents/Coding/ChatGPT_etc/alzhazen/nb_scratchpad/chat_test.ipynb Cell 3 line 6
#       <a href='vscode-notebook-cell:/Users/gburns/Documents/Coding/ChatGPT_etc/alzhazen/nb_scratchpad/chat_test.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> inputs = {"input": {"input": "what does eugene think of cats?"}}
#       <a href='vscode-notebook-cell:/Users/gburns/Documents/Coding/ChatGPT_etc/alzhazen/nb_scratchpad/chat_test.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> response = requests.post("http://localhost:8000/invoke", json=inputs)
# ----> <a href='vscode-notebook-cell:/Users/gburns/Documents/Coding/ChatGPT_etc/alzhazen/nb_scratchpad/chat_test.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a> response.json()
#
# File ~/miniconda3/envs/alhazen/lib/python3.11/site-packages/requests/models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# You can also interact with this via the RemoteRunnable interface (to use in other chains)

# %%
from langserve import RemoteRunnable

remote_runnable = RemoteRunnable("http://localhost:8000/")

# %% [markdown]
# Remote runnable has the same interface as local runnables

# %%
await remote_runnable.ainvoke({"input": "hi!"})
# Out:
# {'output': 'Hello! How can I assist you today?'}

# %%
remote_runnable.invoke({"input": "what does eugene think of cats?"})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/gburns/Documents/Coding/ChatGPT_etc/alzhazen/nb_scratchpad/chat_test.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/Users/gburns/Documents/Coding/ChatGPT_etc/alzhazen/nb_scratchpad/chat_test.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> remote_runnable.invoke({"input": "what does eugene think of cats?"})
#
# NameError: name 'remote_runnable' is not defined
