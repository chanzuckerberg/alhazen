# %% [markdown]
# # Building databases of published works
#
# > Pragmatic tools for constructing databases of scientific works based on queries defined with Boolean Logic.

# %%
#| default_exp utils.db

# %%
#| hide
from nbdev import *

# %% [markdown]
# Tabulate queries in a spreadsheet and generate a database based on the data from those queries.
#
# **Example**:  Define a dataframe with an `id` column and a `query` column (expressing a search query in Boolean Logic):
#
# | ID | DISEASE NAME | QUERY  |
# |----|--------------|--------|
# | 1 | Adult Polyglucosan Body Disease | adult polyglucosan body disease \| adult polyglucosan body neuropathy
# | 2 | AGAT deficiency |  "GATM deficiency" \| "AGAT deficiency" \| "arginine:glycine amidinotransferase deficiency" \| "L-arginine:glycine amidinotransferase deficiency"
# | 3 | Guanidinoacetate methyltransferase deficiency | "guanidinoacetate methyltransferase deficiency" \| "GAMT deficiency"
# | 4 | CLOVES Syndrome | "CLOVES syndrome \| (congenital lipomatous overgrowth) & (vascular malformation epidermal) & (nevi-spinal) & syndrome \| (congenital lipomatous overgrowth) & (vascular malformations) & (Epidermal nevi) & ((skeletal\|spinal) & abnormalities) \| CLOVE syndrome \| (congenital lipomatous overgrowth) & (vascular malformation) & (epidermal nevi)

# %%
#| export

import local_resources.linkml as linkml

from alhazen.utils.airtableUtils import AirtableUtils
from alhazen.utils.searchEngineUtils import ESearchQuery, EuroPMCQuery
from alhazen.utils.queryTranslator import QueryTranslator, QueryType
from alhazen.schema_sqla import ScientificPublication, ScientificPublicationCollection
import alhazen.schema_python as linkml_py
from alhazen.utils.jats_text_extractor import NxmlDoc
from alhazen.utils.ceifns_db import *

from langchain.callbacks.tracers import ConsoleCallbackHandler
from langchain.schema.runnable import RunnableLambda

from bs4 import BeautifulSoup,Tag,Comment,NavigableString
from databricks import sql
from datetime import datetime
from importlib_resources import files
import os
import pandas as pd
from pathlib import Path
import re
import requests
from sqlalchemy import create_engine, exists
from sqlalchemy.orm import sessionmaker
from time import time,sleep
from tqdm import tqdm
from urllib.request import urlopen
from urllib.parse import quote_plus, quote, unquote
from urllib.error import URLError, HTTPError

# %%
db = Ceifns_LiteratureDb('/Users/gburns/alhazen/', 'em_tech' )
if db.session is None:
    session_class = sessionmaker(bind=db.engine)
    db.session = session_class()

# %%
from io import StringIO

EM_QUERIES_TSV = '''
ID,NAME,QUERY
0,Hierarchical phase-contrast tomography,Hierarchical phase-contrast tomography | HIP-CT | Hierarchical phase contrast tomography
1,Cryo-Electron Tomography,Cryoelectron Tomography | Cryo Electron Tomography | Cryo-Electron Tomography | Cryo-ET | CryoET
2,Volume Electron Microscopy,Volume Electron Microscopy | Volume EM | (serial section & (electron microscopy | EM | transmission electron microscopy | TEM | scanning electron microscopy | SEM | electron tomography )) | (serial block-face & (SEM | scanning electron microscopy)) | (focused ion beam & (SEM | scanning electron microscopy)) | (automated serial & (TEM | transmission electron microscopy)) | ( massively parallel imaging & (SEM | scanning electron microscopy)) | multibeam SEM | FAST-SEM | cryo-TEM
'''
EM_QUERIES_TSV = '''
ID,NAME,QUERY
0,Cryo-Electron Tomography,Cryoelectron Tomography | Cryo Electron Tomography | Cryo-Electron Tomography | Cryo-ET | CryoET
'''

cdf = pd.read_csv(StringIO(EM_QUERIES_TSV), sep=',')
qs = QuerySpec('EM Technology', 'ID', 'QUERY', 'NAME', {}, ['TITLE','ABSTRACT', 'METHODS'])
qt = QueryTranslator(cdf.sort_values('ID'), 'ID', 'QUERY', 'NAME')

db.add_corpus_from_epmc(qt, None, sections=qs.sections)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 864.27it/s]
# 100%|██████████| 1/1 [00:00<00:00, 1506.57it/s]
# https://www.ebi.ac.uk/europepmc/webservices/rest/search?format=JSON&pageSize=1000&synonym=TRUE&resultType=core&query=((TITLE:"Cryoelectron Tomography" OR ABSTRACT:"Cryoelectron Tomography" OR METHODS:"Cryoelectron Tomography") OR (TITLE:"Cryo Electron Tomography" OR ABSTRACT:"Cryo Electron Tomography" OR METHODS:"Cryo Electron Tomography") OR (TITLE:"Cryo-Electron Tomography" OR ABSTRACT:"Cryo-Electron Tomography" OR METHODS:"Cryo-Electron Tomography") OR (TITLE:"Cryo-ET" OR ABSTRACT:"Cryo-ET" OR METHODS:"Cryo-ET") OR (TITLE:"CryoET" OR ABSTRACT:"CryoET" OR METHODS:"CryoET")), 2446 European PMC PAPERS FOUND
#   0%|          | 0/3 [00:05<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/gburns/Documents/Coding/ChatGPT_etc/alzhazen/nb_scratchpad/35b_queries.ipynb Cell 7 line 1
#      <a href='vscode-notebook-cell:/Users/gburns/Documents/Coding/ChatGPT_etc/alzhazen/nb_scratchpad/35b_queries.ipynb#X41sZmlsZQ%3D%3D?line=14'>15</a> qs = QuerySpec('EM Technology', 'ID', 'QUERY', 'NAME', {}, ['TITLE','ABSTRACT', 'METHODS'])
#      <a href='vscode-notebook-cell:/Users/gburns/Documents/Coding/ChatGPT_etc/alzhazen/nb_scratchpad/35b_queries.ipynb#X41sZmlsZQ%3D%3D?line=15'>16</a> qt = QueryTranslator(cdf.sort_values('ID'), 'ID', 'QUERY', 'NAME')
# ---> <a href='vscode-notebook-cell:/Users/gburns/Documents/Coding/ChatGPT_etc/alzhazen/nb_scratchpad/35b_queries.ipynb#X41sZmlsZQ%3D%3D?line=17'>18</a> db.add_corpus_from_epmc(qt, None, sections=qs.sections)
#
# File ~/Documents/Coding/ChatGPT_etc/alzhazen/alhazen/utils/local_literature_db.py:240, in LocalLiteratureDb.add_corpus_from_epmc(self, qt, qt2, sections, sections2)
#     237 self.session.commit()
#     239 epmcq = EuroPMCQuery()
# --> 240 numFound, epmc_publications = epmcq.run_empc_query(query)
#     241 for p in tqdm(epmc_publications):
#     242   p_check = self.session.query(linkml_sqla.ScientificPublication).filter(linkml_sqla.ScientificPublication.id==p.id).first()
#
# File ~/Documents/Coding/ChatGPT_etc/alzhazen/alhazen/utils/searchEngineUtils.py:402, in EuroPMCQuery.run_empc_query(self, q, page_size, timeout, extra_columns)
#     400 for i in tqdm(range(0, numFound, page_size)):
#     401     url = EMPC_API_URL + '&cursorMark=' + cursorMark + '&query=' + q
# --> 402     r = requests.get(url, timeout=timeout)
#     403     data = json.loads(r.text)
#     404     date_format = '%Y-%m-%d'
#
# File ~/miniconda3/envs/alhazen/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniconda3/envs/alhazen/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/envs/alhazen/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/envs/alhazen/lib/python3.11/site-packages/requests/sessions.py:747, in Session.send(self, request, **kwargs)
#     744         pass
#     746 if not stream:
# --> 747     r.content
#     749 return r
#
# File ~/miniconda3/envs/alhazen/lib/python3.11/site-packages/requests/models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File ~/miniconda3/envs/alhazen/lib/python3.11/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~/miniconda3/envs/alhazen/lib/python3.11/site-packages/urllib3/response.py:624, in HTTPResponse.stream(self, amt, decode_content)
#     608 """
#     609 A generator wrapper for the read() method. A call will block until
#     610 ``amt`` bytes have been read from the connection or until the
#    (...)
#     621     'content-encoding' header.
#     622 """
#     623 if self.chunked and self.supports_chunked_reads():
# --> 624     for line in self.read_chunked(amt, decode_content=decode_content):
#     625         yield line
#     626 else:
#
# File ~/miniconda3/envs/alhazen/lib/python3.11/site-packages/urllib3/response.py:831, in HTTPResponse.read_chunked(self, amt, decode_content)
#     829 if self.chunk_left == 0:
#     830     break
# --> 831 chunk = self._handle_chunk(amt)
#     832 decoded = self._decode(
#     833     chunk, decode_content=decode_content, flush_decoder=False
#     834 )
#     835 if decoded:
#
# File ~/miniconda3/envs/alhazen/lib/python3.11/site-packages/urllib3/response.py:784, in HTTPResponse._handle_chunk(self, amt)
#     782     returned_chunk = value
#     783 else:  # amt > self.chunk_left
# --> 784     returned_chunk = self._fp._safe_read(self.chunk_left)
#     785     self._fp._safe_read(2)  # Toss the CRLF at the end of the chunk.
#     786     self.chunk_left = None
#
# File ~/miniconda3/envs/alhazen/lib/python3.11/http/client.py:631, in HTTPResponse._safe_read(self, amt)
#     624 def _safe_read(self, amt):
#     625     """Read the number of bytes requested.
#     626
#     627     This function should be used when <amt> bytes "should" be present for
#     628     reading. If the bytes are truly not available (due to EOF), then the
#     629     IncompleteRead exception can be used to detect the problem.
#     630     """
# --> 631     data = self.fp.read(amt)
#     632     if len(data) < amt:
#     633         raise IncompleteRead(data, amt-len(data))
#
# File ~/miniconda3/envs/alhazen/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/miniconda3/envs/alhazen/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/envs/alhazen/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
list_c = db.session.query(ScientificPublicationCollection).all()
for c in list_c:
  print('ID: %s | Name: %s'%(c.id,c.name))
# Out:
# ID: 0 | Name: Cryo-Electron Tomography

# %%
pdf_path = '/tmp/alhazen/pdf_files/'
nxml_path = '/tmp/alhazen/nxml_files/'

l = []
for p in tqdm(db.list_corpus_publications('0')):

    has_full_text = False
    has_full_text_methods = False
    has_pdf = False
    
    pdf_file_path = pdf_path+p.doi+'.pdf'
    if os.path.exists(pdf_file_path):
        has_pdf = True

    nxml_file_path = nxml_path+p.doi+'.nxml'
    if os.path.exists(nxml_file_path):
        with open(nxml_file_path, 'r') as f:
            xml = f.read()
            soup = BeautifulSoup(xml, "lxml")
        body = soup.find_all('body')
        if body:
            has_full_text = True
        d = NxmlDoc(p.doi, xml)
        m = '\n'.join([d.read_section_text(sec) for sec in d.search_section_titles('methods')])
        if(len(m) > 0):
            has_full_text_methods = True

    l.append({'id':p.id, 'title':p.title, 'doi':p.doi, 'pub_date':p.publication_date, 'has_full_text':has_full_text, 'has_full_text_methods':has_full_text_methods, 'has_pdf':has_pdf})

df = pd.DataFrame(l)
df
# Out:
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/gburns/Documents/Coding/ChatGPT_etc/alzhazen/nb_scratchpad/35b_queries.ipynb Cell 9 line 5
#       <a href='vscode-notebook-cell:/Users/gburns/Documents/Coding/ChatGPT_etc/alzhazen/nb_scratchpad/35b_queries.ipynb#X50sZmlsZQ%3D%3D?line=1'>2</a> nxml_path = '/tmp/alhazen/nxml_files/'
#       <a href='vscode-notebook-cell:/Users/gburns/Documents/Coding/ChatGPT_etc/alzhazen/nb_scratchpad/35b_queries.ipynb#X50sZmlsZQ%3D%3D?line=3'>4</a> l = []
# ----> <a href='vscode-notebook-cell:/Users/gburns/Documents/Coding/ChatGPT_etc/alzhazen/nb_scratchpad/35b_queries.ipynb#X50sZmlsZQ%3D%3D?line=4'>5</a> for p in tqdm(db.list_corpus_publications('0')):
#       <a href='vscode-notebook-cell:/Users/gburns/Documents/Coding/ChatGPT_etc/alzhazen/nb_scratchpad/35b_queries.ipynb#X50sZmlsZQ%3D%3D?line=6'>7</a>     has_full_text = False
#       <a href='vscode-notebook-cell:/Users/gburns/Documents/Coding/ChatGPT_etc/alzhazen/nb_scratchpad/35b_queries.ipynb#X50sZmlsZQ%3D%3D?line=7'>8</a>     has_full_text_methods = False
#
# File ~/miniconda3/envs/alhazen/lib/python3.11/site-packages/tqdm/std.py:1182, in tqdm.__iter__(self)
#    1179 time = self._time
#    1181 try:
# -> 1182     for obj in iterable:
#    1183         yield obj
#    1184         # Update and possibly print the progressbar.
#    1185         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/Documents/Coding/ChatGPT_etc/alzhazen/alhazen/utils/local_literature_db.py:293, in LocalLiteratureDb.list_corpus_publications(self, corpus_id)
#     289 def list_corpus_publications(self, corpus_id):
#     290   cp = self.session.query(linkml_sqla.ScientificPublicationCollection) \
#     291           .join(linkml_sqla.ScientificPublicationCollection.has_part) \
#     292           .filter(linkml_sqla.ScientificPublicationCollection.id==corpus_id).first()
# --> 293   for p in cp.has_part:
#     294     yield(p)
#
# AttributeError: 'NoneType' object has no attribute 'has_part'

# %%
# query a specific paper and run an analysis on that paper.
#p = db.session.query(ScientificPublication) \
#            .filter(ScientificPublication.doi=='10.1038/s41592-022-01746-2').first()
p = db.session.query(ScientificPublication) \
            .filter(ScientificPublication.doi=='10.1038/s41586-022-05255-2').first()

# %%
print(p.doi)
print(p.title)
print(p.abstract)
print(p.publication_date)
print('~~~~~~~~~~~~~~~~~~~~~~~~~~')
# Out:
# 10.1038/s41586-022-05255-2
# Visualizing translation dynamics at atomic detail inside a bacterial cell.
# Translation is the fundamental process of protein synthesis and is catalysed by the ribosome in all living cells<sup>1</sup>. Here we use advances in cryo-electron tomography and sub-tomogram analysis<sup>2,3</sup> to visualize the structural dynamics of translation inside the bacterium Mycoplasma pneumoniae. To interpret the functional states in detail, we first obtain a high-resolution in-cell average map of all translating ribosomes and build an atomic model for the M. pneumoniae ribosome that reveals distinct extensions of ribosomal proteins. Classification then resolves 13 ribosome states that differ in their conformation and composition. These recapitulate major states that were previously resolved in vitro, and reflect intermediates during active translation. On the basis of these states, we animate translation elongation inside native cells and show how antibiotics reshape the cellular translation landscapes. During translation elongation, ribosomes often assemble in defined three-dimensional arrangements to form polysomes<sup>4</sup>. By mapping the intracellular organization of translating ribosomes, we show that their association into polysomes involves a local coordination mechanism that is mediated by the ribosomal protein L9. We propose that an extended conformation of L9 within polysomes mitigates collisions to facilitate translation fidelity. Our work thus demonstrates the feasibility of visualizing molecular processes at atomic detail inside cells.
# 2022-09-28
# ~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_colwidth', 0)

# %%
path = db.loc+db.name+'/nxml_files/'
nxml_path = path+p.doi+'.nxml'
print(nxml_path)
if os.path.exists(nxml_path):
    with open(nxml_path, 'r') as f:
        xml = f.read()
        d = NxmlDoc(p.doi, xml)
        #sections_df = pd.DataFrame([(t.start, t.end, d.text[t.start+1:t.end]) for t in d.standoffs if t.element.tag=='sec'], 
        #                           columns=['start', 'end', 'text'])
        #sections_df['first_line']= sections_df.text.apply(lambda x: x.split('\n')[0])   
        #methods_df = sections_df[sections_df.first_line.str.contains('method', case=False)]
        #methods_text = methods_df.text.str.cat(sep='\n')
    
        df2 = d.build_simple_document_dataframe()
df2
# Out:
# /Users/gburns/alhazen/em_tech/nxml_files/10.1038/s41586-022-05255-2.nxml
#                            PMID  PARAGRAPH_ID            TAG TOP_SECTION  \
# 0    10.1038/s41586-022-05255-2             0  article-title
# 1    10.1038/s41586-022-05255-2             1       abstract
# 2    10.1038/s41586-022-05255-2             2       abstract
# 3    10.1038/s41586-022-05255-2             3          title        Main
# 4    10.1038/s41586-022-05255-2             4              p        Main
# ..                          ...           ...            ...         ...
# 139  10.1038/s41586-022-05255-2           139          title
# 140  10.1038/s41586-022-05255-2           140              p
# 141  10.1038/s41586-022-05255-2           141          title
# 142  10.1038/s41586-022-05255-2           142              p
# 143  10.1038/s41586-022-05255-2           143          title
#
#     SECTION  OFFSET  LENGTH FIG_REF  \
# 0               153      73
# 1              2557    1458
# 2              4016     252
# 3      Main    4480       4
# 4      Main    4485    2002
# ..      ...     ...     ...     ...
# 139           70155      17
# 140           70173     414
# 141           70590      19
# 142           70610      43
# 143           70656      10
#
#                                             PLAIN_TEXT
# 0    Visualizing translation dynamics at atomic det...
# 1    \nTranslation is the fundamental process of pr...
# 2    \nCryo-electron tomography is used to reveal t...
# 3                                                 Main
# 4    Translation of genetic information through mes...
# ..                                                 ...
# 139                                  Code availability
# 140  The code and associated data for bioinformatic...
# 141                                Competing interests
# 142        The authors declare no competing interests.
# 143                                         References
#
# [144 rows x 9 columns]

# %%
df3 = df2[df2.TOP_SECTION.str.contains('method', case=False)]
df4 = df3.groupby('SECTION').agg({'OFFSET': 'min', 'LENGTH': 'sum', 'PLAIN_TEXT':lambda x: '\n'.join(x)}).sort_values('OFFSET')
df4.reset_index(drop=False)
# Out:
#                                               SECTION  OFFSET  LENGTH  \
# 0                                             Methods   29117       7
# 1      Cryo-ET sample preparation and data collection   29126    1332
# 2   Image processing, ribosome template matching a...   30464    1304
# 3   Atomic model building in high-resolution ribos...   31773    1593
# 4        Bioinformatic analysis of ribosomal proteins   33370    6783
# 5   Sub-tomogram classification of the translation...   40161    4106
# 6   Model building and comparison of the ribosome ...   44275    1844
# 7         Spatial analysis of ribosomes and polysomes   46124    3155
# 8   Statistical analysis of translation elongation...   49286    3227
# 9                     Single-cell clustering analysis   52519     858
# 10                                  Reporting summary   53382     133
# 11                                     Online content   53520     331
#
#                                            PLAIN_TEXT
# 0                                             Methods
# 1   Cryo-ET sample preparation and data collection...
# 2   Image processing, ribosome template matching a...
# 3   Atomic model building in high-resolution ribos...
# 4   Bioinformatic analysis of ribosomal proteins\n...
# 5   Sub-tomogram classification of the translation...
# 6   Model building and comparison of the ribosome ...
# 7   Spatial analysis of ribosomes and polysomes\nS...
# 8   Statistical analysis of translation elongation...
# 9   Single-cell clustering analysis\nThe distribut...
# 10  Reporting summary\nFurther information on rese...
# 11  Online content\nAny methods, additional refere...

# %%
# A global registry for all prompt templates
#global instructions
from alhazen.core import PromptTemplateRegistry

instructions = PromptTemplateRegistry()
instructions.load_prompts_from_yaml('ft_method_metadata_extraction.yaml')
pt = instructions.get_instruction_template('cryoet metadata extraction').generate_llama2_prompt_template()
pt
# Out:
# PromptTemplate(input_variables=['metadata_name', 'metadata_specification', 'section_text'], template="<s>[INST]\n                <<SYS>>You are an expert biological scientist trained in imaging and microscopy.<</SYS>>\n                Read the text of a section from the methods section of a research paper shown below (delimited with triple backticks).\nSection Text:- '''{section_text}'''\nExtract the metadata from the section text based only on the specification delineated by square brackets and record the answer in the 'metadata_value' field of the output. Do not extract any other metadata.\n[{metadata_specification}]\nRecord the term '{metadata_name}' in the 'metadata_name' field of the output.\nGenerate only JSON formatted output with three fields 'metadata_name', 'metadata_value' and 'orginal_text'. Do not provide additional explanation or context for the answer.\nIf the metadata is not present in the text, record a value of 'not present' in the 'metadata_value' field of the output. Do not include any other response other than a JSON object.\nFinally, if you found the metadata in the text, record the original text of the sentence where the metadata specification was extracted from in the 'original_text' field of the output.\nIf you did not find the specified metadata in the text, record 'not present' in the 'original_text' field of the output.\nRemember, only generate JSON formatted output without any additional text or explanation.\n                [/INST]</s>")

# %%
from functools import partial

from alhazen.core import PromptTemplateRegistry, get_langchain_llm, get_cached_gguf, get_langchain_embeddings, GGUF_LOOKUP_URL, MODEL_TYPE

from langchain.callbacks.manager import CallbackManagerForChainRun
from langchain.chains.combine_documents import collapse_docs, split_list_of_docs
from langchain.llms import LlamaCpp 
from langchain.prompts import PromptTemplate
from langchain.schema import StrOutputParser
from langchain.schema.prompt_template import format_document
from langchain.schema.runnable import RunnableParallel, RunnablePassthrough

# %%
os.environ['LLMS_TEMP_DIR'] = '/Users/gburns/alhazen/'
n_gpu_layers = 1 #kwargs.get('n_gpu_layers', 1)
temperature = 0.1 #kwargs.get('temperature', 0.1)
n_batch = 512 #kwargs.get('n_batch', 512)  # Should be between 1 and n_ctx, consider the amount of VRAM in your GPU.
model_path = get_cached_gguf('llama-2-70b-chat')
n_ctx = 4096 #kwargs.get('n_ctx', 4096)

llm = LlamaCpp(
    model_path=model_path,
    n_ctx=n_ctx,
    n_gpu_layers=n_gpu_layers,
    temperature=temperature,
    n_batch=n_batch,
    f16_kv=True,
    verbose=True, # Verbose is required to pass to the callback manager
)    

#llm = get_langchain_llm('llama-2-70b-chat')
# Out:
# llama_model_loader: loaded meta data with 19 key-value pairs and 723 tensors from /Users/gburns/alhazen/llama-2-70b-chat.Q5_K_M.gguf (version GGUF V2 (latest))
# llama_model_loader: - tensor    0:                token_embd.weight q5_K     [  8192, 32000,     1,     1 ]
# llama_model_loader: - tensor    1:           blk.0.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor    2:            blk.0.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor    3:            blk.0.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor    4:              blk.0.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor    5:            blk.0.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor    6:              blk.0.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor    7:         blk.0.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor    8:              blk.0.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor    9:              blk.0.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor   10:           blk.1.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor   11:            blk.1.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor   12:            blk.1.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor   13:              blk.1.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor   14:            blk.1.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor   15:              blk.1.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor   16:         blk.1.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor   17:              blk.1.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor   18:              blk.1.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor   19:           blk.2.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor   20:            blk.2.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor   21:            blk.2.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor   22:              blk.2.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor   23:            blk.2.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor   24:              blk.2.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor   25:         blk.2.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor   26:              blk.2.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor   27:              blk.2.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor   28:           blk.3.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor   29:            blk.3.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor   30:            blk.3.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor   31:              blk.3.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor   32:            blk.3.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor   33:              blk.3.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor   34:         blk.3.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor   35:              blk.3.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor   36:              blk.3.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor   37:           blk.4.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor   38:            blk.4.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor   39:            blk.4.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor   40:              blk.4.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor   41:            blk.4.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor   42:              blk.4.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor   43:         blk.4.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor   44:              blk.4.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor   45:              blk.4.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor   46:            blk.5.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor   47:              blk.5.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor   48:         blk.5.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor   49:              blk.5.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor   50:              blk.5.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor   51:          blk.10.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor   52:           blk.10.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor   53:           blk.10.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor   54:             blk.10.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor   55:           blk.10.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor   56:             blk.10.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor   57:        blk.10.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor   58:             blk.10.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor   59:             blk.10.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor   60:             blk.11.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor   61:        blk.11.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor   62:             blk.11.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor   63:             blk.11.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor   64:           blk.5.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor   65:            blk.5.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor   66:              blk.5.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor   67:            blk.5.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor   68:           blk.6.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor   69:            blk.6.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor   70:            blk.6.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor   71:              blk.6.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor   72:            blk.6.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor   73:              blk.6.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor   74:         blk.6.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor   75:              blk.6.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor   76:              blk.6.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor   77:           blk.7.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor   78:            blk.7.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor   79:            blk.7.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor   80:              blk.7.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor   81:            blk.7.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor   82:              blk.7.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor   83:         blk.7.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor   84:              blk.7.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor   85:              blk.7.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor   86:           blk.8.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor   87:            blk.8.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor   88:            blk.8.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor   89:              blk.8.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor   90:            blk.8.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor   91:              blk.8.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor   92:         blk.8.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor   93:              blk.8.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor   94:              blk.8.attn_v.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor   95:           blk.9.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor   96:            blk.9.ffn_down.weight q5_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor   97:            blk.9.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor   98:              blk.9.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor   99:            blk.9.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  100:              blk.9.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  101:         blk.9.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  102:              blk.9.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  103:              blk.9.attn_v.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  104:          blk.11.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  105:           blk.11.ffn_down.weight q5_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  106:           blk.11.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  107:             blk.11.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  108:           blk.11.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  109:          blk.12.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  110:           blk.12.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  111:           blk.12.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  112:             blk.12.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  113:           blk.12.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  114:             blk.12.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  115:        blk.12.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  116:             blk.12.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  117:             blk.12.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  118:          blk.13.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  119:           blk.13.ffn_down.weight q5_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  120:           blk.13.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  121:             blk.13.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  122:           blk.13.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  123:             blk.13.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  124:        blk.13.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  125:             blk.13.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  126:             blk.13.attn_v.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  127:          blk.14.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  128:           blk.14.ffn_down.weight q5_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  129:           blk.14.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  130:             blk.14.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  131:           blk.14.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  132:             blk.14.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  133:        blk.14.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  134:             blk.14.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  135:             blk.14.attn_v.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  136:          blk.15.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  137:           blk.15.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  138:           blk.15.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  139:             blk.15.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  140:           blk.15.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  141:             blk.15.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  142:        blk.15.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  143:             blk.15.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  144:             blk.15.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  145:          blk.16.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  146:           blk.16.ffn_down.weight q5_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  147:           blk.16.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  148:             blk.16.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  149:           blk.16.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  150:             blk.16.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  151:        blk.16.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  152:             blk.16.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  153:             blk.16.attn_v.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  154:          blk.17.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  155:           blk.17.ffn_down.weight q5_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  156:           blk.17.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  157:             blk.17.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  158:           blk.17.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  159:             blk.17.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  160:        blk.17.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  161:             blk.17.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  162:             blk.17.attn_v.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  163:          blk.18.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  164:           blk.18.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  165:           blk.18.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  166:             blk.18.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  167:           blk.18.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  168:             blk.18.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  169:        blk.18.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  170:             blk.18.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  171:             blk.18.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  172:          blk.19.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  173:           blk.19.ffn_down.weight q5_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  174:           blk.19.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  175:             blk.19.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  176:           blk.19.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  177:             blk.19.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  178:        blk.19.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  179:             blk.19.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  180:             blk.19.attn_v.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  181:          blk.20.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  182:           blk.20.ffn_down.weight q5_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  183:           blk.20.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  184:             blk.20.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  185:           blk.20.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  186:             blk.20.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  187:        blk.20.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  188:             blk.20.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  189:             blk.20.attn_v.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  190:          blk.21.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  191:           blk.21.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  192:           blk.21.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  193:             blk.21.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  194:           blk.21.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  195:             blk.21.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  196:        blk.21.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  197:             blk.21.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  198:             blk.21.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  199:           blk.22.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  200:             blk.22.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  201:             blk.22.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  202:        blk.22.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  203:             blk.22.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  204:             blk.22.attn_v.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  205:          blk.22.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  206:           blk.22.ffn_down.weight q5_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  207:           blk.22.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  208:          blk.23.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  209:           blk.23.ffn_down.weight q5_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  210:           blk.23.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  211:             blk.23.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  212:           blk.23.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  213:             blk.23.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  214:        blk.23.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  215:             blk.23.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  216:             blk.23.attn_v.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  217:          blk.24.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  218:           blk.24.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  219:           blk.24.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  220:             blk.24.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  221:           blk.24.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  222:             blk.24.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  223:        blk.24.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  224:             blk.24.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  225:             blk.24.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  226:          blk.25.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  227:           blk.25.ffn_down.weight q5_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  228:           blk.25.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  229:             blk.25.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  230:           blk.25.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  231:             blk.25.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  232:        blk.25.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  233:             blk.25.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  234:             blk.25.attn_v.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  235:          blk.26.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  236:           blk.26.ffn_down.weight q5_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  237:           blk.26.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  238:             blk.26.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  239:           blk.26.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  240:             blk.26.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  241:        blk.26.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  242:             blk.26.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  243:             blk.26.attn_v.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  244:          blk.27.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  245:           blk.27.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  246:           blk.27.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  247:             blk.27.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  248:           blk.27.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  249:             blk.27.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  250:        blk.27.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  251:             blk.27.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  252:             blk.27.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  253:           blk.28.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  254:             blk.28.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  255:        blk.28.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  256:             blk.28.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  257:             blk.28.attn_v.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  258:          blk.28.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  259:           blk.28.ffn_down.weight q5_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  260:             blk.28.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  261:           blk.28.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  262:          blk.29.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  263:           blk.29.ffn_down.weight q5_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  264:           blk.29.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  265:             blk.29.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  266:           blk.29.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  267:             blk.29.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  268:        blk.29.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  269:             blk.29.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  270:             blk.29.attn_v.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  271:          blk.30.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  272:           blk.30.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  273:           blk.30.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  274:             blk.30.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  275:           blk.30.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  276:             blk.30.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  277:        blk.30.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  278:             blk.30.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  279:             blk.30.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  280:          blk.31.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  281:           blk.31.ffn_down.weight q5_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  282:           blk.31.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  283:             blk.31.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  284:           blk.31.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  285:             blk.31.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  286:        blk.31.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  287:             blk.31.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  288:             blk.31.attn_v.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  289:          blk.32.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  290:           blk.32.ffn_down.weight q5_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  291:           blk.32.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  292:             blk.32.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  293:           blk.32.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  294:             blk.32.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  295:        blk.32.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  296:             blk.32.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  297:             blk.32.attn_v.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  298:          blk.33.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  299:           blk.33.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  300:           blk.33.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  301:             blk.33.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  302:           blk.33.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  303:             blk.33.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  304:        blk.33.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  305:             blk.33.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  306:             blk.33.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  307:             blk.34.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  308:        blk.34.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  309:             blk.34.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  310:             blk.34.attn_v.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  311:          blk.34.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  312:           blk.34.ffn_down.weight q5_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  313:           blk.34.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  314:             blk.34.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  315:           blk.34.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  316:          blk.35.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  317:           blk.35.ffn_down.weight q5_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  318:           blk.35.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  319:             blk.35.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  320:           blk.35.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  321:             blk.35.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  322:        blk.35.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  323:             blk.35.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  324:             blk.35.attn_v.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  325:          blk.36.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  326:           blk.36.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  327:           blk.36.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  328:             blk.36.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  329:           blk.36.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  330:             blk.36.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  331:        blk.36.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  332:             blk.36.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  333:             blk.36.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  334:          blk.37.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  335:           blk.37.ffn_down.weight q5_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  336:           blk.37.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  337:             blk.37.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  338:           blk.37.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  339:             blk.37.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  340:        blk.37.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  341:             blk.37.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  342:             blk.37.attn_v.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  343:          blk.38.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  344:           blk.38.ffn_down.weight q5_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  345:           blk.38.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  346:             blk.38.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  347:           blk.38.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  348:             blk.38.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  349:        blk.38.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  350:             blk.38.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  351:             blk.38.attn_v.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  352:          blk.39.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  353:           blk.39.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  354:           blk.39.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  355:             blk.39.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  356:           blk.39.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  357:             blk.39.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  358:        blk.39.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  359:             blk.39.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  360:             blk.39.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  361:          blk.40.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  362:           blk.40.ffn_down.weight q5_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  363:           blk.40.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  364:             blk.40.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  365:           blk.40.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  366:             blk.40.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  367:        blk.40.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  368:             blk.40.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  369:             blk.40.attn_v.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  370:          blk.41.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  371:           blk.41.ffn_down.weight q5_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  372:           blk.41.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  373:             blk.41.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  374:           blk.41.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  375:             blk.41.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  376:        blk.41.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  377:             blk.41.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  378:             blk.41.attn_v.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  379:          blk.42.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  380:           blk.42.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  381:           blk.42.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  382:             blk.42.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  383:           blk.42.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  384:             blk.42.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  385:        blk.42.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  386:             blk.42.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  387:             blk.42.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  388:          blk.43.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  389:           blk.43.ffn_down.weight q5_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  390:           blk.43.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  391:             blk.43.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  392:           blk.43.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  393:             blk.43.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  394:        blk.43.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  395:             blk.43.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  396:             blk.43.attn_v.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  397:          blk.44.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  398:           blk.44.ffn_down.weight q5_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  399:           blk.44.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  400:             blk.44.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  401:           blk.44.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  402:             blk.44.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  403:        blk.44.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  404:             blk.44.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  405:             blk.44.attn_v.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  406:           blk.45.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  407:             blk.45.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  408:             blk.45.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  409:        blk.45.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  410:             blk.45.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  411:             blk.45.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  412:          blk.45.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  413:           blk.45.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  414:           blk.45.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  415:          blk.46.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  416:           blk.46.ffn_down.weight q5_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  417:           blk.46.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  418:             blk.46.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  419:           blk.46.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  420:             blk.46.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  421:        blk.46.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  422:             blk.46.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  423:             blk.46.attn_v.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  424:          blk.47.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  425:           blk.47.ffn_down.weight q5_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  426:           blk.47.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  427:             blk.47.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  428:           blk.47.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  429:             blk.47.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  430:        blk.47.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  431:             blk.47.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  432:             blk.47.attn_v.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  433:          blk.48.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  434:           blk.48.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  435:           blk.48.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  436:             blk.48.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  437:           blk.48.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  438:             blk.48.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  439:        blk.48.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  440:             blk.48.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  441:             blk.48.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# ...
# llama_model_loader: - tensor  670:             blk.74.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  671:             blk.74.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  672:          blk.74.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  673:           blk.74.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  674:             blk.74.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  675:           blk.74.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  676:          blk.75.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  677:           blk.75.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  678:           blk.75.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  679:             blk.75.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  680:           blk.75.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  681:             blk.75.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  682:        blk.75.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  683:             blk.75.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  684:             blk.75.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  685:          blk.76.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  686:           blk.76.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  687:           blk.76.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  688:             blk.76.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  689:           blk.76.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  690:             blk.76.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  691:        blk.76.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  692:             blk.76.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  693:             blk.76.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  694:          blk.77.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  695:           blk.77.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  696:           blk.77.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  697:             blk.77.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  698:           blk.77.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  699:             blk.77.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  700:        blk.77.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  701:             blk.77.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  702:             blk.77.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  703:          blk.78.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  704:           blk.78.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  705:           blk.78.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  706:             blk.78.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  707:           blk.78.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  708:             blk.78.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  709:        blk.78.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  710:             blk.78.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  711:             blk.78.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  712:          blk.79.attn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  713:           blk.79.ffn_down.weight q6_K     [ 28672,  8192,     1,     1 ]
# llama_model_loader: - tensor  714:           blk.79.ffn_gate.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  715:             blk.79.ffn_up.weight q5_K     [  8192, 28672,     1,     1 ]
# llama_model_loader: - tensor  716:           blk.79.ffn_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  717:             blk.79.attn_k.weight q5_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  718:        blk.79.attn_output.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  719:             blk.79.attn_q.weight q5_K     [  8192,  8192,     1,     1 ]
# llama_model_loader: - tensor  720:             blk.79.attn_v.weight q6_K     [  8192,  1024,     1,     1 ]
# llama_model_loader: - tensor  721:               output_norm.weight f32      [  8192,     1,     1,     1 ]
# llama_model_loader: - tensor  722:                    output.weight q6_K     [  8192, 32000,     1,     1 ]
# llama_model_loader: - kv   0:                       general.architecture str
# llama_model_loader: - kv   1:                               general.name str
# llama_model_loader: - kv   2:                       llama.context_length u32
# llama_model_loader: - kv   3:                     llama.embedding_length u32
# llama_model_loader: - kv   4:                          llama.block_count u32
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32
# llama_model_loader: - kv   7:                 llama.attention.head_count u32
# llama_model_loader: - kv   8:              llama.attention.head_count_kv u32
# llama_model_loader: - kv   9:     llama.attention.layer_norm_rms_epsilon f32
# llama_model_loader: - kv  10:                          general.file_type u32
# llama_model_loader: - kv  11:                       tokenizer.ggml.model str
# llama_model_loader: - kv  12:                      tokenizer.ggml.tokens arr
# llama_model_loader: - kv  13:                      tokenizer.ggml.scores arr
# llama_model_loader: - kv  14:                  tokenizer.ggml.token_type arr
# llama_model_loader: - kv  15:                tokenizer.ggml.bos_token_id u32
# llama_model_loader: - kv  16:                tokenizer.ggml.eos_token_id u32
# llama_model_loader: - kv  17:            tokenizer.ggml.unknown_token_id u32
# llama_model_loader: - kv  18:               general.quantization_version u32
# llama_model_loader: - type  f32:  161 tensors
# llama_model_loader: - type q5_K:  481 tensors
# llama_model_loader: - type q6_K:   81 tensors
# llm_load_print_meta: format         = GGUF V2 (latest)
# llm_load_print_meta: arch           = llama
# llm_load_print_meta: vocab type     = SPM
# llm_load_print_meta: n_vocab        = 32000
# llm_load_print_meta: n_merges       = 0
# llm_load_print_meta: n_ctx_train    = 4096
# llm_load_print_meta: n_ctx          = 4096
# llm_load_print_meta: n_embd         = 8192
# llm_load_print_meta: n_head         = 64
# llm_load_print_meta: n_head_kv      = 8
# llm_load_print_meta: n_layer        = 80
# llm_load_print_meta: n_rot          = 128
# llm_load_print_meta: n_gqa          = 8
# llm_load_print_meta: f_norm_eps     = 0.0e+00
# llm_load_print_meta: f_norm_rms_eps = 1.0e-05
# llm_load_print_meta: n_ff           = 28672
# llm_load_print_meta: freq_base      = 10000.0
# llm_load_print_meta: freq_scale     = 1
# llm_load_print_meta: model type     = 70B
# llm_load_print_meta: model ftype    = mostly Q5_K - Medium
# llm_load_print_meta: model params   = 68.98 B
# llm_load_print_meta: model size     = 45.40 GiB (5.65 BPW)
# llm_load_print_meta: general.name   = LLaMA v2
# llm_load_print_meta: BOS token = 1 '<s>'
# llm_load_print_meta: EOS token = 2 '</s>'
# llm_load_print_meta: UNK token = 0 '<unk>'
# llm_load_print_meta: LF token  = 13 '<0x0A>'
# llm_load_tensors: ggml ctx size =    0.23 MB
# llm_load_tensors: mem required  = 46494.72 MB (+ 1280.00 MB per state)
# ....................................................................................................
# llama_new_context_with_model: kv self size  = 1280.00 MB
# ggml_metal_init: allocating
# ggml_metal_init: found device: Apple M2 Max
# ggml_metal_init: picking default device: Apple M2 Max
# ggml_metal_init: loading '/Users/gburns/miniconda3/envs/alhazen/lib/python3.11/site-packages/llama_cpp/ggml-metal.metal'
# ggml_metal_init: loaded kernel_add                            0x2bd0bfda0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_row                        0x2bd0bffd0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul                            0x2bd0c0200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_row                        0x2bd0c0430 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_scale                          0x2bd0c0660 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_silu                           0x2bd0c0890 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_relu                           0x2bd0c0ac0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu                           0x2bd0c0cf0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max                       0x2bd0c0f20 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_4                     0x2bd0c1150 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_diag_mask_inf                  0x2bd0c1380 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_diag_mask_inf_8                0x2bd0c15b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_f32                   0x2bd0c17e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_f16                   0x2bd0c1a10 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q4_0                  0x2bd0c1c40 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q4_1                  0x2bd0c1e70 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q8_0                  0x2bd0c20a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q2_K                  0x2bd0c22d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q3_K                  0x2bd0c2500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q4_K                  0x2bd0c2730 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q5_K                  0x2bd0c2960 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q6_K                  0x2bd0c2b90 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rms_norm                       0x2bd0c2dc0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_norm                           0x2bd0c2ff0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mat_f32_f32                0x2bd0c3220 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mat_f16_f32                0x2bd0c3450 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mat_f16_f32_1row           0x2bd0c3680 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mat_f16_f32_l4             0x2bd0c38b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mat_q4_0_f32               0x2bd0c3ae0 | th_max =  896 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mat_q4_1_f32               0x2bd0c3d10 | th_max =  896 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mat_q8_0_f32               0x2bd0c3f40 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mat_q2_K_f32               0x2bd0c4170 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mat_q3_K_f32               0x2bd0c43a0 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mat_q4_K_f32               0x2bd0c45d0 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mat_q5_K_f32               0x2bd0c4800 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mat_q6_K_f32               0x2bd0c4a30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_f32_f32                 0x2bd0c4c60 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_f16_f32                 0x2bd0c4e90 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q4_0_f32                0x2bd0c50c0 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q8_0_f32                0x2bd0c52f0 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q4_1_f32                0x2bd0c5520 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q2_K_f32                0x2bd0c5750 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q3_K_f32                0x2bd0c5980 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q4_K_f32                0x2bd0c5bb0 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q5_K_f32                0x2bd0c5de0 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q6_K_f32                0x2bd0c6010 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_rope                           0x2bd0c6240 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_alibi_f32                      0x2bd0c6470 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_f16                    0x2bd0c66a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_f32                    0x2bd0c68d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f16_f16                    0x2bd0c6b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: hasUnifiedMemory              = true
# ggml_metal_init: recommendedMaxWorkingSetSize  = 73728.00 MB
# ggml_metal_init: maxTransferRate               = built-in GPU
# llama_new_context_with_model: compute buffer total size =  565.47 MB
# llama_new_context_with_model: max tensor size =   205.08 MB
# ggml_metal_add_buffer: allocated 'data            ' buffer, size = 46495.22 MB, (94838.56 / 73728.00), warning: current allocated size is greater than the recommended max working set size
# ggml_metal_add_buffer: allocated 'eval            ' buffer, size =     1.48 MB, (94840.05 / 73728.00), warning: current allocated size is greater than the recommended max working set size
# ggml_metal_add_buffer: allocated 'kv              ' buffer, size =  1282.00 MB, (96122.05 / 73728.00), warning: current allocated size is greater than the recommended max working set size
# AVX = 0 | AVX2 = 0 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 0 | NEON = 1 | ARM_FMA = 1 | F16C = 0 | FP16_VA = 1 | WASM_SIMD = 0 | BLAS = 1 | SSE3 = 0 | SSSE3 = 0 | VSX = 0 |
# ggml_metal_add_buffer: allocated 'alloc           ' buffer, size =   564.02 MB, (96686.06 / 73728.00), warning: current allocated size is greater than the recommended max working set size

# %%
from alhazen.utils.langchain_utils import suppress_stdout_stderr, JsonEnclosedByTextOutputParser
from langchain.schema import OutputParserException

instructions = PromptTemplateRegistry()
instructions.load_prompts_from_yaml('ft_method_metadata_extraction.yaml')
pt1 = instructions.get_instruction_template('cryoet protocol step identification').generate_llama2_prompt_template()

pt2 = instructions.get_instruction_template('cryoet metadata extraction').generate_llama2_prompt_template()
metadata_specs = [
    {'step': 'AB', 'name': 'biological_sample_type', 'spec': 'What is the type of biological sample being used? Select from the following list: cell culture, tissue, organoid, organ, whole organism, virus, micro-organism, other.'},
    {'step': 'AB', 'name': 'organism_name', 'spec': 'If the biological sample was taken from an organism, provide the scientific name of the organism. If the biological sample is not from an organism, return none.'},
    {'step': 'AB', 'name': 'cell_strain', 'spec': 'If the biological sample described in the text is a cell or cell culture, what was the strain?'},
    {'step': 'AB', 'name': 'sample_preparation', 'spec': 'Provide a summary of any actions performed on the biological sample.'},
    {'step': 'C', 'name': 'grid_preparation', 'spec': 'Provide a summary of how grids were prepared for electron microscopy.'},
    {'step': 'D', 'name': 'cryoet_pixel_spacing', 'spec': ' What was the pixel spacing the CryoET step?'},
    {'step': 'D', 'name': 'cryoet_acceleration_voltage', 'spec': 'What was the acceleration voltage?'},
    {'step': 'D', 'name': 'microscope_name', 'spec': 'What was the name of the type of electron microscope being used?'},
    {'step': 'D', 'name': 'microscope_setup', 'spec': 'Which, if any, of the following electron microscopy methods were used:- (A) an energy filter, (B) a phase plate, or (C) an image corrector?'},
    {'step': 'D', 'name': 'camera_manufacturer', 'spec': 'Which company made the camera used to capture tilt images?'},
    {'step': 'D', 'name': 'camera_model', 'spec': 'What model of camera was used to capture tilt images?'},
    {'step': 'D', 'name': 'tilt_minimum', 'spec': 'What was the minimum angle used in the tilt-series?'},
    {'step': 'D', 'name': 'tilt_maximum', 'spec': 'What was the maximum angle used in the tilt-series?'},
    {'step': 'D', 'name': 'total_flux', 'spec': 'What was the total flux or total exposure dose?'},
    {'step': 'E', 'name': 'reconstruction_software', 'spec': 'What software or computational methods were used to perform the tomogram reconstruction?'},
    {'step': 'E', 'name': 'tomogram_size', 'spec': 'What are the dimensions of the tomogram dataset (measured in numbers of pixels)?'},
    {'step': 'E', 'name': 'reconstruction_method', 'spec': 'What computational methods / algorithms were used (e.g., weighted back propagation, etc)?'},
    {'step': 'F', 'name': 'annotated_entities', 'spec': 'What organelles or subcellular components were annotated in the images?'},
    {'step': 'F', 'name': 'annotation_methods', 'spec': 'List all the methods describing how annotations were generated (manually, computational analysis, machine learning, etc)?'},
    {'step': 'F', 'name': 'annotated_software', 'spec': 'What software was used to make the annotations?'},
] 
docs = [ row.PLAIN_TEXT 
    for i, row in df4.iterrows()
    if row.LENGTH > 50
]

# Can't use callbacks with LCEL constructs
protocol_step_id_lcel = pt1 | llm | JsonEnclosedByTextOutputParser()
extract_lcel = pt2 | llm | JsonEnclosedByTextOutputParser()

extractions = []
for i, row in df4.reset_index(drop=False).iterrows():
    print('\n\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print(i, row.OFFSET, row.PLAIN_TEXT)
    if row.LENGTH <= 50:
        continue
    #if i<11:
    #    continue
    s1 = {'section_text':row.PLAIN_TEXT }
    
    protocol_step = None
    attempts = 0
    while protocol_step is None and attempts < 5:
        try: 
            #with suppress_stdout_stderr():
            out1 = protocol_step_id_lcel.invoke(s1, config={'callbacks': [ConsoleCallbackHandler()]})
            if out1 is not None:
                protocol_step = out1.get('protocol_step', None)
            else: 
                protocol_step = 'X'
        except OutputParserException as e:
            attempts += 1
            print(e) 
            continue

    print('\t'+protocol_step)  
    for spec in metadata_specs:
        print('\t'+spec.get('name'))
        if protocol_step not in spec.get('step') :
            continue
        s2 = {'section_text':row.PLAIN_TEXT, 'metadata_specification': spec.get('spec'), 'metadata_name': spec.get('name') }
        
        try:
            #with suppress_stdout_stderr():
            out2 = extract_lcel.invoke(s2, config={'callbacks': [ConsoleCallbackHandler()]})
        except OutputParserException as e:
            continue
        if out2 is not None:
            out2['p_id'] = i
            out2['offset'] = row.OFFSET
            out2['length'] = row.LENGTH
            extractions.append(out2)
    print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
# Out:
# ggml_metal_free: deallocating
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 0 29117 Methods
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 1 29126 Cryo-ET sample preparation and data collection
# The M. pneumoniae cultivation, sample preparation and data collection were described previously2. The three datasets of native untreated, Cm-treated and PUM-treated cells were re-processed in Warp and M 1.0.7 (the alpha versions that were officially released as v.1.0.9.)3,54. A small dataset of 15 tomograms acquired with Volta phase plate was processed with the denoising network in Warp 1.0.9 for visualization purposes only (as shown in Fig. 1a).
# A dataset of spectinomycin-treated cells was collected following the same procedure as before2. In brief, spectinomycin (Sigma-Aldrich) at a final concentration of 0.4 mg ml-1 was added into the culture medium, 15-20 min before plunge-freezing. Tilt-series collection with the dose-symmetric scheme55 was performed on a Titan Krios transmission electron microscope equipped with a K3 camera (Gatan) using SerialEM 3.8 (ref. 56) with the following parameters: magnification 81,000x, pixel size 1.053 A, tilt range -60degrees to 60degrees with 3degrees increment, total dose 120-140 e- A-2.
# In total, 356 native untreated, 65 Cm-treated, 86 PUM-treated and 70 Spc-treated cellular tomograms were analysed in this work. Details of cryo-EM data collection, refinement and validation statistics are provided in Supplementary Tables 1 and 3-6.
# [chain/start] [1:chain:RunnableSequence] Entering Chain run with input:
# {
#   "section_text": "Cryo-ET sample preparation and data collection\nThe M. pneumoniae cultivation, sample preparation and data collection were described previously2. The three datasets of native untreated, Cm-treated and PUM-treated cells were re-processed in Warp and M 1.0.7 (the alpha versions that were officially released as v.1.0.9.)3,54. A small dataset of 15 tomograms acquired with Volta phase plate was processed with the denoising network in Warp 1.0.9 for visualization purposes only (as shown in Fig. 1a).\nA dataset of spectinomycin-treated cells was collected following the same procedure as before2. In brief, spectinomycin (Sigma-Aldrich) at a final concentration of 0.4 mg ml-1 was added into the culture medium, 15-20 min before plunge-freezing. Tilt-series collection with the dose-symmetric scheme55 was performed on a Titan Krios transmission electron microscope equipped with a K3 camera (Gatan) using SerialEM 3.8 (ref. 56) with the following parameters: magnification 81,000x, pixel size 1.053 A, tilt range -60degrees to 60degrees with 3degrees increment, total dose 120-140 e- A-2.\nIn total, 356 native untreated, 65 Cm-treated, 86 PUM-treated and 70 Spc-treated cellular tomograms were analysed in this work. Details of cryo-EM data collection, refinement and validation statistics are provided in Supplementary Tables 1 and 3-6."
# }
# [chain/start] [1:chain:RunnableSequence > 2:prompt:PromptTemplate] Entering Prompt run with input:
# {
#   "section_text": "Cryo-ET sample preparation and data collection\nThe M. pneumoniae cultivation, sample preparation and data collection were described previously2. The three datasets of native untreated, Cm-treated and PUM-treated cells were re-processed in Warp and M 1.0.7 (the alpha versions that were officially released as v.1.0.9.)3,54. A small dataset of 15 tomograms acquired with Volta phase plate was processed with the denoising network in Warp 1.0.9 for visualization purposes only (as shown in Fig. 1a).\nA dataset of spectinomycin-treated cells was collected following the same procedure as before2. In brief, spectinomycin (Sigma-Aldrich) at a final concentration of 0.4 mg ml-1 was added into the culture medium, 15-20 min before plunge-freezing. Tilt-series collection with the dose-symmetric scheme55 was performed on a Titan Krios transmission electron microscope equipped with a K3 camera (Gatan) using SerialEM 3.8 (ref. 56) with the following parameters: magnification 81,000x, pixel size 1.053 A, tilt range -60degrees to 60degrees with 3degrees increment, total dose 120-140 e- A-2.\nIn total, 356 native untreated, 65 Cm-treated, 86 PUM-treated and 70 Spc-treated cellular tomograms were analysed in this work. Details of cryo-EM data collection, refinement and validation statistics are provided in Supplementary Tables 1 and 3-6."
# }
# [chain/end] [1:chain:RunnableSequence > 2:prompt:PromptTemplate] s] Exiting Prompt run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "prompts",
#     "base",
#     "StringPromptValue"
#   ],
#   "kwargs": {
#     "text": "<s>[INST]\n                <<SYS>>You are an expert biological scientist trained in imaging and microscopy.<</SYS>>\n                Read the text of a section of a research paper shown below (delimited with triple backticks).\nSection Text:- '''Cryo-ET sample preparation and data collection\nThe M. pneumoniae cultivation, sample preparation and data collection were described previously2. The three datasets of native untreated, Cm-treated and PUM-treated cells were re-processed in Warp and M 1.0.7 (the alpha versions that were officially released as v.1.0.9.)3,54. A small dataset of 15 tomograms acquired with Volta phase plate was processed with the denoising network in Warp 1.0.9 for visualization purposes only (as shown in Fig. 1a).\nA dataset of spectinomycin-treated cells was collected following the same procedure as before2. In brief, spectinomycin (Sigma-Aldrich) at a final concentration of 0.4 mg ml-1 was added into the culture medium, 15-20 min before plunge-freezing. Tilt-series collection with the dose-symmetric scheme55 was performed on a Titan Krios transmission electron microscope equipped with a K3 camera (Gatan) using SerialEM 3.8 (ref. 56) with the following parameters: magnification 81,000x, pixel size 1.053 A, tilt range -60degrees to 60degrees with 3degrees increment, total dose 120-140 e- A-2.\nIn total, 356 native untreated, 65 Cm-treated, 86 PUM-treated and 70 Spc-treated cellular tomograms were analysed in this work. Details of cryo-EM data collection, refinement and validation statistics are provided in Supplementary Tables 1 and 3-6.'''\nThe text is taken from a scientific paper that uses Cryo-Electron Tomography (CryoET) to study the microscopic structure of a biological sample. The text may describe the procedures followed as part of the protocol or some other aspect of the work.\nIf the text describes the protocol being used, identify which of the following steps is being described - (A) the preparation of a biological sample for imaging (such as cells, tissue, a virus, a microorganism, etc.), (B) vitrification (freezing) of the sample, (C) milling the sample using a focussed ion beam (FIB) to create a used to prepare a thin, electron-transparent lamella. (D) imaging the lamella using CryoET by collecting a tilt series of images of the lamella at different angles. (E) reconstructing 3-D tomograms in by aligning tilt series and performing reconstruction computations. (F) annotating the 3D model of the sample to identify structures of interest. (G) other protocol steps, not listed above.\nIf the text describes other aspects of the work, record 'not present' in the 'protocol_step' field of the output.\nGenerate only JSON formatted output with one field 'protocol_step'. Do not include any other response other than a JSON object.\nIdentify which of these parts of the protocol are described in the text, and record the corresponding value of A, B, C, D, E, or F in the 'protocol_step' field of the output.\n                [/INST]</s>"
#   }
# }
# [llm/start] [1:chain:RunnableSequence > 3:llm:LlamaCpp] Entering LLM run with input:
# {
#   "prompts": [
#     "<s>[INST]\n                <<SYS>>You are an expert biological scientist trained in imaging and microscopy.<</SYS>>\n                Read the text of a section of a research paper shown below (delimited with triple backticks).\nSection Text:- '''Cryo-ET sample preparation and data collection\nThe M. pneumoniae cultivation, sample preparation and data collection were described previously2. The three datasets of native untreated, Cm-treated and PUM-treated cells were re-processed in Warp and M 1.0.7 (the alpha versions that were officially released as v.1.0.9.)3,54. A small dataset of 15 tomograms acquired with Volta phase plate was processed with the denoising network in Warp 1.0.9 for visualization purposes only (as shown in Fig. 1a).\nA dataset of spectinomycin-treated cells was collected following the same procedure as before2. In brief, spectinomycin (Sigma-Aldrich) at a final concentration of 0.4 mg ml-1 was added into the culture medium, 15-20 min before plunge-freezing. Tilt-series collection with the dose-symmetric scheme55 was performed on a Titan Krios transmission electron microscope equipped with a K3 camera (Gatan) using SerialEM 3.8 (ref. 56) with the following parameters: magnification 81,000x, pixel size 1.053 A, tilt range -60degrees to 60degrees with 3degrees increment, total dose 120-140 e- A-2.\nIn total, 356 native untreated, 65 Cm-treated, 86 PUM-treated and 70 Spc-treated cellular tomograms were analysed in this work. Details of cryo-EM data collection, refinement and validation statistics are provided in Supplementary Tables 1 and 3-6.'''\nThe text is taken from a scientific paper that uses Cryo-Electron Tomography (CryoET) to study the microscopic structure of a biological sample. The text may describe the procedures followed as part of the protocol or some other aspect of the work.\nIf the text describes the protocol being used, identify which of the following steps is being described - (A) the preparation of a biological sample for imaging (such as cells, tissue, a virus, a microorganism, etc.), (B) vitrification (freezing) of the sample, (C) milling the sample using a focussed ion beam (FIB) to create a used to prepare a thin, electron-transparent lamella. (D) imaging the lamella using CryoET by collecting a tilt series of images of the lamella at different angles. (E) reconstructing 3-D tomograms in by aligning tilt series and performing reconstruction computations. (F) annotating the 3D model of the sample to identify structures of interest. (G) other protocol steps, not listed above.\nIf the text describes other aspects of the work, record 'not present' in the 'protocol_step' field of the output.\nGenerate only JSON formatted output with one field 'protocol_step'. Do not include any other response other than a JSON object.\nIdentify which of these parts of the protocol are described in the text, and record the corresponding value of A, B, C, D, E, or F in the 'protocol_step' field of the output.\n                [/INST]</s>"
#   ]
# }
# llama_print_timings:        load time = 10455.37 ms
# llama_print_timings:      sample time =   122.00 ms /   110 runs   (    1.11 ms per token,   901.66 tokens per second)
# llama_print_timings: prompt eval time = 17214.07 ms /   837 tokens (   20.57 ms per token,    48.62 tokens per second)
# llama_print_timings:        eval time = 19574.83 ms /   109 runs   (  179.59 ms per token,     5.57 tokens per second)
# llama_print_timings:       total time = 37195.23 ms
# Llama.generate: prefix-match hit
# [llm/end] [1:chain:RunnableSequence > 3:llm:LlamaCpp] [37.20s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "  {\n\"protocol_step\": \"A\"\n}\n\nThe text describes the preparation of a biological sample for imaging, specifically the cultivation and sample preparation of M. pneumoniae cells, as well as the addition of various treatments (Cm-treated, PUM-treated, and Spc-treated) to the cells before plunge-freezing. Therefore, option A (the preparation of a biological sample for imaging) is the most appropriate choice.",
#         "generation_info": null,
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [chain/start] [1:chain:RunnableSequence > 4:parser:JsonEnclosedByTextOutputParser] Entering Parser run with input:
# {
#   "input": "  {\n\"protocol_step\": \"A\"\n}\n\nThe text describes the preparation of a biological sample for imaging, specifically the cultivation and sample preparation of M. pneumoniae cells, as well as the addition of various treatments (Cm-treated, PUM-treated, and Spc-treated) to the cells before plunge-freezing. Therefore, option A (the preparation of a biological sample for imaging) is the most appropriate choice."
# }
# [chain/end] [1:chain:RunnableSequence > 4:parser:JsonEnclosedByTextOutputParser] s] Exiting Parser run with output:
# {
#   "protocol_step": "A"
# }
# [chain/end] [1:chain:RunnableSequence] [37.20s] Exiting Chain run with output:
# {
#   "protocol_step": "A"
# }
# 	A
# 	biological_sample_type
# [chain/start] [1:chain:RunnableSequence] Entering Chain run with input:
# {
#   "section_text": "Cryo-ET sample preparation and data collection\nThe M. pneumoniae cultivation, sample preparation and data collection were described previously2. The three datasets of native untreated, Cm-treated and PUM-treated cells were re-processed in Warp and M 1.0.7 (the alpha versions that were officially released as v.1.0.9.)3,54. A small dataset of 15 tomograms acquired with Volta phase plate was processed with the denoising network in Warp 1.0.9 for visualization purposes only (as shown in Fig. 1a).\nA dataset of spectinomycin-treated cells was collected following the same procedure as before2. In brief, spectinomycin (Sigma-Aldrich) at a final concentration of 0.4 mg ml-1 was added into the culture medium, 15-20 min before plunge-freezing. Tilt-series collection with the dose-symmetric scheme55 was performed on a Titan Krios transmission electron microscope equipped with a K3 camera (Gatan) using SerialEM 3.8 (ref. 56) with the following parameters: magnification 81,000x, pixel size 1.053 A, tilt range -60degrees to 60degrees with 3degrees increment, total dose 120-140 e- A-2.\nIn total, 356 native untreated, 65 Cm-treated, 86 PUM-treated and 70 Spc-treated cellular tomograms were analysed in this work. Details of cryo-EM data collection, refinement and validation statistics are provided in Supplementary Tables 1 and 3-6.",
#   "metadata_specification": "What is the type of biological sample being used? Select from the following list: cell culture, tissue, organoid, organ, whole organism, virus, micro-organism, other.",
#   "metadata_name": "biological_sample_type"
# }
# [chain/start] [1:chain:RunnableSequence > 2:prompt:PromptTemplate] Entering Prompt run with input:
# {
#   "section_text": "Cryo-ET sample preparation and data collection\nThe M. pneumoniae cultivation, sample preparation and data collection were described previously2. The three datasets of native untreated, Cm-treated and PUM-treated cells were re-processed in Warp and M 1.0.7 (the alpha versions that were officially released as v.1.0.9.)3,54. A small dataset of 15 tomograms acquired with Volta phase plate was processed with the denoising network in Warp 1.0.9 for visualization purposes only (as shown in Fig. 1a).\nA dataset of spectinomycin-treated cells was collected following the same procedure as before2. In brief, spectinomycin (Sigma-Aldrich) at a final concentration of 0.4 mg ml-1 was added into the culture medium, 15-20 min before plunge-freezing. Tilt-series collection with the dose-symmetric scheme55 was performed on a Titan Krios transmission electron microscope equipped with a K3 camera (Gatan) using SerialEM 3.8 (ref. 56) with the following parameters: magnification 81,000x, pixel size 1.053 A, tilt range -60degrees to 60degrees with 3degrees increment, total dose 120-140 e- A-2.\nIn total, 356 native untreated, 65 Cm-treated, 86 PUM-treated and 70 Spc-treated cellular tomograms were analysed in this work. Details of cryo-EM data collection, refinement and validation statistics are provided in Supplementary Tables 1 and 3-6.",
#   "metadata_specification": "What is the type of biological sample being used? Select from the following list: cell culture, tissue, organoid, organ, whole organism, virus, micro-organism, other.",
#   "metadata_name": "biological_sample_type"
# }
# [chain/end] [1:chain:RunnableSequence > 2:prompt:PromptTemplate] s] Exiting Prompt run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "prompts",
#     "base",
#     "StringPromptValue"
#   ],
#   "kwargs": {
#     "text": "<s>[INST]\n                <<SYS>>You are an expert biological scientist trained in imaging and microscopy.<</SYS>>\n                Read the text of a section from the methods section of a research paper shown below (delimited with triple backticks).\nSection Text:- '''Cryo-ET sample preparation and data collection\nThe M. pneumoniae cultivation, sample preparation and data collection were described previously2. The three datasets of native untreated, Cm-treated and PUM-treated cells were re-processed in Warp and M 1.0.7 (the alpha versions that were officially released as v.1.0.9.)3,54. A small dataset of 15 tomograms acquired with Volta phase plate was processed with the denoising network in Warp 1.0.9 for visualization purposes only (as shown in Fig. 1a).\nA dataset of spectinomycin-treated cells was collected following the same procedure as before2. In brief, spectinomycin (Sigma-Aldrich) at a final concentration of 0.4 mg ml-1 was added into the culture medium, 15-20 min before plunge-freezing. Tilt-series collection with the dose-symmetric scheme55 was performed on a Titan Krios transmission electron microscope equipped with a K3 camera (Gatan) using SerialEM 3.8 (ref. 56) with the following parameters: magnification 81,000x, pixel size 1.053 A, tilt range -60degrees to 60degrees with 3degrees increment, total dose 120-140 e- A-2.\nIn total, 356 native untreated, 65 Cm-treated, 86 PUM-treated and 70 Spc-treated cellular tomograms were analysed in this work. Details of cryo-EM data collection, refinement and validation statistics are provided in Supplementary Tables 1 and 3-6.'''\nExtract the metadata from the section text based only on the specification delineated by square brackets and record the answer in the 'metadata_value' field of the output. Do not extract any other metadata.\n[What is the type of biological sample being used? Select from the following list: cell culture, tissue, organoid, organ, whole organism, virus, micro-organism, other.]\nRecord the term 'biological_sample_type' in the 'metadata_name' field of the output.\nGenerate only JSON formatted output with three fields 'metadata_name', 'metadata_value' and 'orginal_text'. Do not provide additional explanation or context for the answer.\nIf the metadata is not present in the text, record a value of 'not present' in the 'metadata_value' field of the output. Do not include any other response other than a JSON object.\nFinally, if you found the metadata in the text, record the original text of the sentence where the metadata specification was extracted from in the 'original_text' field of the output.\nIf you did not find the specified metadata in the text, record 'not present' in the 'original_text' field of the output.\nRemember, only generate JSON formatted output without any additional text or explanation.\n                [/INST]</s>"
#   }
# }
# [llm/start] [1:chain:RunnableSequence > 3:llm:LlamaCpp] Entering LLM run with input:
# {
#   "prompts": [
#     "<s>[INST]\n                <<SYS>>You are an expert biological scientist trained in imaging and microscopy.<</SYS>>\n                Read the text of a section from the methods section of a research paper shown below (delimited with triple backticks).\nSection Text:- '''Cryo-ET sample preparation and data collection\nThe M. pneumoniae cultivation, sample preparation and data collection were described previously2. The three datasets of native untreated, Cm-treated and PUM-treated cells were re-processed in Warp and M 1.0.7 (the alpha versions that were officially released as v.1.0.9.)3,54. A small dataset of 15 tomograms acquired with Volta phase plate was processed with the denoising network in Warp 1.0.9 for visualization purposes only (as shown in Fig. 1a).\nA dataset of spectinomycin-treated cells was collected following the same procedure as before2. In brief, spectinomycin (Sigma-Aldrich) at a final concentration of 0.4 mg ml-1 was added into the culture medium, 15-20 min before plunge-freezing. Tilt-series collection with the dose-symmetric scheme55 was performed on a Titan Krios transmission electron microscope equipped with a K3 camera (Gatan) using SerialEM 3.8 (ref. 56) with the following parameters: magnification 81,000x, pixel size 1.053 A, tilt range -60degrees to 60degrees with 3degrees increment, total dose 120-140 e- A-2.\nIn total, 356 native untreated, 65 Cm-treated, 86 PUM-treated and 70 Spc-treated cellular tomograms were analysed in this work. Details of cryo-EM data collection, refinement and validation statistics are provided in Supplementary Tables 1 and 3-6.'''\nExtract the metadata from the section text based only on the specification delineated by square brackets and record the answer in the 'metadata_value' field of the output. Do not extract any other metadata.\n[What is the type of biological sample being used? Select from the following list: cell culture, tissue, organoid, organ, whole organism, virus, micro-organism, other.]\nRecord the term 'biological_sample_type' in the 'metadata_name' field of the output.\nGenerate only JSON formatted output with three fields 'metadata_name', 'metadata_value' and 'orginal_text'. Do not provide additional explanation or context for the answer.\nIf the metadata is not present in the text, record a value of 'not present' in the 'metadata_value' field of the output. Do not include any other response other than a JSON object.\nFinally, if you found the metadata in the text, record the original text of the sentence where the metadata specification was extracted from in the 'original_text' field of the output.\nIf you did not find the specified metadata in the text, record 'not present' in the 'original_text' field of the output.\nRemember, only generate JSON formatted output without any additional text or explanation.\n                [/INST]</s>"
#   ]
# }
# [llm/end] [1:chain:RunnableSequence > 3:llm:LlamaCpp] [24.20s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "  {\n\"metadata_name\": \"biological_sample_type\",\n\"metadata_value\": \"cell culture\",\n\"original_text\": \"The M. pneumoniae cultivation, sample preparation and data collection were described previously2.\"\n}",
#         "generation_info": null,
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [chain/start] [1:chain:RunnableSequence > 4:parser:JsonEnclosedByTextOutputParser] Entering Parser run with input:
# {
#   "input": "  {\n\"metadata_name\": \"biological_sample_type\",\n\"metadata_value\": \"cell culture\",\n\"original_text\": \"The M. pneumoniae cultivation, sample preparation and data collection were described previously2.\"\n}"
# }
# [chain/end] [1:chain:RunnableSequence > 4:parser:JsonEnclosedByTextOutputParser] s] Exiting Parser run with output:
# {
#   "metadata_name": "biological_sample_type",
#   "metadata_value": "cell culture",
#   "original_text": "The M. pneumoniae cultivation, sample preparation and data collection were described previously2."
# }
# [chain/end] [1:chain:RunnableSequence] [24.20s] Exiting Chain run with output:
# {
#   "metadata_name": "biological_sample_type",
#   "metadata_value": "cell culture",
#   "original_text": "The M. pneumoniae cultivation, sample preparation and data collection were described previously2."
# }
# 	organism_name
# [chain/start] [1:chain:RunnableSequence] Entering Chain run with input:
# {
#   "section_text": "Cryo-ET sample preparation and data collection\nThe M. pneumoniae cultivation, sample preparation and data collection were described previously2. The three datasets of native untreated, Cm-treated and PUM-treated cells were re-processed in Warp and M 1.0.7 (the alpha versions that were officially released as v.1.0.9.)3,54. A small dataset of 15 tomograms acquired with Volta phase plate was processed with the denoising network in Warp 1.0.9 for visualization purposes only (as shown in Fig. 1a).\nA dataset of spectinomycin-treated cells was collected following the same procedure as before2. In brief, spectinomycin (Sigma-Aldrich) at a final concentration of 0.4 mg ml-1 was added into the culture medium, 15-20 min before plunge-freezing. Tilt-series collection with the dose-symmetric scheme55 was performed on a Titan Krios transmission electron microscope equipped with a K3 camera (Gatan) using SerialEM 3.8 (ref. 56) with the following parameters: magnification 81,000x, pixel size 1.053 A, tilt range -60degrees to 60degrees with 3degrees increment, total dose 120-140 e- A-2.\nIn total, 356 native untreated, 65 Cm-treated, 86 PUM-treated and 70 Spc-treated cellular tomograms were analysed in this work. Details of cryo-EM data collection, refinement and validation statistics are provided in Supplementary Tables 1 and 3-6.",
#   "metadata_specification": "If the biological sample was taken from an organism, provide the scientific name of the organism. If the biological sample is not from an organism, return none.",
#   "metadata_name": "organism_name"
# }
# [chain/start] [1:chain:RunnableSequence > 2:prompt:PromptTemplate] Entering Prompt run with input:
# {
#   "section_text": "Cryo-ET sample preparation and data collection\nThe M. pneumoniae cultivation, sample preparation and data collection were described previously2. The three datasets of native untreated, Cm-treated and PUM-treated cells were re-processed in Warp and M 1.0.7 (the alpha versions that were officially released as v.1.0.9.)3,54. A small dataset of 15 tomograms acquired with Volta phase plate was processed with the denoising network in Warp 1.0.9 for visualization purposes only (as shown in Fig. 1a).\nA dataset of spectinomycin-treated cells was collected following the same procedure as before2. In brief, spectinomycin (Sigma-Aldrich) at a final concentration of 0.4 mg ml-1 was added into the culture medium, 15-20 min before plunge-freezing. Tilt-series collection with the dose-symmetric scheme55 was performed on a Titan Krios transmission electron microscope equipped with a K3 camera (Gatan) using SerialEM 3.8 (ref. 56) with the following parameters: magnification 81,000x, pixel size 1.053 A, tilt range -60degrees to 60degrees with 3degrees increment, total dose 120-140 e- A-2.\nIn total, 356 native untreated, 65 Cm-treated, 86 PUM-treated and 70 Spc-treated cellular tomograms were analysed in this work. Details of cryo-EM data collection, refinement and validation statistics are provided in Supplementary Tables 1 and 3-6.",
#   "metadata_specification": "If the biological sample was taken from an organism, provide the scientific name of the organism. If the biological sample is not from an organism, return none.",
#   "metadata_name": "organism_name"
# }
# [chain/end] [1:chain:RunnableSequence > 2:prompt:PromptTemplate] s] Exiting Prompt run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "prompts",
#     "base",
#     "StringPromptValue"
#   ],
#   "kwargs": {
#     "text": "<s>[INST]\n                <<SYS>>You are an expert biological scientist trained in imaging and microscopy.<</SYS>>\n                Read the text of a section from the methods section of a research paper shown below (delimited with triple backticks).\nSection Text:- '''Cryo-ET sample preparation and data collection\nThe M. pneumoniae cultivation, sample preparation and data collection were described previously2. The three datasets of native untreated, Cm-treated and PUM-treated cells were re-processed in Warp and M 1.0.7 (the alpha versions that were officially released as v.1.0.9.)3,54. A small dataset of 15 tomograms acquired with Volta phase plate was processed with the denoising network in Warp 1.0.9 for visualization purposes only (as shown in Fig. 1a).\nA dataset of spectinomycin-treated cells was collected following the same procedure as before2. In brief, spectinomycin (Sigma-Aldrich) at a final concentration of 0.4 mg ml-1 was added into the culture medium, 15-20 min before plunge-freezing. Tilt-series collection with the dose-symmetric scheme55 was performed on a Titan Krios transmission electron microscope equipped with a K3 camera (Gatan) using SerialEM 3.8 (ref. 56) with the following parameters: magnification 81,000x, pixel size 1.053 A, tilt range -60degrees to 60degrees with 3degrees increment, total dose 120-140 e- A-2.\nIn total, 356 native untreated, 65 Cm-treated, 86 PUM-treated and 70 Spc-treated cellular tomograms were analysed in this work. Details of cryo-EM data collection, refinement and validation statistics are provided in Supplementary Tables 1 and 3-6.'''\nExtract the metadata from the section text based only on the specification delineated by square brackets and record the answer in the 'metadata_value' field of the output. Do not extract any other metadata.\n[If the biological sample was taken from an organism, provide the scientific name of the organism. If the biological sample is not from an organism, return none.]\nRecord the term 'organism_name' in the 'metadata_name' field of the output.\nGenerate only JSON formatted output with three fields 'metadata_name', 'metadata_value' and 'orginal_text'. Do not provide additional explanation or context for the answer.\nIf the metadata is not present in the text, record a value of 'not present' in the 'metadata_value' field of the output. Do not include any other response other than a JSON object.\nFinally, if you found the metadata in the text, record the original text of the sentence where the metadata specification was extracted from in the 'original_text' field of the output.\nIf you did not find the specified metadata in the text, record 'not present' in the 'original_text' field of the output.\nRemember, only generate JSON formatted output without any additional text or explanation.\n                [/INST]</s>"
#   }
# }
# [llm/start] [1:chain:RunnableSequence > 3:llm:LlamaCpp] Entering LLM run with input:
# {
#   "prompts": [
#     "<s>[INST]\n                <<SYS>>You are an expert biological scientist trained in imaging and microscopy.<</SYS>>\n                Read the text of a section from the methods section of a research paper shown below (delimited with triple backticks).\nSection Text:- '''Cryo-ET sample preparation and data collection\nThe M. pneumoniae cultivation, sample preparation and data collection were described previously2. The three datasets of native untreated, Cm-treated and PUM-treated cells were re-processed in Warp and M 1.0.7 (the alpha versions that were officially released as v.1.0.9.)3,54. A small dataset of 15 tomograms acquired with Volta phase plate was processed with the denoising network in Warp 1.0.9 for visualization purposes only (as shown in Fig. 1a).\nA dataset of spectinomycin-treated cells was collected following the same procedure as before2. In brief, spectinomycin (Sigma-Aldrich) at a final concentration of 0.4 mg ml-1 was added into the culture medium, 15-20 min before plunge-freezing. Tilt-series collection with the dose-symmetric scheme55 was performed on a Titan Krios transmission electron microscope equipped with a K3 camera (Gatan) using SerialEM 3.8 (ref. 56) with the following parameters: magnification 81,000x, pixel size 1.053 A, tilt range -60degrees to 60degrees with 3degrees increment, total dose 120-140 e- A-2.\nIn total, 356 native untreated, 65 Cm-treated, 86 PUM-treated and 70 Spc-treated cellular tomograms were analysed in this work. Details of cryo-EM data collection, refinement and validation statistics are provided in Supplementary Tables 1 and 3-6.'''\nExtract the metadata from the section text based only on the specification delineated by square brackets and record the answer in the 'metadata_value' field of the output. Do not extract any other metadata.\n[If the biological sample was taken from an organism, provide the scientific name of the organism. If the biological sample is not from an organism, return none.]\nRecord the term 'organism_name' in the 'metadata_name' field of the output.\nGenerate only JSON formatted output with three fields 'metadata_name', 'metadata_value' and 'orginal_text'. Do not provide additional explanation or context for the answer.\nIf the metadata is not present in the text, record a value of 'not present' in the 'metadata_value' field of the output. Do not include any other response other than a JSON object.\nFinally, if you found the metadata in the text, record the original text of the sentence where the metadata specification was extracted from in the 'original_text' field of the output.\nIf you did not find the specified metadata in the text, record 'not present' in the 'original_text' field of the output.\nRemember, only generate JSON formatted output without any additional text or explanation.\n                [/INST]</s>"
#   ]
# }
# llama_print_timings:        load time = 10455.37 ms
# llama_print_timings:      sample time =    41.15 ms /    57 runs   (    0.72 ms per token,  1385.08 tokens per second)
# llama_print_timings: prompt eval time = 14021.93 ms /   729 tokens (   19.23 ms per token,    51.99 tokens per second)
# llama_print_timings:        eval time = 10065.44 ms /    56 runs   (  179.74 ms per token,     5.56 tokens per second)
# llama_print_timings:       total time = 24199.13 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time = 10455.37 ms
# llama_print_timings:      sample time =    87.33 ms /   118 runs   (    0.74 ms per token,  1351.18 tokens per second)
# llama_print_timings: prompt eval time =  5086.36 ms /   233 tokens (   21.83 ms per token,    45.81 tokens per second)
# llama_print_timings:        eval time = 21194.94 ms /   117 runs   (  181.15 ms per token,     5.52 tokens per second)
# llama_print_timings:       total time = 26520.75 ms
# Llama.generate: prefix-match hit
# [llm/end] [1:chain:RunnableSequence > 3:llm:LlamaCpp] [26.52s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "  {\n\"metadata_name\": \"organism_name\",\n\"metadata_value\": \"M. pneumoniae\",\n\"original_text\": \"The M. pneumoniae cultivation, sample preparation and data collection were described previously2.\"\n}\n\nExplanation:\n\nThe section text mentions the scientific name of the organism, M. pneumoniae, which is extracted as the metadata value for the field \"organism_name\". The original text sentence where this metadata was found is also recorded in the output.",
#         "generation_info": null,
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [chain/start] [1:chain:RunnableSequence > 4:parser:JsonEnclosedByTextOutputParser] Entering Parser run with input:
# {
#   "input": "  {\n\"metadata_name\": \"organism_name\",\n\"metadata_value\": \"M. pneumoniae\",\n\"original_text\": \"The M. pneumoniae cultivation, sample preparation and data collection were described previously2.\"\n}\n\nExplanation:\n\nThe section text mentions the scientific name of the organism, M. pneumoniae, which is extracted as the metadata value for the field \"organism_name\". The original text sentence where this metadata was found is also recorded in the output."
# }
# [chain/end] [1:chain:RunnableSequence > 4:parser:JsonEnclosedByTextOutputParser] s] Exiting Parser run with output:
# {
#   "metadata_name": "organism_name",
#   "metadata_value": "M. pneumoniae",
#   "original_text": "The M. pneumoniae cultivation, sample preparation and data collection were described previously2."
# }
# [chain/end] [1:chain:RunnableSequence] [26.52s] Exiting Chain run with output:
# {
#   "metadata_name": "organism_name",
#   "metadata_value": "M. pneumoniae",
#   "original_text": "The M. pneumoniae cultivation, sample preparation and data collection were described previously2."
# }
# 	cell_strain
# [chain/start] [1:chain:RunnableSequence] Entering Chain run with input:
# {
#   "section_text": "Cryo-ET sample preparation and data collection\nThe M. pneumoniae cultivation, sample preparation and data collection were described previously2. The three datasets of native untreated, Cm-treated and PUM-treated cells were re-processed in Warp and M 1.0.7 (the alpha versions that were officially released as v.1.0.9.)3,54. A small dataset of 15 tomograms acquired with Volta phase plate was processed with the denoising network in Warp 1.0.9 for visualization purposes only (as shown in Fig. 1a).\nA dataset of spectinomycin-treated cells was collected following the same procedure as before2. In brief, spectinomycin (Sigma-Aldrich) at a final concentration of 0.4 mg ml-1 was added into the culture medium, 15-20 min before plunge-freezing. Tilt-series collection with the dose-symmetric scheme55 was performed on a Titan Krios transmission electron microscope equipped with a K3 camera (Gatan) using SerialEM 3.8 (ref. 56) with the following parameters: magnification 81,000x, pixel size 1.053 A, tilt range -60degrees to 60degrees with 3degrees increment, total dose 120-140 e- A-2.\nIn total, 356 native untreated, 65 Cm-treated, 86 PUM-treated and 70 Spc-treated cellular tomograms were analysed in this work. Details of cryo-EM data collection, refinement and validation statistics are provided in Supplementary Tables 1 and 3-6.",
#   "metadata_specification": "If the biological sample described in the text is a cell or cell culture, what was the strain?",
#   "metadata_name": "cell_strain"
# }
# [chain/start] [1:chain:RunnableSequence > 2:prompt:PromptTemplate] Entering Prompt run with input:
# {
#   "section_text": "Cryo-ET sample preparation and data collection\nThe M. pneumoniae cultivation, sample preparation and data collection were described previously2. The three datasets of native untreated, Cm-treated and PUM-treated cells were re-processed in Warp and M 1.0.7 (the alpha versions that were officially released as v.1.0.9.)3,54. A small dataset of 15 tomograms acquired with Volta phase plate was processed with the denoising network in Warp 1.0.9 for visualization purposes only (as shown in Fig. 1a).\nA dataset of spectinomycin-treated cells was collected following the same procedure as before2. In brief, spectinomycin (Sigma-Aldrich) at a final concentration of 0.4 mg ml-1 was added into the culture medium, 15-20 min before plunge-freezing. Tilt-series collection with the dose-symmetric scheme55 was performed on a Titan Krios transmission electron microscope equipped with a K3 camera (Gatan) using SerialEM 3.8 (ref. 56) with the following parameters: magnification 81,000x, pixel size 1.053 A, tilt range -60degrees to 60degrees with 3degrees increment, total dose 120-140 e- A-2.\nIn total, 356 native untreated, 65 Cm-treated, 86 PUM-treated and 70 Spc-treated cellular tomograms were analysed in this work. Details of cryo-EM data collection, refinement and validation statistics are provided in Supplementary Tables 1 and 3-6.",
#   "metadata_specification": "If the biological sample described in the text is a cell or cell culture, what was the strain?",
#   "metadata_name": "cell_strain"
# }
# [chain/end] [1:chain:RunnableSequence > 2:prompt:PromptTemplate] s] Exiting Prompt run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "prompts",
#     "base",
#     "StringPromptValue"
#   ],
#   "kwargs": {
#     "text": "<s>[INST]\n                <<SYS>>You are an expert biological scientist trained in imaging and microscopy.<</SYS>>\n                Read the text of a section from the methods section of a research paper shown below (delimited with triple backticks).\nSection Text:- '''Cryo-ET sample preparation and data collection\nThe M. pneumoniae cultivation, sample preparation and data collection were described previously2. The three datasets of native untreated, Cm-treated and PUM-treated cells were re-processed in Warp and M 1.0.7 (the alpha versions that were officially released as v.1.0.9.)3,54. A small dataset of 15 tomograms acquired with Volta phase plate was processed with the denoising network in Warp 1.0.9 for visualization purposes only (as shown in Fig. 1a).\nA dataset of spectinomycin-treated cells was collected following the same procedure as before2. In brief, spectinomycin (Sigma-Aldrich) at a final concentration of 0.4 mg ml-1 was added into the culture medium, 15-20 min before plunge-freezing. Tilt-series collection with the dose-symmetric scheme55 was performed on a Titan Krios transmission electron microscope equipped with a K3 camera (Gatan) using SerialEM 3.8 (ref. 56) with the following parameters: magnification 81,000x, pixel size 1.053 A, tilt range -60degrees to 60degrees with 3degrees increment, total dose 120-140 e- A-2.\nIn total, 356 native untreated, 65 Cm-treated, 86 PUM-treated and 70 Spc-treated cellular tomograms were analysed in this work. Details of cryo-EM data collection, refinement and validation statistics are provided in Supplementary Tables 1 and 3-6.'''\nExtract the metadata from the section text based only on the specification delineated by square brackets and record the answer in the 'metadata_value' field of the output. Do not extract any other metadata.\n[If the biological sample described in the text is a cell or cell culture, what was the strain?]\nRecord the term 'cell_strain' in the 'metadata_name' field of the output.\nGenerate only JSON formatted output with three fields 'metadata_name', 'metadata_value' and 'orginal_text'. Do not provide additional explanation or context for the answer.\nIf the metadata is not present in the text, record a value of 'not present' in the 'metadata_value' field of the output. Do not include any other response other than a JSON object.\nFinally, if you found the metadata in the text, record the original text of the sentence where the metadata specification was extracted from in the 'original_text' field of the output.\nIf you did not find the specified metadata in the text, record 'not present' in the 'original_text' field of the output.\nRemember, only generate JSON formatted output without any additional text or explanation.\n                [/INST]</s>"
#   }
# }
# [llm/start] [1:chain:RunnableSequence > 3:llm:LlamaCpp] Entering LLM run with input:
# {
#   "prompts": [
#     "<s>[INST]\n                <<SYS>>You are an expert biological scientist trained in imaging and microscopy.<</SYS>>\n                Read the text of a section from the methods section of a research paper shown below (delimited with triple backticks).\nSection Text:- '''Cryo-ET sample preparation and data collection\nThe M. pneumoniae cultivation, sample preparation and data collection were described previously2. The three datasets of native untreated, Cm-treated and PUM-treated cells were re-processed in Warp and M 1.0.7 (the alpha versions that were officially released as v.1.0.9.)3,54. A small dataset of 15 tomograms acquired with Volta phase plate was processed with the denoising network in Warp 1.0.9 for visualization purposes only (as shown in Fig. 1a).\nA dataset of spectinomycin-treated cells was collected following the same procedure as before2. In brief, spectinomycin (Sigma-Aldrich) at a final concentration of 0.4 mg ml-1 was added into the culture medium, 15-20 min before plunge-freezing. Tilt-series collection with the dose-symmetric scheme55 was performed on a Titan Krios transmission electron microscope equipped with a K3 camera (Gatan) using SerialEM 3.8 (ref. 56) with the following parameters: magnification 81,000x, pixel size 1.053 A, tilt range -60degrees to 60degrees with 3degrees increment, total dose 120-140 e- A-2.\nIn total, 356 native untreated, 65 Cm-treated, 86 PUM-treated and 70 Spc-treated cellular tomograms were analysed in this work. Details of cryo-EM data collection, refinement and validation statistics are provided in Supplementary Tables 1 and 3-6.'''\nExtract the metadata from the section text based only on the specification delineated by square brackets and record the answer in the 'metadata_value' field of the output. Do not extract any other metadata.\n[If the biological sample described in the text is a cell or cell culture, what was the strain?]\nRecord the term 'cell_strain' in the 'metadata_name' field of the output.\nGenerate only JSON formatted output with three fields 'metadata_name', 'metadata_value' and 'orginal_text'. Do not provide additional explanation or context for the answer.\nIf the metadata is not present in the text, record a value of 'not present' in the 'metadata_value' field of the output. Do not include any other response other than a JSON object.\nFinally, if you found the metadata in the text, record the original text of the sentence where the metadata specification was extracted from in the 'original_text' field of the output.\nIf you did not find the specified metadata in the text, record 'not present' in the 'original_text' field of the output.\nRemember, only generate JSON formatted output without any additional text or explanation.\n                [/INST]</s>"
#   ]
# }
# llama_print_timings:        load time = 10455.37 ms
# llama_print_timings:      sample time =    42.73 ms /    59 runs   (    0.72 ms per token,  1380.67 tokens per second)
# llama_print_timings: prompt eval time =  4320.77 ms /   215 tokens (   20.10 ms per token,    49.76 tokens per second)
# llama_print_timings:        eval time = 10396.52 ms /    58 runs   (  179.25 ms per token,     5.58 tokens per second)
# llama_print_timings:       total time = 14832.72 ms
# Llama.generate: prefix-match hit
# [llm/end] [1:chain:RunnableSequence > 3:llm:LlamaCpp] [14.83s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "  {\n\"metadata_name\": \"cell_strain\",\n\"metadata_value\": \"M. pneumoniae\",\n\"original_text\": \"The M. pneumoniae cultivation, sample preparation and data collection were described previously2.\"\n}",
#         "generation_info": null,
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [chain/start] [1:chain:RunnableSequence > 4:parser:JsonEnclosedByTextOutputParser] Entering Parser run with input:
# {
#   "input": "  {\n\"metadata_name\": \"cell_strain\",\n\"metadata_value\": \"M. pneumoniae\",\n\"original_text\": \"The M. pneumoniae cultivation, sample preparation and data collection were described previously2.\"\n}"
# }
# [chain/end] [1:chain:RunnableSequence > 4:parser:JsonEnclosedByTextOutputParser] s] Exiting Parser run with output:
# {
#   "metadata_name": "cell_strain",
#   "metadata_value": "M. pneumoniae",
#   "original_text": "The M. pneumoniae cultivation, sample preparation and data collection were described previously2."
# }
# [chain/end] [1:chain:RunnableSequence] [14.84s] Exiting Chain run with output:
# {
#   "metadata_name": "cell_strain",
#   "metadata_value": "M. pneumoniae",
#   "original_text": "The M. pneumoniae cultivation, sample preparation and data collection were described previously2."
# }
# 	sample_preparation
# [chain/start] [1:chain:RunnableSequence] Entering Chain run with input:
# {
# ...
# {
#   "metadata_name": "tilt_minimum",
#   "metadata_value": "not present",
#   "original_text": "Any methods, additional references, Nature Research reporting summaries, source data, extended data, supplementary information, acknowledgements, peer review information; details of author contributions and competing interests; and statements of data and code availability are available at 10.1038/s41586-022-05255-2."
# }
# 	tilt_maximum
# [chain/start] [1:chain:RunnableSequence] Entering Chain run with input:
# {
#   "section_text": "Online content\nAny methods, additional references, Nature Research reporting summaries, source data, extended data, supplementary information, acknowledgements, peer review information; details of author contributions and competing interests; and statements of data and code availability are available at 10.1038/s41586-022-05255-2.",
#   "metadata_specification": "What was the maximum angle used in the tilt-series?",
#   "metadata_name": "tilt_maximum"
# }
# [chain/start] [1:chain:RunnableSequence > 2:prompt:PromptTemplate] Entering Prompt run with input:
# {
#   "section_text": "Online content\nAny methods, additional references, Nature Research reporting summaries, source data, extended data, supplementary information, acknowledgements, peer review information; details of author contributions and competing interests; and statements of data and code availability are available at 10.1038/s41586-022-05255-2.",
#   "metadata_specification": "What was the maximum angle used in the tilt-series?",
#   "metadata_name": "tilt_maximum"
# }
# [chain/end] [1:chain:RunnableSequence > 2:prompt:PromptTemplate] s] Exiting Prompt run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "prompts",
#     "base",
#     "StringPromptValue"
#   ],
#   "kwargs": {
#     "text": "<s>[INST]\n                <<SYS>>You are an expert biological scientist trained in imaging and microscopy.<</SYS>>\n                Read the text of a section from the methods section of a research paper shown below (delimited with triple backticks).\nSection Text:- '''Online content\nAny methods, additional references, Nature Research reporting summaries, source data, extended data, supplementary information, acknowledgements, peer review information; details of author contributions and competing interests; and statements of data and code availability are available at 10.1038/s41586-022-05255-2.'''\nExtract the metadata from the section text based only on the specification delineated by square brackets and record the answer in the 'metadata_value' field of the output. Do not extract any other metadata.\n[What was the maximum angle used in the tilt-series?]\nRecord the term 'tilt_maximum' in the 'metadata_name' field of the output.\nGenerate only JSON formatted output with three fields 'metadata_name', 'metadata_value' and 'orginal_text'. Do not provide additional explanation or context for the answer.\nIf the metadata is not present in the text, record a value of 'not present' in the 'metadata_value' field of the output. Do not include any other response other than a JSON object.\nFinally, if you found the metadata in the text, record the original text of the sentence where the metadata specification was extracted from in the 'original_text' field of the output.\nIf you did not find the specified metadata in the text, record 'not present' in the 'original_text' field of the output.\nRemember, only generate JSON formatted output without any additional text or explanation.\n                [/INST]</s>"
#   }
# }
# [llm/start] [1:chain:RunnableSequence > 3:llm:LlamaCpp] Entering LLM run with input:
# {
#   "prompts": [
#     "<s>[INST]\n                <<SYS>>You are an expert biological scientist trained in imaging and microscopy.<</SYS>>\n                Read the text of a section from the methods section of a research paper shown below (delimited with triple backticks).\nSection Text:- '''Online content\nAny methods, additional references, Nature Research reporting summaries, source data, extended data, supplementary information, acknowledgements, peer review information; details of author contributions and competing interests; and statements of data and code availability are available at 10.1038/s41586-022-05255-2.'''\nExtract the metadata from the section text based only on the specification delineated by square brackets and record the answer in the 'metadata_value' field of the output. Do not extract any other metadata.\n[What was the maximum angle used in the tilt-series?]\nRecord the term 'tilt_maximum' in the 'metadata_name' field of the output.\nGenerate only JSON formatted output with three fields 'metadata_name', 'metadata_value' and 'orginal_text'. Do not provide additional explanation or context for the answer.\nIf the metadata is not present in the text, record a value of 'not present' in the 'metadata_value' field of the output. Do not include any other response other than a JSON object.\nFinally, if you found the metadata in the text, record the original text of the sentence where the metadata specification was extracted from in the 'original_text' field of the output.\nIf you did not find the specified metadata in the text, record 'not present' in the 'original_text' field of the output.\nRemember, only generate JSON formatted output without any additional text or explanation.\n                [/INST]</s>"
#   ]
# }
# llama_print_timings:        load time = 10455.37 ms
# llama_print_timings:      sample time =    83.07 ms /   114 runs   (    0.73 ms per token,  1372.35 tokens per second)
# llama_print_timings: prompt eval time =  4760.12 ms /   209 tokens (   22.78 ms per token,    43.91 tokens per second)
# llama_print_timings:        eval time = 22545.53 ms /   113 runs   (  199.52 ms per token,     5.01 tokens per second)
# llama_print_timings:       total time = 27528.74 ms
# Llama.generate: prefix-match hit
# [llm/end] [1:chain:RunnableSequence > 3:llm:LlamaCpp] [27.53s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "  {\n\"metadata_name\": \"tilt_maximum\",\n\"metadata_value\": \"not present\",\n\"original_text\": \"Any methods, additional references, Nature Research reporting summaries, source data, extended data, supplementary information, acknowledgements, peer review information; details of author contributions and competing interests; and statements of data and code availability are available at 10.1038/s41586-022-05255-2.\"\n}",
#         "generation_info": null,
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [chain/start] [1:chain:RunnableSequence > 4:parser:JsonEnclosedByTextOutputParser] Entering Parser run with input:
# {
#   "input": "  {\n\"metadata_name\": \"tilt_maximum\",\n\"metadata_value\": \"not present\",\n\"original_text\": \"Any methods, additional references, Nature Research reporting summaries, source data, extended data, supplementary information, acknowledgements, peer review information; details of author contributions and competing interests; and statements of data and code availability are available at 10.1038/s41586-022-05255-2.\"\n}"
# }
# [chain/end] [1:chain:RunnableSequence > 4:parser:JsonEnclosedByTextOutputParser] s] Exiting Parser run with output:
# {
#   "metadata_name": "tilt_maximum",
#   "metadata_value": "not present",
#   "original_text": "Any methods, additional references, Nature Research reporting summaries, source data, extended data, supplementary information, acknowledgements, peer review information; details of author contributions and competing interests; and statements of data and code availability are available at 10.1038/s41586-022-05255-2."
# }
# [chain/end] [1:chain:RunnableSequence] [27.53s] Exiting Chain run with output:
# {
#   "metadata_name": "tilt_maximum",
#   "metadata_value": "not present",
#   "original_text": "Any methods, additional references, Nature Research reporting summaries, source data, extended data, supplementary information, acknowledgements, peer review information; details of author contributions and competing interests; and statements of data and code availability are available at 10.1038/s41586-022-05255-2."
# }
# 	total_flux
# [chain/start] [1:chain:RunnableSequence] Entering Chain run with input:
# {
#   "section_text": "Online content\nAny methods, additional references, Nature Research reporting summaries, source data, extended data, supplementary information, acknowledgements, peer review information; details of author contributions and competing interests; and statements of data and code availability are available at 10.1038/s41586-022-05255-2.",
#   "metadata_specification": "What was the total flux or total exposure dose?",
#   "metadata_name": "total_flux"
# }
# [chain/start] [1:chain:RunnableSequence > 2:prompt:PromptTemplate] Entering Prompt run with input:
# {
#   "section_text": "Online content\nAny methods, additional references, Nature Research reporting summaries, source data, extended data, supplementary information, acknowledgements, peer review information; details of author contributions and competing interests; and statements of data and code availability are available at 10.1038/s41586-022-05255-2.",
#   "metadata_specification": "What was the total flux or total exposure dose?",
#   "metadata_name": "total_flux"
# }
# [chain/end] [1:chain:RunnableSequence > 2:prompt:PromptTemplate] s] Exiting Prompt run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "prompts",
#     "base",
#     "StringPromptValue"
#   ],
#   "kwargs": {
#     "text": "<s>[INST]\n                <<SYS>>You are an expert biological scientist trained in imaging and microscopy.<</SYS>>\n                Read the text of a section from the methods section of a research paper shown below (delimited with triple backticks).\nSection Text:- '''Online content\nAny methods, additional references, Nature Research reporting summaries, source data, extended data, supplementary information, acknowledgements, peer review information; details of author contributions and competing interests; and statements of data and code availability are available at 10.1038/s41586-022-05255-2.'''\nExtract the metadata from the section text based only on the specification delineated by square brackets and record the answer in the 'metadata_value' field of the output. Do not extract any other metadata.\n[What was the total flux or total exposure dose?]\nRecord the term 'total_flux' in the 'metadata_name' field of the output.\nGenerate only JSON formatted output with three fields 'metadata_name', 'metadata_value' and 'orginal_text'. Do not provide additional explanation or context for the answer.\nIf the metadata is not present in the text, record a value of 'not present' in the 'metadata_value' field of the output. Do not include any other response other than a JSON object.\nFinally, if you found the metadata in the text, record the original text of the sentence where the metadata specification was extracted from in the 'original_text' field of the output.\nIf you did not find the specified metadata in the text, record 'not present' in the 'original_text' field of the output.\nRemember, only generate JSON formatted output without any additional text or explanation.\n                [/INST]</s>"
#   }
# }
# [llm/start] [1:chain:RunnableSequence > 3:llm:LlamaCpp] Entering LLM run with input:
# {
#   "prompts": [
#     "<s>[INST]\n                <<SYS>>You are an expert biological scientist trained in imaging and microscopy.<</SYS>>\n                Read the text of a section from the methods section of a research paper shown below (delimited with triple backticks).\nSection Text:- '''Online content\nAny methods, additional references, Nature Research reporting summaries, source data, extended data, supplementary information, acknowledgements, peer review information; details of author contributions and competing interests; and statements of data and code availability are available at 10.1038/s41586-022-05255-2.'''\nExtract the metadata from the section text based only on the specification delineated by square brackets and record the answer in the 'metadata_value' field of the output. Do not extract any other metadata.\n[What was the total flux or total exposure dose?]\nRecord the term 'total_flux' in the 'metadata_name' field of the output.\nGenerate only JSON formatted output with three fields 'metadata_name', 'metadata_value' and 'orginal_text'. Do not provide additional explanation or context for the answer.\nIf the metadata is not present in the text, record a value of 'not present' in the 'metadata_value' field of the output. Do not include any other response other than a JSON object.\nFinally, if you found the metadata in the text, record the original text of the sentence where the metadata specification was extracted from in the 'original_text' field of the output.\nIf you did not find the specified metadata in the text, record 'not present' in the 'original_text' field of the output.\nRemember, only generate JSON formatted output without any additional text or explanation.\n                [/INST]</s>"
#   ]
# }
# [llm/end] [1:chain:RunnableSequence > 3:llm:LlamaCpp] [27.46s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "  {\n\"metadata_name\": \"total_flux\",\n\"metadata_value\": \"not present\",\n\"original_text\": \"Any methods, additional references, Nature Research reporting summaries, source data, extended data, supplementary information, acknowledgements, peer review information; details of author contributions and competing interests; and statements of data and code availability are available at 10.1038/s41586-022-05255-2.\"\n}",
#         "generation_info": null,
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [chain/start] [1:chain:RunnableSequence > 4:parser:JsonEnclosedByTextOutputParser] Entering Parser run with input:
# {
#   "input": "  {\n\"metadata_name\": \"total_flux\",\n\"metadata_value\": \"not present\",\n\"original_text\": \"Any methods, additional references, Nature Research reporting summaries, source data, extended data, supplementary information, acknowledgements, peer review information; details of author contributions and competing interests; and statements of data and code availability are available at 10.1038/s41586-022-05255-2.\"\n}"
# }
# [chain/end] [1:chain:RunnableSequence > 4:parser:JsonEnclosedByTextOutputParser] s] Exiting Parser run with output:
# {
#   "metadata_name": "total_flux",
#   "metadata_value": "not present",
#   "original_text": "Any methods, additional references, Nature Research reporting summaries, source data, extended data, supplementary information, acknowledgements, peer review information; details of author contributions and competing interests; and statements of data and code availability are available at 10.1038/s41586-022-05255-2."
# }
# [chain/end] [1:chain:RunnableSequence] [27.46s] Exiting Chain run with output:
# {
#   "metadata_name": "total_flux",
#   "metadata_value": "not present",
#   "original_text": "Any methods, additional references, Nature Research reporting summaries, source data, extended data, supplementary information, acknowledgements, peer review information; details of author contributions and competing interests; and statements of data and code availability are available at 10.1038/s41586-022-05255-2."
# }
# 	reconstruction_software
# 	tomogram_size
# 	reconstruction_method
# 	annotated_entities
# 	annotation_methods
# 	annotated_software
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# llama_print_timings:        load time = 10455.37 ms
# llama_print_timings:      sample time =    81.34 ms /   113 runs   (    0.72 ms per token,  1389.30 tokens per second)
# llama_print_timings: prompt eval time =  4816.11 ms /   207 tokens (   23.27 ms per token,    42.98 tokens per second)
# llama_print_timings:        eval time = 22419.14 ms /   112 runs   (  200.17 ms per token,     5.00 tokens per second)
# llama_print_timings:       total time = 27454.80 ms

# %%
path = db.loc+db.name+'/extractions/'
if not os.path.exists(path+p.doi):
    os.makedirs(path+p.doi)

# %%
extractions_df = pd.DataFrame(extractions)
fls = []
for i, row in extractions_df.iterrows():
    text = d.text[row.offset:row.offset+row.length]
    fls.append(text.split('\n')[0])
extractions_df['first_line'] = fls

# %%
extractions_pivot = extractions_df.pivot(index='metadata_name', columns=['offset', 'first_line'], values='metadata_value').fillna('')
extractions_pivot
# Out:
# offset                                                               29126  \
# first_line                  Cryo-ET sample preparation and data collection
# metadata_name
# biological_sample_type                                        cell culture
# camera_manufacturer
# camera_model
# cell_strain                                                  M. pneumoniae
# cryoet_acceleration_voltage
# cryoet_pixel_spacing
# microscope_name
# microscope_setup
# organism_name                                                M. pneumoniae
# reconstruction_method
# reconstruction_software
# tilt_maximum
# tilt_minimum
# tomogram_size
# total_flux
#
# offset                                                                                30464  \
# first_line                  Image processing, ribosome template matching and map refinement
# metadata_name
# biological_sample_type
# camera_manufacturer
# camera_model
# cell_strain
# cryoet_acceleration_voltage
# cryoet_pixel_spacing
# microscope_name
# microscope_setup
# organism_name
# reconstruction_method               Warp 1.0.9, PyTom57, RELION 3.0, M v.1.0.9
# reconstruction_software             Warp 1.0.9, PyTom57, RELION 3.0, M v.1.0.9
# tilt_maximum
# tilt_minimum
# tomogram_size                109,990 untreated, 21,299 Cm-treated, 23,014 P...
# total_flux
#
# offset                                                                       31773  \
# first_line                  Atomic model building in high-resolution ribosome maps
# metadata_name
# biological_sample_type
# camera_manufacturer
# camera_model
# cell_strain
# cryoet_acceleration_voltage
# cryoet_pixel_spacing
# microscope_name
# microscope_setup
# organism_name
# reconstruction_method        PHENIX real-space refinement, manual adjustmen...
# reconstruction_software      Chimera63, PHENIX real-space refinement64, Coo...
# tilt_maximum
# tilt_minimum
# tomogram_size
# total_flux
#
# offset                                                                                   40161  \
# first_line                  Sub-tomogram classification of the translation states of ribosomes
# metadata_name
# biological_sample_type
# camera_manufacturer
# camera_model
# cell_strain
# cryoet_acceleration_voltage
# cryoet_pixel_spacing
# microscope_name
# microscope_setup
# organism_name
# reconstruction_method
# reconstruction_software                                             RELION 3.0
# tilt_maximum
# tilt_minimum
# tomogram_size                                                      not present
# total_flux
#
# offset                                                                                 44275  \
# first_line                  Model building and comparison of the ribosome translation states
# metadata_name
# biological_sample_type
# camera_manufacturer
# camera_model
# cell_strain
# cryoet_acceleration_voltage
# cryoet_pixel_spacing
# microscope_name
# microscope_setup
# organism_name
# reconstruction_method        rigid-body-fitting and flexible fitting using ...
# reconstruction_software                            Chimera and Namdinator77-79
# tilt_maximum
# tilt_minimum
# tomogram_size
# total_flux
#
# offset                                                            46124  \
# first_line                  Spatial analysis of ribosomes and polysomes
# metadata_name
# biological_sample_type
# camera_manufacturer
# camera_model
# cell_strain
# cryoet_acceleration_voltage
# cryoet_pixel_spacing
# microscope_name
# microscope_setup
# organism_name
# reconstruction_method                                 RELION refinement
# reconstruction_software                               RELION refinement
# tilt_maximum
# tilt_minimum
# tomogram_size                        4 times binning (voxel size 6.8 A)
# total_flux
#
# offset                                                                                   49286  \
# first_line                  Statistical analysis of translation elongation states in polysomes
# metadata_name
# biological_sample_type
# camera_manufacturer
# camera_model
# cell_strain
# cryoet_acceleration_voltage
# cryoet_pixel_spacing
# microscope_name
# microscope_setup
# organism_name
# reconstruction_method                                              not present
# reconstruction_software                                           MATLAB 2019b
# tilt_maximum
# tilt_minimum
# tomogram_size                                                    356 tomograms
# total_flux
#
# offset                                                                   52519  \
# first_line                                     Single-cell clustering analysis
# metadata_name
# biological_sample_type
# camera_manufacturer
# camera_model
# cell_strain
# cryoet_acceleration_voltage
# cryoet_pixel_spacing
# microscope_name
# microscope_setup
# organism_name
# reconstruction_method        hierarchical clustering analysis using the clu...
# reconstruction_software                               Chimera63 and ChimeraX81
# tilt_maximum
# tilt_minimum
# tomogram_size                                                      not present
# total_flux
#
# offset                                  53382          53520
# first_line                  Reporting summary Online content
# metadata_name
# biological_sample_type
# camera_manufacturer               not present    not present
# camera_model                      not present    not present
# cell_strain
# cryoet_acceleration_voltage       not present    not present
# cryoet_pixel_spacing              not present    not present
# microscope_name                   not present    not present
# microscope_setup                  not present    not present
# organism_name
# reconstruction_method
# reconstruction_software
# tilt_maximum                      not present    not present
# tilt_minimum                      not present    not present
# tomogram_size
# total_flux                        not present    not present

# %%
extractions_pivot.to_csv(path+'/'+p.doi+'/extractions.tsv', sep='\t', index=True, header=True)

# %%
extractions_pivot2 = extractions_df.pivot(index='metadata_name', columns=['offset', 'first_line'], values='original_text').fillna('')
extractions_pivot2.to_csv(path+'/'+p.doi+'/original_text.tsv', sep='\t', index=True, header=True)

# %%
text1 = '{\n\"protocol_step\": E\n}'
text2 = re.sub(r':\s*([a-zA-Z0-9_]+)\s*[,\]\}]', r': "\1"', text1)
print(text2)
# Out:
# {
# "protocol_step": "E"

# %%
for i, row in df4.reset_index(drop=False).iterrows():
    print(i, row.OFFSET, row.PLAIN_TEXT)
    if row.LENGTH <= 50:
        continue
    if i < 11:
        continue
    s1 = {'section_text':row.PLAIN_TEXT }
    with suppress_stdout_stderr():
        out1 = protocol_step_id_chain.invoke(s1)
    if out1:
        protocol_step = out1.get('protocol_step', None)
    else:
        continue
    if protocol_step is None:
        raise Exception('No protocol step found')      
    print('\t'+protocol_step)  
    for spec in metadata_specs:
        print('\t'+spec.get('name'))
        if protocol_step not in spec.get('step') :
            continue
        s2 = {'section_text':row.PLAIN_TEXT, 'metadata_specification': spec.get('spec'), 'metadata_name': spec.get('name') }
        try:
            with suppress_stdout_stderr():
                out2 = extract_chain.invoke(s2)
        except OutputParserException as e:
            continue
        if out2 is not None:
            out2['p_id'] = i
            out2['offset'] = row.OFFSET
            out2['length'] = row.LENGTH
            extractions.append(out2)

# %%
import json
print(json.dumps(extractions, indent=4))
# Out:
# [
#     {
#         "metadata_name": "biological_sample_type",
#         "metadata_value": "cell culture",
#         "original_text": "S. pombe K972 Sp h- wild-type haploid cells were recovered from frozen stock by streaking on YES agar plates (YES Broth, Formedium, 20 g agarose per liter) and incubated at 30 degreesC for 1-3 days."
#     },
#     {
#         "metadata_name": "organism_name",
#         "metadata_value": "S. pombe K972 Sp h- wild-type haploid cells",
#         "original_text": "S. pombe K972 Sp h- wild-type haploid cells were recovered from frozen stock by streaking on YES agar plates (YES Broth, Formedium, 20 g agarose per liter) and incubated at 30 degreesC for 1-3 days."
#     },
#     {
#         "metadata_name": "cell_strain",
#         "metadata_value": "S. pombe K972 Sp h- wild-type haploid",
#         "original_text": "S. pombe K972 Sp h- wild-type haploid cells were recovered from frozen stock by streaking on YES agar plates (YES Broth, Formedium, 20 g agarose per liter) and incubated at 30 degreesC for 1-3 days."
#     },
#     {
#         "metadata_name": "sample_preparation",
#         "metadata_value": "log phase at an optical density at 600 nm of 0.5-0.6",
#         "original_text": "On the next day, cultures were grown to their log phase at an optical density at 600 nm of 0.5-0.6 and diluted beforehand in YES if necessary."
#     },
#     {
#         "metadata_name": "biological_sample_type",
#         "metadata_value": "cell culture",
#         "original_text": "Yeast cells were either diluted to optical density at 600 nm of 0.2-0.4 in YES medium or, following a wash step, in phosphate-buffered saline (PBS) containing 5% or 10% bovine serum albumin as external cryoprotectant."
#     },
#     {
#         "metadata_name": "organism_name",
#         "metadata_value": "Saccharomyces cerevisiae (baker's yeast)",
#         "original_text": "Yeast cells were either diluted to optical density at 600 nm of 0.2-0.4 in YES medium or, following a wash step, in phosphate-buffered saline (PBS) containing 5% or 10% bovine serum albumin as external cryoprotectant."
#     },
#     {
#         "metadata_name": "cell_strain",
#         "metadata_value": "not present",
#         "original_text": "Yeast cells were either diluted to optical density at 600 nm of 0.2-0.4 in YES medium or, following a wash step, in phosphate-buffered saline (PBS) containing 5% or 10% bovine serum albumin as external cryoprotectant."
#     },
#     {
#         "metadata_name": "sample_preparation",
#         "metadata_value": "Vitrification",
#         "original_text": "Yeast cells were either diluted to optical density at 600 nm of 0.2-0.4 in YES medium or, following a wash step, in phosphate-buffered saline (PBS) containing 5% or 10% bovine serum albumin as external cryoprotectant."
#     },
#     {
#         "metadata_name": "cryoet_pixel_spacing",
#         "metadata_value": "3.45 A",
#         "original_text": "A calibrated pixel size of 3.45 A was used for the NPC defocus* data and 3.37 A for the remaining datasets."
#     },
#     {
#         "metadata_name": "cryoet_acceleration_voltage",
#         "metadata_value": "not present",
#         "original_text": "Cryo-ET acquisition parameters are summarized in Supplementary Tables 7-9."
#     },
#     {
#         "metadata_name": "microscope_name",
#         "metadata_value": "Titan Krios",
#         "original_text": "Autogrids with lamellae were loaded into a Titan Krios (Thermo Fisher Scientific) such that the axis of the pre-tilt introduced by FIB milling was aligned perpendicular to the tilt axis of the microscope53."
#     },
#     {
#         "metadata_name": "cryoet_pixel_spacing",
#         "metadata_value": "not present",
#         "original_text": "Tomogram reconstruction\nTilt movie frames were aligned using a SerialEM plugin. Tilt series were filtered according to the accumulated electron dose by Fourier cropping using the mtffilter function in etomo (IMOD/BETA4.10.1258), and sorted by tilt angle using a python script. Four-times-binned tilt images were aligned in etomo (IMOD/4.9.4)58 using patch tracking (typical residual error 0.291-0.569 pixels) and tomograms were reconstructed via weighted back projection. Tomogram thicknesses ranged between 80-310 nm."
#     },
#     null,
#     {
#         "metadata_name": "microscope_name",
#         "metadata_value": "IMOD/BETA4.10.1258",
#         "original_text": "Tilt series were filtered according to the accumulated electron dose by Fourier cropping using the mtffilter function in etomo (IMOD/BETA4.10.1258), and sorted by tilt angle using a python script."
#     },
#     {
#         "metadata_name": "cryoet_pixel_spacing",
#         "metadata_value": "not present",
#         "original_text": "NPC manual localization\nNPCs were manually localized as described previously26. Coordinates and initial orientations of 354 NPCs were manually determined in 127 4x-binned, SIRT-like filtered58 defocus* tomograms57."
#     },
#     {
#         "metadata_name": "cryoet_acceleration_voltage",
#         "metadata_value": "not present",
#         "original_text": "NPC manual localization\nNPCs were manually localized as described previously26. Coordinates and initial orientations of 354 NPCs were manually determined in 127 4x-binned, SIRT-like filtered58 defocus* tomograms57. The annotated NPC data was divided on the basis of quality criteria: 38 tomograms of quality 1 have a thickness below 300 nm, and a tilt-series alignment residual error below 0.7 pixels. Quality 0 was assigned to 89 tomograms with 300-395 nm thickness and a residual error of 0.7-5.0 pixels for tilt-series alignments."
#     },
#     {
#         "metadata_name": "microscope_name",
#         "metadata_value": "SIRT-like filtered58 defocus* tomograms57",
#         "original_text": "NPCs were manually localized as described previously26. Coordinates and initial orientations of 354 NPCs were manually determined in 127 4x-binned, SIRT-like filtered58 defocus* tomograms57."
#     },
#     {
#         "metadata_name": "cryoet_pixel_spacing",
#         "metadata_value": "not present",
#         "original_text": "not present"
#     },
#     {
#         "metadata_name": "cryoet_acceleration_voltage",
#         "metadata_value": "not present",
#         "original_text": "Reporting summary\nFurther information on research design is available in the Nature Portfolio Reporting Summary linked to this article."
#     },
#     {
#         "metadata_name": "microscope_name",
#         "metadata_value": "not present",
#         "original_text": "Further information on research design is available in the Nature Portfolio Reporting Summary linked to this article."
#     },
#     {
#         "metadata_name": "cryoet_pixel_spacing",
#         "metadata_value": "not present",
#         "original_text": "Any methods, additional references, Nature Portfolio reporting summaries, source data, extended data, supplementary information, acknowledgements, peer review information; details of author contributions and competing interests; and statements of data and code availability are available at 10.1038/s41592-022-01746-2."
#     },
#     {
#         "metadata_name": "cryoet_acceleration_voltage",
#         "metadata_value": "not present",
#         "original_text": "Any methods, additional references, Nature Portfolio reporting summaries, source data, extended data, supplementary information, acknowledgements, peer review information; details of author contributions and competing interests; and statements of data and code availability are available at 10.1038/s41592-022-01746-2."
#     },
#     {
#         "metadata_name": "microscope_name",
#         "metadata_value": "not present",
#         "original_text": "Any methods, additional references, Nature Portfolio reporting summaries, source data, extended data, supplementary information, acknowledgements, peer review information; details of author contributions and competing interests; and statements of data and code availability are available at 10.1038/s41592-022-01746-2."
#     }
# ]

# %%
import json
print(json.dumps(out, indent=4))
# Out:
# {
#     "metadata_name": "biological_sample_type",
#     "metadata_value": "cell culture",
#     "original_text": "S. pombe K972 Sp h- wild-type haploid cells were recovered from frozen stock by streaking on YES agar plates (YES Broth, Formedium, 20 g agarose per liter) and incubated at 30 degreesC for 1-3 days."
# }

# %%
map_as_doc_chain.invoke({docs[0].page_content})

# %%
# The chain we'll repeatedly apply to collapse subsets of the documents
# into a consolidate document until the total token size of our
# documents is below some max size.
def format_docs(docs):
    return "\n\n".join(partial_format_document(doc) for doc in docs)

collapse_chain = (
    {"context": format_docs}
    | PromptTemplate.from_template("Collapse this content:\n\n{context}")
    | llm
    | StrOutputParser()
)

def get_num_tokens(docs):
    return llm.get_num_tokens(format_docs(docs))

def collapse(docs, config, token_max=1000,):
    collapse_ct = 1
    while get_num_tokens(docs) > token_max:
        config["run_name"] = f"Collapse {collapse_ct}"
        invoke = partial(collapse_chain.invoke, config=config)
        split_docs = split_list_of_docs(docs, get_num_tokens, token_max)
        docs = [collapse_docs(_docs, invoke) for _docs in split_docs]
        collapse_ct += 1
    return docs

# %%
# The chain we'll use to combine our individual document summaries
# (or summaries over subset of documents if we had to collapse the map results)
# into a final summary.

reduce_chain = (
    {"context": format_docs}
    | PromptTemplate.from_template("Combine these summaries:\n\n{context}")
    | llm
    | StrOutputParser()
).with_config(run_name="Reduce")

# The final full chain
map_reduce = (map_as_doc_chain.map() | collapse | reduce_chain).with_config(run_name="Map reduce")

# %%
from langchain.schema import Document

text = """Nuclear power in space is the use of nuclear power in outer space, typically either small fission systems or radioactive decay for electricity or heat. Another use is for scientific observation, as in a Mössbauer spectrometer. The most common type is a radioisotope thermoelectric generator, which has been used on many space probes and on crewed lunar missions. Small fission reactors for Earth observation satellites, such as the TOPAZ nuclear reactor, have also been flown.[1] A radioisotope heater unit is powered by radioactive decay and can keep components from becoming too cold to function, potentially over a span of decades.[2]

The United States tested the SNAP-10A nuclear reactor in space for 43 days in 1965,[3] with the next test of a nuclear reactor power system intended for space use occurring on 13 September 2012 with the Demonstration Using Flattop Fission (DUFF) test of the Kilopower reactor.[4]

After a ground-based test of the experimental 1965 Romashka reactor, which used uranium and direct thermoelectric conversion to electricity,[5] the USSR sent about 40 nuclear-electric satellites into space, mostly powered by the BES-5 reactor. The more powerful TOPAZ-II reactor produced 10 kilowatts of electricity.[3]

Examples of concepts that use nuclear power for space propulsion systems include the nuclear electric rocket (nuclear powered ion thruster(s)), the radioisotope rocket, and radioisotope electric propulsion (REP).[6] One of the more explored concepts is the nuclear thermal rocket, which was ground tested in the NERVA program. Nuclear pulse propulsion was the subject of Project Orion.[7]

Regulation and hazard prevention[edit]
After the ban of nuclear weapons in space by the Outer Space Treaty in 1967, nuclear power has been discussed at least since 1972 as a sensitive issue by states.[8] Particularly its potential hazards to Earth's environment and thus also humans has prompted states to adopt in the U.N. General Assembly the Principles Relevant to the Use of Nuclear Power Sources in Outer Space (1992), particularly introducing safety principles for launches and to manage their traffic.[8]

Benefits

Both the Viking 1 and Viking 2 landers used RTGs for power on the surface of Mars. (Viking launch vehicle pictured)
While solar power is much more commonly used, nuclear power can offer advantages in some areas. Solar cells, although efficient, can only supply energy to spacecraft in orbits where the solar flux is sufficiently high, such as low Earth orbit and interplanetary destinations close enough to the Sun. Unlike solar cells, nuclear power systems function independently of sunlight, which is necessary for deep space exploration. Nuclear-based systems can have less mass than solar cells of equivalent power, allowing more compact spacecraft that are easier to orient and direct in space. In the case of crewed spaceflight, nuclear power concepts that can power both life support and propulsion systems may reduce both cost and flight time.[9]

Selected applications and/or technologies for space include:

Radioisotope thermoelectric generator
Radioisotope heater unit
Radioisotope piezoelectric generator
Radioisotope rocket
Nuclear thermal rocket
Nuclear pulse propulsion
Nuclear electric rocket
"""

docs = [
    Document(
        page_content=split,
        metadata={"source": "https://en.wikipedia.org/wiki/Nuclear_power_in_space"},
    )
    for split in text.split("\n\n")
]
docs
# Out:
# [Document(page_content='Nuclear power in space is the use of nuclear power in outer space, typically either small fission systems or radioactive decay for electricity or heat. Another use is for scientific observation, as in a Mössbauer spectrometer. The most common type is a radioisotope thermoelectric generator, which has been used on many space probes and on crewed lunar missions. Small fission reactors for Earth observation satellites, such as the TOPAZ nuclear reactor, have also been flown.[1] A radioisotope heater unit is powered by radioactive decay and can keep components from becoming too cold to function, potentially over a span of decades.[2]', metadata={'source': 'https://en.wikipedia.org/wiki/Nuclear_power_in_space'}),
#  Document(page_content='The United States tested the SNAP-10A nuclear reactor in space for 43 days in 1965,[3] with the next test of a nuclear reactor power system intended for space use occurring on 13 September 2012 with the Demonstration Using Flattop Fission (DUFF) test of the Kilopower reactor.[4]', metadata={'source': 'https://en.wikipedia.org/wiki/Nuclear_power_in_space'}),
#  Document(page_content='After a ground-based test of the experimental 1965 Romashka reactor, which used uranium and direct thermoelectric conversion to electricity,[5] the USSR sent about 40 nuclear-electric satellites into space, mostly powered by the BES-5 reactor. The more powerful TOPAZ-II reactor produced 10 kilowatts of electricity.[3]', metadata={'source': 'https://en.wikipedia.org/wiki/Nuclear_power_in_space'}),
#  Document(page_content='Examples of concepts that use nuclear power for space propulsion systems include the nuclear electric rocket (nuclear powered ion thruster(s)), the radioisotope rocket, and radioisotope electric propulsion (REP).[6] One of the more explored concepts is the nuclear thermal rocket, which was ground tested in the NERVA program. Nuclear pulse propulsion was the subject of Project Orion.[7]', metadata={'source': 'https://en.wikipedia.org/wiki/Nuclear_power_in_space'}),
#  Document(page_content="Regulation and hazard prevention[edit]\nAfter the ban of nuclear weapons in space by the Outer Space Treaty in 1967, nuclear power has been discussed at least since 1972 as a sensitive issue by states.[8] Particularly its potential hazards to Earth's environment and thus also humans has prompted states to adopt in the U.N. General Assembly the Principles Relevant to the Use of Nuclear Power Sources in Outer Space (1992), particularly introducing safety principles for launches and to manage their traffic.[8]", metadata={'source': 'https://en.wikipedia.org/wiki/Nuclear_power_in_space'}),
#  Document(page_content='Benefits', metadata={'source': 'https://en.wikipedia.org/wiki/Nuclear_power_in_space'}),
#  Document(page_content='Both the Viking 1 and Viking 2 landers used RTGs for power on the surface of Mars. (Viking launch vehicle pictured)\nWhile solar power is much more commonly used, nuclear power can offer advantages in some areas. Solar cells, although efficient, can only supply energy to spacecraft in orbits where the solar flux is sufficiently high, such as low Earth orbit and interplanetary destinations close enough to the Sun. Unlike solar cells, nuclear power systems function independently of sunlight, which is necessary for deep space exploration. Nuclear-based systems can have less mass than solar cells of equivalent power, allowing more compact spacecraft that are easier to orient and direct in space. In the case of crewed spaceflight, nuclear power concepts that can power both life support and propulsion systems may reduce both cost and flight time.[9]', metadata={'source': 'https://en.wikipedia.org/wiki/Nuclear_power_in_space'}),
#  Document(page_content='Selected applications and/or technologies for space include:', metadata={'source': 'https://en.wikipedia.org/wiki/Nuclear_power_in_space'}),
#  Document(page_content='Radioisotope thermoelectric generator\nRadioisotope heater unit\nRadioisotope piezoelectric generator\nRadioisotope rocket\nNuclear thermal rocket\nNuclear pulse propulsion\nNuclear electric rocket\n', metadata={'source': 'https://en.wikipedia.org/wiki/Nuclear_power_in_space'})]

# %%
map_reduce.invoke(docs, config={"max_concurrency": 1})
# Out:
# Llama.generate: prefix-match hit
# The advantages of using nuclear power in space include:
#
# * Long-lasting energy source that does not require refueling
# * High energy density, which means smaller and lighter systems compared to other power sources
# * Ability to operate in extreme temperatures and radiation environments
# * Can be used for both electricity and heat
# * Can be used for propulsion, such as with a nuclear-powered ion thruster
#
# The disadvantages of using nuclear power in space include:
#
# * Safety concerns, including the risk of radioactive contamination and accidents
# * High cost of development and launch
# * Potential for misuse, such as using it for weapons
# * Requires specialized infrastructure and handling procedures
# * Can have negative public perception
#
# There are several challenges associated with using nuclear power in space, including:
#
# * Radiation protection for the crew and electronics
# * Heat rejection and temperature control
# * Launch and deployment
# * Operations and maintenance
# * Decommissioning and disposal
#
# The future of nuclear power in space is likely to involve the development of advanced reactor designs, such as fission or fusion reactors, that are
# llama_print_timings:        load time =  4949.59 ms
# llama_print_timings:      sample time =   189.82 ms /   256 runs   (    0.74 ms per token,  1348.65 tokens per second)
# llama_print_timings: prompt eval time =     0.00 ms /     1 tokens (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:        eval time = 48455.88 ms /   256 runs   (  189.28 ms per token,     5.28 tokens per second)
# llama_print_timings:       total time = 49102.73 ms
# Llama.generate: prefix-match hit
#  The DUFF test was conducted at the Nevada National Security Site's Device Assembly Facility, and it successfully demonstrated the ability to generate electricity from a fission reaction in space.
#
# The Kilopower reactor is designed to provide 1-10 kilowatts of power for space missions lasting several years, and it uses a combination of nuclear fission and radioisotope thermoelectric generators (RTGs) to generate electricity. The reactor is also designed to be scalable, allowing it to be used in a variety of different configurations depending on the specific mission requirements.
#
# The successful test of the Kilopower reactor represents a significant milestone for space nuclear power, as it demonstrates the feasibility of using fission reactors in space and paves the way for future missions that require a reliable source of power.
#
# In addition to the DUFF test, NASA is also planning to conduct further tests of the Kilopower reactor in the coming years, including a long-duration test on the International Space Station (ISS) and a lunar surface demonstration mission. These tests will help to further validate the performance and safety of the reactor, and
# llama_print_timings:        load time =  4949.59 ms
# llama_print_timings:      sample time =   186.46 ms /   256 runs   (    0.73 ms per token,  1372.94 tokens per second)
# llama_print_timings: prompt eval time =  1984.33 ms /    84 tokens (   23.62 ms per token,    42.33 tokens per second)
# llama_print_timings:        eval time = 49690.56 ms /   255 runs   (  194.86 ms per token,     5.13 tokens per second)
# llama_print_timings:       total time = 52310.30 ms
# Llama.generate: prefix-match hit
# The United States launched its first nuclear-powered satellite in 1962, the SNAP-10A, which used a radioisotope thermoelectric generator (RTG).[4] The RTG was powered by strontium-90 and produced 150 watts of electricity.
#
# The Soviet Union launched its first nuclear-powered satellite in 1963, the Kosmos 217, which used a BES-5 reactor to generate 10 kilowatts of electricity. The satellite was designed to test the feasibility of using nuclear reactors in space and to evaluate the effects of radiation on electronic equipment.
#
# The United States launched its first nuclear-powered satellite with a thermoelectric converter in 1965, the SNAP-19, which used a strontium-90 RTG to generate 300 watts of electricity. The satellite was designed to test the feasibility of using thermoelectric converters in space and to evaluate the effects of radiation on electronic equipment.
#
# In 1972, the Soviet Union launched the first nuclear
# llama_print_timings:        load time =  4949.59 ms
# llama_print_timings:      sample time =   189.49 ms /   256 runs   (    0.74 ms per token,  1350.98 tokens per second)
# llama_print_timings: prompt eval time =  1878.07 ms /    93 tokens (   20.19 ms per token,    49.52 tokens per second)
# llama_print_timings:        eval time = 45737.07 ms /   255 runs   (  179.36 ms per token,     5.58 tokens per second)
# llama_print_timings:       total time = 48257.15 ms
# Llama.generate: prefix-match hit
# The nuclear-electric rocket uses a nuclear reactor to generate electricity, which then powers an ion thruster. The radioisotope rocket instead uses the heat generated by the decay of radioactive isotopes to create thrust. In the case of REP, this heat is converted into electricity to power an electric thruster. The nuclear thermal rocket uses a nuclear reactor to heat a propellant, which then expands through a nozzle to generate thrust. Nuclear pulse propulsion would instead use nuclear explosions to generate thrust.[7]
#
# The advantages of using nuclear power for spacecraft propulsion include high specific impulse (a measure of the efficiency of a thruster), long-term operation, and high thrust-to-power ratios. The disadvantages include safety concerns, nuclear waste disposal issues, and high development costs.[6]
#
# The nuclear electric rocket has been proposed as a possible propulsion system for interplanetary missions, such as a manned mission to Mars. However, the development of such a system would require significant technological advancements and infrastructure investments. The radioisotope rocket and REP have also
# llama_print_timings:        load time =  4949.59 ms
# llama_print_timings:      sample time =   246.66 ms /   256 runs   (    0.96 ms per token,  1037.86 tokens per second)
# llama_print_timings: prompt eval time =  1839.90 ms /    96 tokens (   19.17 ms per token,    52.18 tokens per second)
# llama_print_timings:        eval time = 45057.07 ms /   255 runs   (  176.69 ms per token,     5.66 tokens per second)
# llama_print_timings:       total time = 47813.39 ms
# Llama.generate: prefix-match hit
# In 1996, the International Atomic Energy Agency (IAEA) published "Safety Series No. 100: Fundamental Safety Principles" which included guidelines for the safe use of nuclear power sources in space.[8] The IAEA also provides technical assistance to states on safety matters and has been involved in the development of national regulations for nuclear power sources used in space.[8]
#
# In 2011, the United Nations Committee on the Peaceful Uses of Outer Space (COPUOS) adopted a set of guidelines for the long-term sustainability of outer space activities, including principles related to the safe use of nuclear power sources in space and the mitigation of space debris.[8]
#
# The regulation of nuclear power sources in space is an ongoing process, with states continuing to discuss and develop new safety standards and guidelines. For example, in 2019, the IAEA published a new safety guide on the safe use of nuclear power sources in space, which includes updated guidelines for the design, launch, and operation of nuclear-powered spacecraft.[8]
#
# In
# llama_print_timings:        load time =  4949.59 ms
# llama_print_timings:      sample time =   182.39 ms /   256 runs   (    0.71 ms per token,  1403.60 tokens per second)
# llama_print_timings: prompt eval time =  2460.64 ms /   128 tokens (   19.22 ms per token,    52.02 tokens per second)
# llama_print_timings:        eval time = 45533.55 ms /   255 runs   (  178.56 ms per token,     5.60 tokens per second)
# llama_print_timings:       total time = 48619.31 ms
# Llama.generate: prefix-match hit
#  of Using a Standing Desk
#
# Using a standing desk can have several benefits, including:
#
# 1. Improved posture - Standing while working can help improve your posture, as you are not leaning forward or slouching in a chair.
# 2. Increased energy levels - Standing can help increase your energy levels and reduce fatigue, as you are not sitting for long periods of time.
# 3. Weight loss - Standing burns more calories than sitting, so using a standing desk can help with weight loss efforts.
# 4. Improved health - Prolonged sitting has been linked to several health problems, such as obesity, diabetes, and heart disease. Standing desks can help reduce the amount of time spent sitting.
# 5. Increased productivity - Standing can help increase productivity and focus, as you are not as likely to get comfortable and relaxed while working.
# 6. Reduced back pain - Standing can help reduce back pain, as you are not leaning forward or slouching in a chair.
# 7. Improved circulation - Standing can help improve blood flow and circulation, which can
# llama_print_timings:        load time =  4949.59 ms
# llama_print_timings:      sample time =   237.86 ms /   256 runs   (    0.93 ms per token,  1076.28 tokens per second)
# llama_print_timings: prompt eval time =   744.83 ms /     3 tokens (  248.28 ms per token,     4.03 tokens per second)
# llama_print_timings:        eval time = 48060.32 ms /   255 runs   (  188.47 ms per token,     5.31 tokens per second)
# llama_print_timings:       total time = 49638.28 ms
# Llama.generate: prefix-match hit
# The RTGs used on Viking 1 and 2 were fueled by radioisotope thermoelectric generators (RTGs), which convert the heat generated by the decay of radioactive isotopes into electricity. The RTGs were powered by plutonium-238, a non-weapons-grade isotope with a half-life of about 87 years. The Viking landers each had two RTGs, which provided a total of 150 watts of electrical power for the spacecraft's instruments and communication systems.
#
# The use of nuclear power in space exploration has some advantages over solar power. Nuclear power can provide a constant source of energy, regardless of the distance from the Sun or the time of day. This allows spacecraft to operate continuously, without the need for batteries or other forms of energy storage. Additionally, nuclear power can be more efficient than solar power in certain situations, such as deep space missions where the sunlight is too weak to generate significant amounts of electricity.
#
# However, there are also some disadvantages to using nuclear power in space exploration. N
# llama_print_timings:        load time =  4949.59 ms
# llama_print_timings:      sample time =   225.11 ms /   256 runs   (    0.88 ms per token,  1137.21 tokens per second)
# llama_print_timings: prompt eval time =  4161.84 ms /   188 tokens (   22.14 ms per token,    45.17 tokens per second)
# llama_print_timings:        eval time = 51791.55 ms /   255 runs   (  203.10 ms per token,     4.92 tokens per second)
# llama_print_timings:       total time = 56733.69 ms
# Llama.generate: prefix-match hit
# -	Materials and structures: advanced composites, smart materials, nanomaterials, inflatable structures, and lightweight structures.
# -	Energy: solar sails, solar panels, nuclear power, fuel cells, and energy storage systems.
# -	Propulsion: electric propulsion, ion thrusters, Hall effect thrusters, magneto-plasma dynamic (MPD) thrusters, and advanced rocket engines.
# -	Communications: satellite communications, radio communications, laser communications, and deep space communications networks.
# -	Life support: air revitalization, water recycling, waste management, and food production.
# -	Robotics: robotic arms, robotic hands, mobile robots, and humanoid robots.
# -	Computing: artificial intelligence, machine learning, data analytics, and advanced software.
# -	Scientific research: telescopes, spectrometers, detectors, and other scientific instruments for conducting experiments and gathering data in space.
#
# The content discusses various technologies and applications that are being developed and used in space exploration. These include advanced materials and structures, energy sources such as
# llama_print_timings:        load time =  4949.59 ms
# llama_print_timings:      sample time =   210.48 ms /   256 runs   (    0.82 ms per token,  1216.29 tokens per second)
# llama_print_timings: prompt eval time =   875.62 ms /    11 tokens (   79.60 ms per token,    12.56 tokens per second)
# llama_print_timings:        eval time = 53274.23 ms /   255 runs   (  208.92 ms per token,     4.79 tokens per second)
# llama_print_timings:       total time = 54883.06 ms
# Llama.generate: prefix-match hit
# Nuclear-powered ion thruster
# Nuclear-powered Hall effect thruster
#
# Classify the content into categories.
#
# Please provide detailed information about each category and its subcategories, along with examples of each. Also, please explain the relationship between the categories.
#
# It would be best if you could provide a diagram or flowchart to illustrate the relationships between the categories.
#
# I'll be happy to help you with that!
#
# The given content can be classified into the following categories:
#
# 1. Radioisotope-based power sources
# 	* Radioisotope thermoelectric generator (RTG)
# 	* Radioisotope heater unit (RHU)
# 	* Radioisotope piezoelectric generator (RPG)
# 2. Nuclear-based propulsion systems
# 	* Nuclear thermal rocket (NTR)
# 	* Nuclear pulse propulsion (NPP)
# 	* Nuclear electric rocket (NER)
# 3. Nuclear-powered electrical thrusters
# 	* Nuclear-powered ion thruster (NIT)
# 	* Nuclear-powered
# llama_print_timings:        load time =  4949.59 ms
# llama_print_timings:      sample time =   192.31 ms /   256 runs   (    0.75 ms per token,  1331.17 tokens per second)
# llama_print_timings: prompt eval time =  1670.95 ms /    57 tokens (   29.31 ms per token,    34.11 tokens per second)
# llama_print_timings:        eval time = 53701.19 ms /   255 runs   (  210.59 ms per token,     4.75 tokens per second)
# llama_print_timings:       total time = 56041.17 ms
# Llama.generate: prefix-match hit
#  Hall effect thruster (NHET)
# 4. Safety and regulatory considerations
# 	* Radiation protection for crew and electronics
# 	* Heat rejection and temperature control
# 	* Launch and deployment
# 	* Operations and maintenance
# 	* Decommissioning and disposal
# 5. Future developments and advancements
# 	* Advanced reactor designs (fission or fusion reactors)
# 	* Scalable reactor designs for various mission requirements
# 	* Long-duration tests on the International Space Station (ISS) and lunar surface demonstration missions
# 6. Historical background and past missions
# 	* First nuclear-powered satellite (SNAP-10A)
# 	* First nuclear-powered satellite with a thermoelectric converter (SNAP-19)
# 	* Soviet Union's first nuclear-powered satellite (Kosmos 217)
# 	* Radioisotope rocket and REP (radioisotope electric propulsion)
#
# The relationship between the categories is as follows:
#
# Radioisotope-based power sources are used to generate electricity, which can then be used to power nuclear-based
# llama_print_timings:        load time =  4949.59 ms
# llama_print_timings:      sample time =   240.07 ms /   256 runs   (    0.94 ms per token,  1066.37 tokens per second)
# llama_print_timings: prompt eval time = 55764.83 ms /  2328 tokens (   23.95 ms per token,    41.75 tokens per second)
# llama_print_timings:        eval time = 57927.55 ms /   255 runs   (  227.17 ms per token,     4.40 tokens per second)
# llama_print_timings:       total time = 114587.14 ms
# " Hall effect thruster (NHET)\n4. Safety and regulatory considerations\n\t* Radiation protection for crew and electronics\n\t* Heat rejection and temperature control\n\t* Launch and deployment\n\t* Operations and maintenance\n\t* Decommissioning and disposal\n5. Future developments and advancements\n\t* Advanced reactor designs (fission or fusion reactors)\n\t* Scalable reactor designs for various mission requirements\n\t* Long-duration tests on the International Space Station (ISS) and lunar surface demonstration missions\n6. Historical background and past missions\n\t* First nuclear-powered satellite (SNAP-10A)\n\t* First nuclear-powered satellite with a thermoelectric converter (SNAP-19)\n\t* Soviet Union's first nuclear-powered satellite (Kosmos 217)\n\t* Radioisotope rocket and REP (radioisotope electric propulsion)\n\nThe relationship between the categories is as follows:\n\nRadioisotope-based power sources are used to generate electricity, which can then be used to power nuclear-based"
