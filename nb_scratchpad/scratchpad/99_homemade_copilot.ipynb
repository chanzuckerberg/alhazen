# %% [markdown]
# # Local Mixtral

# %%
from langchain.schema.runnable import RunnableParallel, RunnablePassthrough, RunnableLambda
from operator import itemgetter
from langchain.chat_models import ChatOllama
from langchain.schema import get_buffer_string, OutputParserException, format_document
from langchain.callbacks.tracers import ConsoleCallbackHandler
from langchain.schema import StrOutputParser
from langchain.prompts import ChatPromptTemplate, PromptTemplate
from alhazen.utils.output_parsers import JsonEnclosedByTextOutputParser

def _sanitize_output(text: str):
    _, after = text.split("```python")
    return after.split("```")[0]

sys_p = '''You are an expert python programmer. 
You write concise, well-documented, high-quality source code.'''

hum_p_1 = '''The following snippet of HTML enclosed in triple backticks is a table about 
large language models. Only using the HTML data, write a python function that plots 
a horizontal bar chart with the name of each large language model on the vertical axis and 
the number of parameters used in each model on the horizontal. Use the seaborn library.
Only generate valid python code in your answer.   

```{html}```
'''
prompt = ChatPromptTemplate.from_messages([
            ("system", sys_p),
            ("human", hum_p_1)])

model = ChatOllama(model='codellama:34b-python')

codegen_chain = prompt | model | StrOutputParser()

# %%
import requests
from bs4 import BeautifulSoup

# Replace this URL with the one you want to scrape
url = "https://en.wikipedia.org/wiki/Large_language_model#List"

# Send a request to the URL and get the HTML content
response = requests.get(url)
html_content = response.text

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(html_content, "html.parser")

# Find the table you want to extract (you may need to adjust the selector based on the page)
table = soup.find("table", {"class": "wikitable sortable"})

print(table)
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Name</th>
# <th>Release date<sup class="reference" id="cite_ref-120"><a href="#cite_note-120">[a]</a></sup></th>
# <th>Developer</th>
# <th>Number of parameters<sup class="reference" id="cite_ref-121"><a href="#cite_note-121">[b]</a></sup></th>
# <th>Corpus size
# </th>
# <th>Training cost (petaFLOP-day)</th>
# <th>License<sup class="reference" id="cite_ref-122"><a href="#cite_note-122">[c]</a></sup></th>
# <th>Notes
# </th></tr>
# <tr>
# <td><a href="/wiki/GPT-1" title="GPT-1">GPT-1</a></td>
# <td><span data-sort-value="000000002018-06-01-0000" style="white-space:nowrap">June 2018</span></td>
# <td><a href="/wiki/OpenAI" title="OpenAI">OpenAI</a></td>
# <td><span data-sort-value="117000000 !">117 million</span></td>
# <td>
# </td>
# <td></td>
# <td class="table-yes" style="background:#9EFF9E;vertical-align:middle;text-align:center;">MIT<sup class="reference" id="cite_ref-gpt1_123-0"><a href="#cite_note-gpt1-123">[120]</a></sup>
# </td>
# <td>First GPT model, decoder-only transformer.
# </td></tr>
# <tr>
# <td><a href="/wiki/BERT_(language_model)" title="BERT (language model)">BERT</a></td>
# <td><span data-sort-value="000000002018-10-01-0000" style="white-space:nowrap">October 2018</span></td>
# <td><a href="/wiki/Google" title="Google">Google</a></td>
# <td><span data-sort-value="340000000 !">340 million</span><sup class="reference" id="cite_ref-bert-paper_124-0"><a href="#cite_note-bert-paper-124">[121]</a></sup></td>
# <td><span data-sort-value="3300000000 !">3.3 billion</span> words<sup class="reference" id="cite_ref-bert-paper_124-1"><a href="#cite_note-bert-paper-124">[121]</a></sup>
# </td>
# <td><span data-sort-value="9 !">9</span><sup class="reference" id="cite_ref-bHZJ2_125-0"><a href="#cite_note-bHZJ2-125">[122]</a></sup></td>
# <td class="table-yes" style="background:#9EFF9E;vertical-align:middle;text-align:center;">Apache 2.0<sup class="reference" id="cite_ref-bert-web_126-0"><a href="#cite_note-bert-web-126">[123]</a></sup>
# </td>
# <td>An early and influential language model,<sup class="reference" id="cite_ref-Manning-2022_7-1"><a href="#cite_note-Manning-2022-7">[7]</a></sup> but encoder-only and thus not built to be prompted or generative<sup class="reference" id="cite_ref-Ir545_127-0"><a href="#cite_note-Ir545-127">[124]</a></sup>
# </td></tr>
# <tr>
# <td>XLNet</td>
# <td><span data-sort-value="000000002019-06-01-0000" style="white-space:nowrap">June 2019</span></td>
# <td><a href="/wiki/Google" title="Google">Google</a></td>
# <td><span data-sort-value="340000000 !">~340 million</span><sup class="reference" id="cite_ref-45rAm_128-0"><a href="#cite_note-45rAm-128">[125]</a></sup></td>
# <td><span data-sort-value="3300000000 !">33 billion</span> words
# </td>
# <td></td>
# <td class="table-yes" style="background:#9EFF9E;vertical-align:middle;text-align:center;">Apache 2.0<sup class="reference" id="cite_ref-xlnet_129-0"><a href="#cite_note-xlnet-129">[126]</a></sup>
# </td>
# <td>An alternative to BERT; designed as encoder-only<sup class="reference" id="cite_ref-gAbNO_130-0"><a href="#cite_note-gAbNO-130">[127]</a></sup><sup class="reference" id="cite_ref-LX3rI_131-0"><a href="#cite_note-LX3rI-131">[128]</a></sup>
# </td></tr>
# <tr>
# <td><a href="/wiki/GPT-2" title="GPT-2">GPT-2</a></td>
# <td><span data-sort-value="000000002019-02-01-0000" style="white-space:nowrap">February 2019</span></td>
# <td><a href="/wiki/OpenAI" title="OpenAI">OpenAI</a></td>
# <td><span data-sort-value="1500000000 !">1.5 billion</span><sup class="reference" id="cite_ref-15Brelease_132-0"><a href="#cite_note-15Brelease-132">[129]</a></sup></td>
# <td>40GB<sup class="reference" id="cite_ref-5T8u5_133-0"><a href="#cite_note-5T8u5-133">[130]</a></sup> (~<span data-sort-value="10000000000 !">10 billion</span> tokens)<sup class="reference" id="cite_ref-LambdaLabs_134-0"><a href="#cite_note-LambdaLabs-134">[131]</a></sup>
# </td>
# <td></td>
# <td class="table-yes" style="background:#9EFF9E;vertical-align:middle;text-align:center;">MIT<sup class="reference" id="cite_ref-Sudbe_135-0"><a href="#cite_note-Sudbe-135">[132]</a></sup>
# </td>
# <td>general-purpose model based on transformer architecture
# </td></tr>
# <tr>
# <td><a href="/wiki/GPT-3" title="GPT-3">GPT-3</a></td>
# <td><span data-sort-value="000000002020-05-01-0000" style="white-space:nowrap">May 2020</span></td>
# <td>OpenAI</td>
# <td><span data-sort-value="175000000000 !">175 billion</span><sup class="reference" id="cite_ref-Wiggers_37-1"><a href="#cite_note-Wiggers-37">[37]</a></sup></td>
# <td><span data-sort-value="300000000000 !">300 billion</span> tokens<sup class="reference" id="cite_ref-LambdaLabs_134-1"><a href="#cite_note-LambdaLabs-134">[131]</a></sup>
# </td>
# <td>3640<sup class="reference" id="cite_ref-:2_136-0"><a href="#cite_note-:2-136">[133]</a></sup></td>
# <td class="table-no" style="background:#FFC7C7;vertical-align:middle;text-align:center;">proprietary
# </td>
# <td>A fine-tuned variant of GPT-3, termed GPT-3.5, was made available to the public through a web interface called <a href="/wiki/ChatGPT" title="ChatGPT">ChatGPT</a> in 2022.<sup class="reference" id="cite_ref-chatgpt-blog_137-0"><a href="#cite_note-chatgpt-blog-137">[134]</a></sup>
# </td></tr>
# <tr>
# <td>GPT-Neo</td>
# <td><span data-sort-value="000000002021-03-01-0000" style="white-space:nowrap">March 2021</span></td>
# <td><a href="/wiki/EleutherAI" title="EleutherAI">EleutherAI</a></td>
# <td><span data-sort-value="2700000000 !">2.7 billion</span><sup class="reference" id="cite_ref-gpt-neo_138-0"><a href="#cite_note-gpt-neo-138">[135]</a></sup></td>
# <td>825 GiB<sup class="reference" id="cite_ref-Pile_139-0"><a href="#cite_note-Pile-139">[136]</a></sup>
# </td>
# <td></td>
# <td class="table-yes" style="background:#9EFF9E;vertical-align:middle;text-align:center;">MIT<sup class="reference" id="cite_ref-vb-gpt-neo_140-0"><a href="#cite_note-vb-gpt-neo-140">[137]</a></sup>
# </td>
# <td>The first of <a href="/wiki/EleutherAI#GPT_models" title="EleutherAI">a series of free GPT-3 alternatives</a> released by EleutherAI. GPT-Neo outperformed an equivalent-size GPT-3 model on some benchmarks, but was significantly worse than the largest GPT-3.<sup class="reference" id="cite_ref-vb-gpt-neo_140-1"><a href="#cite_note-vb-gpt-neo-140">[137]</a></sup>
# </td></tr>
# <tr>
# <td><a href="/wiki/GPT-J" title="GPT-J">GPT-J</a></td>
# <td><span data-sort-value="000000002021-06-01-0000" style="white-space:nowrap">June 2021</span></td>
# <td><a href="/wiki/EleutherAI" title="EleutherAI">EleutherAI</a></td>
# <td><span data-sort-value="6000000000 !">6 billion</span><sup class="reference" id="cite_ref-JxohJ_141-0"><a href="#cite_note-JxohJ-141">[138]</a></sup></td>
# <td>825 GiB<sup class="reference" id="cite_ref-Pile_139-1"><a href="#cite_note-Pile-139">[136]</a></sup>
# </td>
# <td>200<sup class="reference" id="cite_ref-:3_142-0"><a href="#cite_note-:3-142">[139]</a></sup></td>
# <td class="table-yes" style="background:#9EFF9E;vertical-align:middle;text-align:center;">Apache 2.0
# </td>
# <td>GPT-3-style language model
# </td></tr>
# <tr>
# <td>Megatron-Turing NLG</td>
# <td><span data-sort-value="000000002021-10-01-0000" style="white-space:nowrap">October 2021</span><sup class="reference" id="cite_ref-BwnW5_143-0"><a href="#cite_note-BwnW5-143">[140]</a></sup></td>
# <td><a href="/wiki/Microsoft" title="Microsoft">Microsoft</a> and <a href="/wiki/Nvidia" title="Nvidia">Nvidia</a></td>
# <td><span data-sort-value="530000000000 !">530 billion</span><sup class="reference" id="cite_ref-mtnlg-preprint_144-0"><a href="#cite_note-mtnlg-preprint-144">[141]</a></sup></td>
# <td><span data-sort-value="338600000000 !">338.6 billion</span> tokens<sup class="reference" id="cite_ref-mtnlg-preprint_144-1"><a href="#cite_note-mtnlg-preprint-144">[141]</a></sup>
# </td>
# <td></td>
# <td class="table-no" style="background:#FFC7C7;vertical-align:middle;text-align:center;">Restricted web access
# </td>
# <td>Standard architecture but trained on a supercomputing cluster.
# </td></tr>
# <tr>
# <td>Ernie 3.0 Titan</td>
# <td><span data-sort-value="000000002021-12-01-0000" style="white-space:nowrap">December 2021</span></td>
# <td><a href="/wiki/Baidu" title="Baidu">Baidu</a></td>
# <td><span data-sort-value="260000000000 !">260 billion</span><sup class="reference" id="cite_ref-qeOB8_145-0"><a href="#cite_note-qeOB8-145">[142]</a></sup></td>
# <td>4 Tb
# </td>
# <td></td>
# <td class="table-no" style="background:#FFC7C7;vertical-align:middle;text-align:center;">Proprietary
# </td>
# <td>Chinese-language LLM. <a href="/wiki/Ernie_Bot" title="Ernie Bot">Ernie Bot</a> is based on this model.
# </td></tr>
# <tr>
# <td>Claude<sup class="reference" id="cite_ref-i8jc4_146-0"><a href="#cite_note-i8jc4-146">[143]</a></sup></td>
# <td><span data-sort-value="000000002021-12-01-0000" style="white-space:nowrap">December 2021</span></td>
# <td><a href="/wiki/Anthropic" title="Anthropic">Anthropic</a></td>
# <td><span data-sort-value="52000000000 !">52 billion</span><sup class="reference" id="cite_ref-AnthroArch_147-0"><a href="#cite_note-AnthroArch-147">[144]</a></sup></td>
# <td><span data-sort-value="400000000000 !">400 billion</span> tokens<sup class="reference" id="cite_ref-AnthroArch_147-1"><a href="#cite_note-AnthroArch-147">[144]</a></sup>
# </td>
# <td></td>
# <td class="table-partial" style="background: #FFB; vertical-align: middle; text-align: center;">beta
# </td>
# <td>Fine-tuned for desirable behavior in conversations.<sup class="reference" id="cite_ref-RZqhw_148-0"><a href="#cite_note-RZqhw-148">[145]</a></sup>
# </td></tr>
# <tr>
# <td>GLaM (Generalist Language Model)</td>
# <td><span data-sort-value="000000002021-12-01-0000" style="white-space:nowrap">December 2021</span></td>
# <td>Google</td>
# <td><span data-sort-value="1200000000000 !">1.2 trillion</span><sup class="reference" id="cite_ref-glam-blog_28-1"><a href="#cite_note-glam-blog-28">[28]</a></sup></td>
# <td><span data-sort-value="1600000000000 !">1.6 trillion</span> tokens<sup class="reference" id="cite_ref-glam-blog_28-2"><a href="#cite_note-glam-blog-28">[28]</a></sup>
# </td>
# <td>5600<sup class="reference" id="cite_ref-glam-blog_28-3"><a href="#cite_note-glam-blog-28">[28]</a></sup></td>
# <td class="table-no" style="background:#FFC7C7;vertical-align:middle;text-align:center;">Proprietary
# </td>
# <td>Sparse <a href="/wiki/Mixture_of_experts" title="Mixture of experts">mixture of experts</a> model, making it more expensive to train but cheaper to run inference compared to GPT-3.
# </td></tr>
# <tr>
# <td>Gopher</td>
# <td><span data-sort-value="000000002021-12-01-0000" style="white-space:nowrap">December 2021</span></td>
# <td><a class="mw-redirect" href="/wiki/DeepMind" title="DeepMind">DeepMind</a></td>
# <td><span data-sort-value="280000000000 !">280 billion</span><sup class="reference" id="cite_ref-mD5eE_149-0"><a href="#cite_note-mD5eE-149">[146]</a></sup></td>
# <td><span data-sort-value="300000000000 !">300 billion</span> tokens<sup class="reference" id="cite_ref-hoffman_150-0"><a href="#cite_note-hoffman-150">[147]</a></sup>
# </td>
# <td>5833<sup class="reference" id="cite_ref-:4_151-0"><a href="#cite_note-:4-151">[148]</a></sup></td>
# <td class="table-no" style="background:#FFC7C7;vertical-align:middle;text-align:center;">Proprietary
# </td>
# <td>Further developed into the Chinchilla model.
# </td></tr>
# <tr>
# <td><a href="/wiki/LaMDA" title="LaMDA">LaMDA</a> (Language Models for Dialog Applications)</td>
# <td><span data-sort-value="000000002022-01-01-0000" style="white-space:nowrap">January 2022</span></td>
# <td>Google</td>
# <td><span data-sort-value="137000000000 !">137 billion</span><sup class="reference" id="cite_ref-lamda-blog_152-0"><a href="#cite_note-lamda-blog-152">[149]</a></sup></td>
# <td>1.56T words,<sup class="reference" id="cite_ref-lamda-blog_152-1"><a href="#cite_note-lamda-blog-152">[149]</a></sup> <span data-sort-value="168000000000 !">168 billion</span> tokens<sup class="reference" id="cite_ref-hoffman_150-1"><a href="#cite_note-hoffman-150">[147]</a></sup>
# </td>
# <td>4110<sup class="reference" id="cite_ref-DMs9Z_153-0"><a href="#cite_note-DMs9Z-153">[150]</a></sup></td>
# <td class="table-no" style="background:#FFC7C7;vertical-align:middle;text-align:center;">Proprietary
# </td>
# <td>Specialized for response generation in conversations.
# </td></tr>
# <tr>
# <td>GPT-NeoX</td>
# <td><span data-sort-value="000000002022-02-01-0000" style="white-space:nowrap">February 2022</span></td>
# <td><a href="/wiki/EleutherAI" title="EleutherAI">EleutherAI</a></td>
# <td><span data-sort-value="20000000000 !">20 billion</span><sup class="reference" id="cite_ref-gpt-neox-20b_154-0"><a href="#cite_note-gpt-neox-20b-154">[151]</a></sup></td>
# <td>825 GiB<sup class="reference" id="cite_ref-Pile_139-2"><a href="#cite_note-Pile-139">[136]</a></sup>
# </td>
# <td>740<sup class="reference" id="cite_ref-:3_142-1"><a href="#cite_note-:3-142">[139]</a></sup></td>
# <td class="table-yes" style="background:#9EFF9E;vertical-align:middle;text-align:center;">Apache 2.0
# </td>
# <td>based on the Megatron architecture
# </td></tr>
# <tr>
# <td><a href="/wiki/Chinchilla_AI" title="Chinchilla AI">Chinchilla</a></td>
# <td><span data-sort-value="000000002022-03-01-0000" style="white-space:nowrap">March 2022</span></td>
# <td><a class="mw-redirect" href="/wiki/DeepMind" title="DeepMind">DeepMind</a></td>
# <td><span data-sort-value="70000000000 !">70 billion</span><sup class="reference" id="cite_ref-chinchilla-blog_155-0"><a href="#cite_note-chinchilla-blog-155">[152]</a></sup></td>
# <td><span data-sort-value="1400000000000 !">1.4 trillion</span> tokens<sup class="reference" id="cite_ref-chinchilla-blog_155-1"><a href="#cite_note-chinchilla-blog-155">[152]</a></sup><sup class="reference" id="cite_ref-hoffman_150-2"><a href="#cite_note-hoffman-150">[147]</a></sup>
# </td>
# <td>6805<sup class="reference" id="cite_ref-:4_151-1"><a href="#cite_note-:4-151">[148]</a></sup></td>
# <td class="table-no" style="background:#FFC7C7;vertical-align:middle;text-align:center;">Proprietary
# </td>
# <td>Reduced-parameter model trained on more data. Used in the <a href="/wiki/Sparrow_(bot)" title="Sparrow (bot)">Sparrow</a> bot. Often cited for its <a href="/wiki/Neural_scaling_law" title="Neural scaling law">neural scaling law</a>.
# </td></tr>
# <tr>
# <td><a href="/wiki/PaLM" title="PaLM">PaLM</a> (Pathways Language Model)</td>
# <td><span data-sort-value="000000002022-04-01-0000" style="white-space:nowrap">April 2022</span></td>
# <td>Google</td>
# <td><span data-sort-value="540000000000 !">540 billion</span><sup class="reference" id="cite_ref-palm-blog_156-0"><a href="#cite_note-palm-blog-156">[153]</a></sup></td>
# <td><span data-sort-value="768000000000 !">768 billion</span> tokens<sup class="reference" id="cite_ref-chinchilla-blog_155-2"><a href="#cite_note-chinchilla-blog-155">[152]</a></sup>
# </td>
# <td>29250<sup class="reference" id="cite_ref-:4_151-2"><a href="#cite_note-:4-151">[148]</a></sup></td>
# <td class="table-no" style="background:#FFC7C7;vertical-align:middle;text-align:center;">Proprietary
# </td>
# <td>Trained for ~60 days on ~6000 <a href="/wiki/Tensor_Processing_Unit" title="Tensor Processing Unit">TPU v4</a> chips. <sup class="reference" id="cite_ref-:4_151-3"><a href="#cite_note-:4-151">[148]</a></sup>
# </td></tr>
# <tr>
# <td>OPT (Open Pretrained Transformer)</td>
# <td><span data-sort-value="000000002022-05-01-0000" style="white-space:nowrap">May 2022</span></td>
# <td><a href="/wiki/Meta_Platforms" title="Meta Platforms">Meta</a></td>
# <td><span data-sort-value="175000000000 !">175 billion</span><sup class="reference" id="cite_ref-jlof8_157-0"><a href="#cite_note-jlof8-157">[154]</a></sup></td>
# <td><span data-sort-value="180000000000 !">180 billion</span> tokens<sup class="reference" id="cite_ref-QjTIc_158-0"><a href="#cite_note-QjTIc-158">[155]</a></sup>
# </td>
# <td>310<sup class="reference" id="cite_ref-:3_142-2"><a href="#cite_note-:3-142">[139]</a></sup></td>
# <td class="table-partial" style="background: #FFB; vertical-align: middle; text-align: center;">Non-commercial research<sup class="reference" id="cite_ref-159"><a href="#cite_note-159">[d]</a></sup>
# </td>
# <td>GPT-3 architecture with some adaptations from Megatron
# </td></tr>
# <tr>
# <td>YaLM 100B</td>
# <td><span data-sort-value="000000002022-06-01-0000" style="white-space:nowrap">June 2022</span></td>
# <td><a href="/wiki/Yandex" title="Yandex">Yandex</a></td>
# <td><span data-sort-value="100000000000 !">100 billion</span><sup class="reference" id="cite_ref-yalm-repo_160-0"><a href="#cite_note-yalm-repo-160">[156]</a></sup>
# </td>
# <td>1.7TB<sup class="reference" id="cite_ref-yalm-repo_160-1"><a href="#cite_note-yalm-repo-160">[156]</a></sup></td>
# <td></td>
# <td class="table-yes" style="background:#9EFF9E;vertical-align:middle;text-align:center;">Apache 2.0</td>
# <td>English-Russian model based on Microsoft's Megatron-LM.
# </td></tr>
# <tr>
# <td>Minerva</td>
# <td><span data-sort-value="000000002022-06-01-0000" style="white-space:nowrap">June 2022</span></td>
# <td>Google</td>
# <td><span data-sort-value="540000000000 !">540 billion</span><sup class="reference" id="cite_ref-minerva-paper_161-0"><a href="#cite_note-minerva-paper-161">[157]</a></sup></td>
# <td>38.5B tokens from webpages filtered for mathematical content and from papers submitted to the arXiv preprint server<sup class="reference" id="cite_ref-minerva-paper_161-1"><a href="#cite_note-minerva-paper-161">[157]</a></sup>
# </td>
# <td></td>
# <td class="table-no" style="background:#FFC7C7;vertical-align:middle;text-align:center;">Proprietary
# </td>
# <td>LLM trained for solving "mathematical and scientific questions using step-by-step reasoning".<sup class="reference" id="cite_ref-FfCNK_162-0"><a href="#cite_note-FfCNK-162">[158]</a></sup> Minerva is based on PaLM model, further trained on mathematical and scientific data.
# </td></tr>
# <tr>
# <td><a href="/wiki/BLOOM_(language_model)" title="BLOOM (language model)">BLOOM</a></td>
# <td><span data-sort-value="000000002022-07-01-0000" style="white-space:nowrap">July 2022</span></td>
# <td>Large collaboration led by <a href="/wiki/Hugging_Face" title="Hugging Face">Hugging Face</a></td>
# <td><span data-sort-value="175000000000 !">175 billion</span><sup class="reference" id="cite_ref-bigger-better_163-0"><a href="#cite_note-bigger-better-163">[159]</a></sup></td>
# <td><span data-sort-value="350000000000 !">350 billion</span> tokens (1.6TB)<sup class="reference" id="cite_ref-B8wB2_164-0"><a href="#cite_note-B8wB2-164">[160]</a></sup>
# </td>
# <td></td>
# <td class="table-partial" style="background: #FFB; vertical-align: middle; text-align: center;">Responsible AI
# </td>
# <td>Essentially GPT-3 but trained on a multi-lingual corpus (30% English excluding programming languages)
# </td></tr>
# <tr>
# <td>Galactica</td>
# <td><span data-sort-value="000000002022-11-01-0000" style="white-space:nowrap">November 2022</span></td>
# <td><a href="/wiki/Meta_Platforms" title="Meta Platforms">Meta</a></td>
# <td><span data-sort-value="120000000000 !">120 billion</span></td>
# <td><span data-sort-value="350000000000 !">106 billion</span> tokens<sup class="reference" id="cite_ref-37sY6_165-0"><a href="#cite_note-37sY6-165">[161]</a></sup>
# </td>
# <td>unknown</td>
# <td class="table-partial" style="background: #FFB; vertical-align: middle; text-align: center;">CC-BY-NC-4.0
# </td>
# <td>Trained on scientific text and modalities.
# </td></tr>
# <tr>
# <td>AlexaTM (Teacher Models)</td>
# <td><span data-sort-value="000000002022-11-01-0000" style="white-space:nowrap">November 2022</span></td>
# <td><a href="/wiki/Amazon_(company)" title="Amazon (company)">Amazon</a></td>
# <td><span data-sort-value="20000000000 !">20 billion</span><sup class="reference" id="cite_ref-u5szh_166-0"><a href="#cite_note-u5szh-166">[162]</a></sup></td>
# <td><span data-sort-value="1300000000000 !">1.3 trillion</span><sup class="reference" id="cite_ref-HaA7l_167-0"><a href="#cite_note-HaA7l-167">[163]</a></sup>
# </td>
# <td></td>
# <td class="table-no" style="background:#FFC7C7;vertical-align:middle;text-align:center;">proprietary<sup class="reference" id="cite_ref-rpehM_168-0"><a href="#cite_note-rpehM-168">[164]</a></sup>
# </td>
# <td>bidirectional sequence-to-sequence architecture
# </td></tr>
# <tr>
# <td><a href="/wiki/Neuro-sama" title="Neuro-sama">Neuro-sama</a></td>
# <td><span data-sort-value="000000002022-12-01-0000" style="white-space:nowrap">December 2022</span></td>
# <td>Independent</td>
# <td>Unknown</td>
# <td>Unknown
# </td>
# <td></td>
# <td class="table-no" style="background:#FFC7C7;vertical-align:middle;text-align:center;">privately-owned
# </td>
# <td>A language model designed for live-streaming on <a href="/wiki/Twitch_(service)" title="Twitch (service)">Twitch</a>.
# </td></tr>
# <tr>
# <td><a href="/wiki/LLaMA" title="LLaMA">LLaMA</a> (Large Language Model Meta AI)</td>
# <td><span data-sort-value="000000002023-02-01-0000" style="white-space:nowrap">February 2023</span></td>
# <td><a href="/wiki/Meta_Platforms" title="Meta Platforms">Meta</a></td>
# <td><span data-sort-value="65000000000 !">65 billion</span><sup class="reference" id="cite_ref-llama-blog_169-0"><a href="#cite_note-llama-blog-169">[165]</a></sup></td>
# <td><span data-sort-value="1400000000000 !">1.4 trillion</span><sup class="reference" id="cite_ref-llama-blog_169-1"><a href="#cite_note-llama-blog-169">[165]</a></sup>
# </td>
# <td>6300<sup class="reference" id="cite_ref-:5_170-0"><a href="#cite_note-:5-170">[166]</a></sup></td>
# <td class="table-partial" style="background: #FFB; vertical-align: middle; text-align: center;">Non-commercial research<sup class="reference" id="cite_ref-171"><a href="#cite_note-171">[e]</a></sup>
# </td>
# <td>Trained on a large 20-language corpus to aim for better performance with fewer parameters.<sup class="reference" id="cite_ref-llama-blog_169-2"><a href="#cite_note-llama-blog-169">[165]</a></sup> Researchers from Stanford University trained a fine-tuned model based on LLaMA weights, called Alpaca.<sup class="reference" id="cite_ref-KBedq_172-0"><a href="#cite_note-KBedq-172">[167]</a></sup>
# </td></tr>
# <tr>
# <td><a href="/wiki/GPT-4" title="GPT-4">GPT-4</a></td>
# <td><span data-sort-value="000000002023-03-01-0000" style="white-space:nowrap">March 2023</span></td>
# <td>OpenAI</td>
# <td>Exact number unknown<sup class="reference" id="cite_ref-174"><a href="#cite_note-174">[f]</a></sup></td>
# <td>Unknown
# </td>
# <td>Unknown</td>
# <td class="table-no" style="background:#FFC7C7;vertical-align:middle;text-align:center;">proprietary
# </td>
# <td>Available for ChatGPT Plus users and used in <a href="/wiki/GPT-4#Usage" title="GPT-4">several products</a>.
# </td></tr>
# <tr>
# <td>Cerebras-GPT
# </td>
# <td><span data-sort-value="000000002023-03-01-0000" style="white-space:nowrap">March 2023</span>
# </td>
# <td>Cerebras
# </td>
# <td><span data-sort-value="13000000000 !">13 billion</span><sup class="reference" id="cite_ref-D0k2a_175-0"><a href="#cite_note-D0k2a-175">[169]</a></sup>
# </td>
# <td>
# </td>
# <td>270<sup class="reference" id="cite_ref-:3_142-3"><a href="#cite_note-:3-142">[139]</a></sup></td>
# <td class="table-yes" style="background:#9EFF9E;vertical-align:middle;text-align:center;">Apache 2.0
# </td>
# <td>Trained with Chinchilla formula.
# </td></tr>
# <tr>
# <td>Falcon</td>
# <td><span data-sort-value="000000002023-03-01-0000" style="white-space:nowrap">March 2023</span></td>
# <td><a href="/wiki/Technology_Innovation_Institute" title="Technology Innovation Institute">Technology Innovation Institute</a></td>
# <td><span data-sort-value="40000000000 !">40 billion</span><sup class="reference" id="cite_ref-falcon_176-0"><a href="#cite_note-falcon-176">[170]</a></sup></td>
# <td>1 trillion tokens, from RefinedWeb (filtered web text corpus)<sup class="reference" id="cite_ref-Xb1gq_177-0"><a href="#cite_note-Xb1gq-177">[171]</a></sup> plus some "curated corpora".<sup class="reference" id="cite_ref-gzTNw_178-0"><a href="#cite_note-gzTNw-178">[172]</a></sup>
# </td>
# <td>2800<sup class="reference" id="cite_ref-:5_170-1"><a href="#cite_note-:5-170">[166]</a></sup></td>
# <td class="table-yes" style="background:#9EFF9E;vertical-align:middle;text-align:center;">Apache 2.0<sup class="reference" id="cite_ref-Wmlcs_179-0"><a href="#cite_note-Wmlcs-179">[173]</a></sup>
# </td>
# <td>
# </td></tr>
# <tr>
# <td>BloombergGPT</td>
# <td><span data-sort-value="000000002023-03-01-0000" style="white-space:nowrap">March 2023</span></td>
# <td><a href="/wiki/Bloomberg_L.P." title="Bloomberg L.P.">Bloomberg L.P.</a></td>
# <td><span data-sort-value="50000000000 !">50 billion</span></td>
# <td>363 billion token dataset based on Bloomberg's data sources, plus 345 billion tokens from general purpose datasets<sup class="reference" id="cite_ref-nGOSu_180-0"><a href="#cite_note-nGOSu-180">[174]</a></sup>
# </td>
# <td></td>
# <td class="table-no" style="background:#FFC7C7;vertical-align:middle;text-align:center;">Proprietary
# </td>
# <td>LLM trained on financial data from proprietary sources, that "outperforms existing models on financial tasks by significant margins without sacrificing performance on general LLM benchmarks"
# </td></tr>
# <tr>
# <td>PanGu-Σ</td>
# <td><span data-sort-value="000000002023-03-01-0000" style="white-space:nowrap">March 2023</span></td>
# <td><a href="/wiki/Huawei" title="Huawei">Huawei</a></td>
# <td><span data-sort-value="1085000000000 !">1.085 trillion</span></td>
# <td>329 billion tokens<sup class="reference" id="cite_ref-9WSFw_181-0"><a href="#cite_note-9WSFw-181">[175]</a></sup>
# </td>
# <td></td>
# <td class="table-no" style="background:#FFC7C7;vertical-align:middle;text-align:center;">Proprietary
# </td>
# <td>
# </td></tr>
# <tr>
# <td>OpenAssistant<sup class="reference" id="cite_ref-JiOl8_182-0"><a href="#cite_note-JiOl8-182">[176]</a></sup></td>
# <td><span data-sort-value="000000002023-03-01-0000" style="white-space:nowrap">March 2023</span></td>
# <td><a href="/wiki/LAION" title="LAION">LAION</a></td>
# <td><span data-sort-value="17000000000 !">17 billion</span></td>
# <td>1.5 trillion tokens
# </td>
# <td></td>
# <td class="table-yes" style="background:#9EFF9E;vertical-align:middle;text-align:center;">Apache 2.0
# </td>
# <td>Trained on crowdsourced open data
# </td></tr>
# <tr>
# <td>Jurassic-2<sup class="reference" id="cite_ref-183"><a href="#cite_note-183">[177]</a></sup>
# </td>
# <td><span data-sort-value="000000002023-03-01-0000" style="white-space:nowrap">March 2023</span>
# </td>
# <td><a href="/wiki/AI21_Labs" title="AI21 Labs">AI21 Labs</a>
# </td>
# <td>Exact size unknown
# </td>
# <td>Unknown
# </td>
# <td></td>
# <td class="table-no" style="background:#FFC7C7;vertical-align:middle;text-align:center;">Proprietary
# </td>
# <td>Multilingual<sup class="reference" id="cite_ref-184"><a href="#cite_note-184">[178]</a></sup>
# </td></tr>
# <tr>
# <td><a href="/wiki/PaLM" title="PaLM">PaLM 2</a> (Pathways Language Model 2)</td>
# <td><span data-sort-value="000000002023-05-01-0000" style="white-space:nowrap">May 2023</span></td>
# <td>Google</td>
# <td><span data-sort-value="340000000000 !">340 billion</span><sup class="reference" id="cite_ref-cnbc-20230516_185-0"><a href="#cite_note-cnbc-20230516-185">[179]</a></sup></td>
# <td><span data-sort-value="3600000000000 !">3.6 trillion</span> tokens<sup class="reference" id="cite_ref-cnbc-20230516_185-1"><a href="#cite_note-cnbc-20230516-185">[179]</a></sup>
# </td>
# <td>85000<sup class="reference" id="cite_ref-:5_170-2"><a href="#cite_note-:5-170">[166]</a></sup></td>
# <td class="table-no" style="background:#FFC7C7;vertical-align:middle;text-align:center;">Proprietary
# </td>
# <td>Used in <a href="/wiki/Bard_(chatbot)" title="Bard (chatbot)">Bard chatbot</a>.<sup class="reference" id="cite_ref-pWyLA_186-0"><a href="#cite_note-pWyLA-186">[180]</a></sup>
# </td></tr>
# <tr>
# <td>Llama 2</td>
# <td><span data-sort-value="000000002023-07-01-0000" style="white-space:nowrap">July 2023</span></td>
# <td>Meta</td>
# <td><span data-sort-value="70000000000 !">70 billion</span><sup class="reference" id="cite_ref-meta-20230719_187-0"><a href="#cite_note-meta-20230719-187">[181]</a></sup></td>
# <td><span data-sort-value="2000000000000 !">2 trillion</span> tokens<sup class="reference" id="cite_ref-meta-20230719_187-1"><a href="#cite_note-meta-20230719-187">[181]</a></sup>
# </td>
# <td></td>
# <td class="table-partial" style="background: #FFB; vertical-align: middle; text-align: center;">Llama 2 license
# </td>
# <td>Successor of LLaMA.
# </td></tr>
# <tr>
# <td>Claude 2
# </td>
# <td>July 2023
# </td>
# <td>Anthropic
# </td>
# <td>Unknown
# </td>
# <td>Unknown
# </td>
# <td>Unknown</td>
# <td class="table-no" style="background:#FFC7C7;vertical-align:middle;text-align:center;">Proprietary
# </td>
# <td>Used in Claude chatbot.<sup class="reference" id="cite_ref-188"><a href="#cite_note-188">[182]</a></sup>
# </td></tr>
# <tr>
# <td>Falcon 180B</td>
# <td><span data-sort-value="000000002023-09-01-0000" style="white-space:nowrap">September 2023</span></td>
# <td>Technology Innovation Institute</td>
# <td><span data-sort-value="180000000000 !">180 billion</span><sup class="reference" id="cite_ref-tii-20230921_189-0"><a href="#cite_note-tii-20230921-189">[183]</a></sup></td>
# <td><span data-sort-value="3500000000000 !">3.5 trillion</span> tokens<sup class="reference" id="cite_ref-tii-20230921_189-1"><a href="#cite_note-tii-20230921-189">[183]</a></sup>
# </td>
# <td></td>
# <td class="table-partial" style="background: #FFB; vertical-align: middle; text-align: center;">Falcon 180B TII license
# </td></tr>
# <tr>
# <td>Mistral 7B</td>
# <td><span data-sort-value="000000002023-09-01-0000" style="white-space:nowrap">September 2023</span></td>
# <td><a href="/wiki/Mistral_AI" title="Mistral AI">Mistral AI</a></td>
# <td><span data-sort-value="7300000000 !">7.3 billion</span><sup class="reference" id="cite_ref-mistral-20230927_190-0"><a href="#cite_note-mistral-20230927-190">[184]</a></sup></td>
# <td>Unknown
# </td>
# <td></td>
# <td class="table-yes" style="background:#9EFF9E;vertical-align:middle;text-align:center;">Apache 2.0
# </td>
# <td>
# </td></tr>
# <tr>
# <td>Claude 2.1
# </td>
# <td>November 2023
# </td>
# <td>Anthropic
# </td>
# <td>Unknown
# </td>
# <td>Unknown
# </td>
# <td>Unknown</td>
# <td class="table-no" style="background:#FFC7C7;vertical-align:middle;text-align:center;">Proprietary
# </td>
# <td>Used in Claude chatbot. Has a context window of 200,000 tokens, or ~500 pages.<sup class="reference" id="cite_ref-191"><a href="#cite_note-191">[185]</a></sup>
# </td></tr>
# <tr>
# <td>Grok-1
# </td>
# <td>November 2023
# </td>
# <td><a class="mw-redirect" href="/wiki/X.AI" title="X.AI">x.AI</a>
# </td>
# <td>Unknown
# </td>
# <td>Unknown
# </td>
# <td>Unknown</td>
# <td class="table-no" style="background:#FFC7C7;vertical-align:middle;text-align:center;">Proprietary
# </td>
# <td>Used in <a href="/wiki/Grok_(chatbot)" title="Grok (chatbot)">Grok</a> chatbot. Grok-1 has a context length of 8,192 tokens and has access to X (Twitter).<sup class="reference" id="cite_ref-192"><a href="#cite_note-192">[186]</a></sup>
# </td></tr>
# <tr>
# <td><a href="/wiki/Gemini_(language_model)" title="Gemini (language model)">Gemini</a>
# </td>
# <td>December 2023
# </td>
# <td><a href="/wiki/Google_DeepMind" title="Google DeepMind">Google DeepMind</a>
# </td>
# <td>Unknown
# </td>
# <td>Unknown
# </td>
# <td>Unknown</td>
# <td class="table-no" style="background:#FFC7C7;vertical-align:middle;text-align:center;">Proprietary
# </td>
# <td>Multimodal model, comes in three sizes. Used in <a href="/wiki/Bard_(chatbot)" title="Bard (chatbot)">Bard chatbot</a>.<sup class="reference" id="cite_ref-193"><a href="#cite_note-193">[187]</a></sup>
# </td></tr>
# <tr>
# <td>Mixtral 8x7B
# </td>
# <td>December 2023
# </td>
# <td><a href="/wiki/Mistral_AI" title="Mistral AI">Mistral AI</a>
# </td>
# <td>46.7B total, 12.9B parameters per token<sup class="reference" id="cite_ref-194"><a href="#cite_note-194">[188]</a></sup>
# </td>
# <td>Unknown
# </td>
# <td>Unknown</td>
# <td class="table-yes" style="background:#9EFF9E;vertical-align:middle;text-align:center;">Apache 2.0
# </td>
# <td><a href="/wiki/Mixture_of_experts" title="Mixture of experts">Mixture of experts</a> model, outperforms GPT-3.5 and Llama 2 70B on many benchmarks. All weights were released via torrent.<sup class="reference" id="cite_ref-195"><a href="#cite_note-195">[189]</a></sup>
# </td></tr>
# <tr>
# <td>Phi-2
# </td>
# <td>December 2023
# </td>
# <td>Microsoft
# </td>
# <td>2.7B
# </td>
# <td>1.4T tokens
# </td>
# <td>Unknown</td>
# <td class="table-yes" style="background:#9EFF9E;vertical-align:middle;text-align:center;">MIT
# </td>
# <td>So-called <i>small language model</i>, that "matches or outperforms models up to 25x larger", trained on "textbook-quality" data based on the paper "Textbooks Are All You Need". Model training took "14 days on 96 A100 GPUs".<sup class="reference" id="cite_ref-196"><a href="#cite_note-196">[190]</a></sup>
# </td></tr></tbody></table>

# %%
psrc = codegen_chain.invoke({'html':str(table)}, config={'callbacks': [ConsoleCallbackHandler()]})
print(psrc)
# Out:
# [chain/start] [1:chain:RunnableSequence] Entering Chain run with input:
# {
#   "html": "<table class=\"wikitable sortable\">\n<tbody><tr>\n<th>Name</th>\n<th>Release date<sup class=\"reference\" id=\"cite_ref-120\"><a href=\"#cite_note-120\">[a]</a></sup></th>\n<th>Developer</th>\n<th>Number of parameters<sup class=\"reference\" id=\"cite_ref-121\"><a href=\"#cite_note-121\">[b]</a></sup></th>\n<th>Corpus size\n</th>\n<th>Training cost (petaFLOP-day)</th>\n<th>License<sup class=\"reference\" id=\"cite_ref-122\"><a href=\"#cite_note-122\">[c]</a></sup></th>\n<th>Notes\n</th></tr>\n<tr>\n<td><a href=\"/wiki/GPT-1\" title=\"GPT-1\">GPT-1</a></td>\n<td><span data-sort-value=\"000000002018-06-01-0000\" style=\"white-space:nowrap\">June 2018</span></td>\n<td><a href=\"/wiki/OpenAI\" title=\"OpenAI\">OpenAI</a></td>\n<td><span data-sort-value=\"117000000 !\">117 million</span></td>\n<td>\n</td>\n<td></td>\n<td class=\"table-yes\" style=\"background:#9EFF9E;vertical-align:middle;text-align:center;\">MIT<sup class=\"reference\" id=\"cite_ref-gpt1_123-0\"><a href=\"#cite_note-gpt1-123\">[120]</a></sup>\n</td>\n<td>First GPT model, decoder-only transformer.\n</td></tr>\n<tr>\n<td><a href=\"/wiki/BERT_(language_model)\" title=\"BERT (language model)\">BERT</a></td>\n<td><span data-sort-value=\"000000002018-10-01-0000\" style=\"white-space:nowrap\">October 2018</span></td>\n<td><a href=\"/wiki/Google\" title=\"Google\">Google</a></td>\n<td><span data-sort-value=\"340000000 !\">340 million</span><sup class=\"reference\" id=\"cite_ref-bert-paper_124-0\"><a href=\"#cite_note-bert-paper-124\">[121]</a></sup></td>\n<td><span data-sort-value=\"3300000000 !\">3.3 billion</span> words<sup class=\"reference\" id=\"cite_ref-bert-paper_124-1\"><a href=\"#cite_note-bert-paper-124\">[121]</a></sup>\n</td>\n<td><span data-sort-value=\"9 !\">9</span><sup class=\"reference\" id=\"cite_ref-bHZJ2_125-0\"><a href=\"#cite_note-bHZJ2-125\">[122]</a></sup></td>\n<td class=\"table-yes\" style=\"background:#9EFF9E;vertical-align:middle;text-align:center;\">Apache 2.0<sup class=\"reference\" id=\"cite_ref-bert-web_126-0\"><a href=\"#cite_note-bert-web-126\">[123]</a></sup>\n</td>\n<td>An early and influential language model,<sup class=\"reference\" id=\"cite_ref-Manning-2022_7-1\"><a href=\"#cite_note-Manning-2022-7\">[7]</a></sup> but encoder-only and thus not built to be prompted or generative<sup class=\"reference\" id=\"cite_ref-Ir545_127-0\"><a href=\"#cite_note-Ir545-127\">[124]</a></sup>\n</td></tr>\n<tr>\n<td>XLNet</td>\n<td><span data-sort-value=\"000000002019-06-01-0000\" style=\"white-space:nowrap\">June 2019</span></td>\n<td><a href=\"/wiki/Google\" title=\"Google\">Google</a></td>\n<td><span data-sort-value=\"340000000 !\">~340 million</span><sup class=\"reference\" id=\"cite_ref-45rAm_128-0\"><a href=\"#cite_note-45rAm-128\">[125]</a></sup></td>\n<td><span data-sort-value=\"3300000000 !\">33 billion</span> words\n</td>\n<td></td>\n<td class=\"table-yes\" style=\"background:#9EFF9E;vertical-align:middle;text-align:center;\">Apache 2.0<sup class=\"reference\" id=\"cite_ref-xlnet_129-0\"><a href=\"#cite_note-xlnet-129\">[126]</a></sup>\n</td>\n<td>An alternative to BERT; designed as encoder-only<sup class=\"reference\" id=\"cite_ref-gAbNO_130-0\"><a href=\"#cite_note-gAbNO-130\">[127]</a></sup><sup class=\"reference\" id=\"cite_ref-LX3rI_131-0\"><a href=\"#cite_note-LX3rI-131\">[128]</a></sup>\n</td></tr>\n<tr>\n<td><a href=\"/wiki/GPT-2\" title=\"GPT-2\">GPT-2</a></td>\n<td><span data-sort-value=\"000000002019-02-01-0000\" style=\"white-space:nowrap\">February 2019</span></td>\n<td><a href=\"/wiki/OpenAI\" title=\"OpenAI\">OpenAI</a></td>\n<td><span data-sort-value=\"1500000000 !\">1.5 billion</span><sup class=\"reference\" id=\"cite_ref-15Brelease_132-0\"><a href=\"#cite_note-15Brelease-132\">[129]</a></sup></td>\n<td>40GB<sup class=\"reference\" id=\"cite_ref-5T8u5_133-0\"><a href=\"#cite_note-5T8u5-133\">[130]</a></sup> (~<span data-sort-value=\"10000000000 !\">10 billion</span> tokens)<sup class=\"reference\" id=\"cite_ref- ...
# }
# [chain/start] [1:chain:RunnableSequence > 2:prompt:ChatPromptTemplate] Entering Prompt run with input:
# {
#   "html": "<table class=\"wikitable sortable\">\n<tbody><tr>\n<th>Name</th>\n<th>Release date<sup class=\"reference\" id=\"cite_ref-120\"><a href=\"#cite_note-120\">[a]</a></sup></th>\n<th>Developer</th>\n<th>Number of parameters<sup class=\"reference\" id=\"cite_ref-121\"><a href=\"#cite_note-121\">[b]</a></sup></th>\n<th>Corpus size\n</th>\n<th>Training cost (petaFLOP-day)</th>\n<th>License<sup class=\"reference\" id=\"cite_ref-122\"><a href=\"#cite_note-122\">[c]</a></sup></th>\n<th>Notes\n</th></tr>\n<tr>\n<td><a href=\"/wiki/GPT-1\" title=\"GPT-1\">GPT-1</a></td>\n<td><span data-sort-value=\"000000002018-06-01-0000\" style=\"white-space:nowrap\">June 2018</span></td>\n<td><a href=\"/wiki/OpenAI\" title=\"OpenAI\">OpenAI</a></td>\n<td><span data-sort-value=\"117000000 !\">117 million</span></td>\n<td>\n</td>\n<td></td>\n<td class=\"table-yes\" style=\"background:#9EFF9E;vertical-align:middle;text-align:center;\">MIT<sup class=\"reference\" id=\"cite_ref-gpt1_123-0\"><a href=\"#cite_note-gpt1-123\">[120]</a></sup>\n</td>\n<td>First GPT model, decoder-only transformer.\n</td></tr>\n<tr>\n<td><a href=\"/wiki/BERT_(language_model)\" title=\"BERT (language model)\">BERT</a></td>\n<td><span data-sort-value=\"000000002018-10-01-0000\" style=\"white-space:nowrap\">October 2018</span></td>\n<td><a href=\"/wiki/Google\" title=\"Google\">Google</a></td>\n<td><span data-sort-value=\"340000000 !\">340 million</span><sup class=\"reference\" id=\"cite_ref-bert-paper_124-0\"><a href=\"#cite_note-bert-paper-124\">[121]</a></sup></td>\n<td><span data-sort-value=\"3300000000 !\">3.3 billion</span> words<sup class=\"reference\" id=\"cite_ref-bert-paper_124-1\"><a href=\"#cite_note-bert-paper-124\">[121]</a></sup>\n</td>\n<td><span data-sort-value=\"9 !\">9</span><sup class=\"reference\" id=\"cite_ref-bHZJ2_125-0\"><a href=\"#cite_note-bHZJ2-125\">[122]</a></sup></td>\n<td class=\"table-yes\" style=\"background:#9EFF9E;vertical-align:middle;text-align:center;\">Apache 2.0<sup class=\"reference\" id=\"cite_ref-bert-web_126-0\"><a href=\"#cite_note-bert-web-126\">[123]</a></sup>\n</td>\n<td>An early and influential language model,<sup class=\"reference\" id=\"cite_ref-Manning-2022_7-1\"><a href=\"#cite_note-Manning-2022-7\">[7]</a></sup> but encoder-only and thus not built to be prompted or generative<sup class=\"reference\" id=\"cite_ref-Ir545_127-0\"><a href=\"#cite_note-Ir545-127\">[124]</a></sup>\n</td></tr>\n<tr>\n<td>XLNet</td>\n<td><span data-sort-value=\"000000002019-06-01-0000\" style=\"white-space:nowrap\">June 2019</span></td>\n<td><a href=\"/wiki/Google\" title=\"Google\">Google</a></td>\n<td><span data-sort-value=\"340000000 !\">~340 million</span><sup class=\"reference\" id=\"cite_ref-45rAm_128-0\"><a href=\"#cite_note-45rAm-128\">[125]</a></sup></td>\n<td><span data-sort-value=\"3300000000 !\">33 billion</span> words\n</td>\n<td></td>\n<td class=\"table-yes\" style=\"background:#9EFF9E;vertical-align:middle;text-align:center;\">Apache 2.0<sup class=\"reference\" id=\"cite_ref-xlnet_129-0\"><a href=\"#cite_note-xlnet-129\">[126]</a></sup>\n</td>\n<td>An alternative to BERT; designed as encoder-only<sup class=\"reference\" id=\"cite_ref-gAbNO_130-0\"><a href=\"#cite_note-gAbNO-130\">[127]</a></sup><sup class=\"reference\" id=\"cite_ref-LX3rI_131-0\"><a href=\"#cite_note-LX3rI-131\">[128]</a></sup>\n</td></tr>\n<tr>\n<td><a href=\"/wiki/GPT-2\" title=\"GPT-2\">GPT-2</a></td>\n<td><span data-sort-value=\"000000002019-02-01-0000\" style=\"white-space:nowrap\">February 2019</span></td>\n<td><a href=\"/wiki/OpenAI\" title=\"OpenAI\">OpenAI</a></td>\n<td><span data-sort-value=\"1500000000 !\">1.5 billion</span><sup class=\"reference\" id=\"cite_ref-15Brelease_132-0\"><a href=\"#cite_note-15Brelease-132\">[129]</a></sup></td>\n<td>40GB<sup class=\"reference\" id=\"cite_ref-5T8u5_133-0\"><a href=\"#cite_note-5T8u5-133\">[130]</a></sup> (~<span data-sort-value=\"10000000000 !\">10 billion</span> tokens)<sup class=\"reference\" id=\"cite_ref- ...
# }
# [chain/end] [1:chain:RunnableSequence > 2:prompt:ChatPromptTemplate] s] Exiting Prompt run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "prompts",
#     "chat",
#     "ChatPromptValue"
#   ],
#   "kwargs": {
#     "messages": [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "SystemMessage"
#         ],
#         "kwargs": {
#           "content": "You are an expert python programmer. \nYou write concise, well-documented, high-quality source code.",
#           "additional_kwargs": {}
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "HumanMessage"
#         ],
#         "kwargs": {
#           "content": "The following snippet of HTML enclosed in triple backticks is a table about \nlarge language models. Only using the HTML data, write a python function that plots \na horizontal bar chart with the name of each large language model on the vertical axis and \nthe number of parameters used in each model on the horizontal. Use the seaborn library.\nOnly generate valid python code in your answer.   \n\n```<table class=\"wikitable sortable\">\n<tbody><tr>\n<th>Name</th>\n<th>Release date<sup class=\"reference\" id=\"cite_ref-120\"><a href=\"#cite_note-120\">[a]</a></sup></th>\n<th>Developer</th>\n<th>Number of parameters<sup class=\"reference\" id=\"cite_ref-121\"><a href=\"#cite_note-121\">[b]</a></sup></th>\n<th>Corpus size\n</th>\n<th>Training cost (petaFLOP-day)</th>\n<th>License<sup class=\"reference\" id=\"cite_ref-122\"><a href=\"#cite_note-122\">[c]</a></sup></th>\n<th>Notes\n</th></tr>\n<tr>\n<td><a href=\"/wiki/GPT-1\" title=\"GPT-1\">GPT-1</a></td>\n<td><span data-sort-value=\"000000002018-06-01-0000\" style=\"white-space:nowrap\">June 2018</span></td>\n<td><a href=\"/wiki/OpenAI\" title=\"OpenAI\">OpenAI</a></td>\n<td><span data-sort-value=\"117000000 !\">117 million</span></td>\n<td>\n</td>\n<td></td>\n<td class=\"table-yes\" style=\"background:#9EFF9E;vertical-align:middle;text-align:center;\">MIT<sup class=\"reference\" id=\"cite_ref-gpt1_123-0\"><a href=\"#cite_note-gpt1-123\">[120]</a></sup>\n</td>\n<td>First GPT model, decoder-only transformer.\n</td></tr>\n<tr>\n<td><a href=\"/wiki/BERT_(language_model)\" title=\"BERT (language model)\">BERT</a></td>\n<td><span data-sort-value=\"000000002018-10-01-0000\" style=\"white-space:nowrap\">October 2018</span></td>\n<td><a href=\"/wiki/Google\" title=\"Google\">Google</a></td>\n<td><span data-sort-value=\"340000000 !\">340 million</span><sup class=\"reference\" id=\"cite_ref-bert-paper_124-0\"><a href=\"#cite_note-bert-paper-124\">[121]</a></sup></td>\n<td><span data-sort-value=\"3300000000 !\">3.3 billion</span> words<sup class=\"reference\" id=\"cite_ref-bert-paper_124-1\"><a href=\"#cite_note-bert-paper-124\">[121]</a></sup>\n</td>\n<td><span data-sort-value=\"9 !\">9</span><sup class=\"reference\" id=\"cite_ref-bHZJ2_125-0\"><a href=\"#cite_note-bHZJ2-125\">[122]</a></sup></td>\n<td class=\"table-yes\" style=\"background:#9EFF9E;vertical-align:middle;text-align:center;\">Apache 2.0<sup class=\"reference\" id=\"cite_ref-bert-web_126-0\"><a href=\"#cite_note-bert-web-126\">[123]</a></sup>\n</td>\n<td>An early and influential language model,<sup class=\"reference\" id=\"cite_ref-Manning-2022_7-1\"><a href=\"#cite_note-Manning-2022-7\">[7]</a></sup> but encoder-only and thus not built to be prompted or generative<sup class=\"reference\" id=\"cite_ref-Ir545_127-0\"><a href=\"#cite_note-Ir545-127\">[124]</a></sup>\n</td></tr>\n<tr>\n<td>XLNet</td>\n<td><span data-sort-value=\"000000002019-06-01-0000\" style=\"white-space:nowrap\">June 2019</span></td>\n<td><a href=\"/wiki/Google\" title=\"Google\">Google</a></td>\n<td><span data-sort-value=\"340000000 !\">~340 million</span><sup class=\"reference\" id=\"cite_ref-45rAm_128-0\"><a href=\"#cite_note-45rAm-128\">[125]</a></sup></td>\n<td><span data-sort-value=\"3300000000 !\">33 billion</span> words\n</td>\n<td></td>\n<td class=\"table-yes\" style=\"background:#9EFF9E;vertical-align:middle;text-align:center;\">Apache 2.0<sup class=\"reference\" id=\"cite_ref-xlnet_129-0\"><a href=\"#cite_note-xlnet-129\">[126]</a></sup>\n</td>\n<td>An alternative to BERT; designed as encoder-only<sup class=\"reference\" id=\"cite_ref-gAbNO_130-0\"><a href=\"#cite_note-gAbNO-130\">[127]</a></sup><sup class=\"reference\" id=\"cite_ref-LX3rI_131-0\"><a href=\"#cite_note-LX3rI-131\">[128]</a></sup>\n</td></tr>\n<tr>\n<td><a href=\"/wiki/GPT-2\" title=\"GPT-2\">GPT-2</a></td>\n<td><span data-sort-value=\"000000002019-02-01-0000\" style=\"white-space:nowrap\">February 2019</span></td>\n<td><a href=\"/wiki/OpenAI\" title=\"OpenAI\ ...
#           "additional_kwargs": {}
#         }
#       }
#     ]
#   }
# }
# [llm/start] [1:chain:RunnableSequence > 3:llm:ChatOllama] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are an expert python programmer. \nYou write concise, well-documented, high-quality source code.\nHuman: The following snippet of HTML enclosed in triple backticks is a table about \nlarge language models. Only using the HTML data, write a python function that plots \na horizontal bar chart with the name of each large language model on the vertical axis and \nthe number of parameters used in each model on the horizontal. Use the seaborn library.\nOnly generate valid python code in your answer.   \n\n```<table class=\"wikitable sortable\">\n<tbody><tr>\n<th>Name</th>\n<th>Release date<sup class=\"reference\" id=\"cite_ref-120\"><a href=\"#cite_note-120\">[a]</a></sup></th>\n<th>Developer</th>\n<th>Number of parameters<sup class=\"reference\" id=\"cite_ref-121\"><a href=\"#cite_note-121\">[b]</a></sup></th>\n<th>Corpus size\n</th>\n<th>Training cost (petaFLOP-day)</th>\n<th>License<sup class=\"reference\" id=\"cite_ref-122\"><a href=\"#cite_note-122\">[c]</a></sup></th>\n<th>Notes\n</th></tr>\n<tr>\n<td><a href=\"/wiki/GPT-1\" title=\"GPT-1\">GPT-1</a></td>\n<td><span data-sort-value=\"000000002018-06-01-0000\" style=\"white-space:nowrap\">June 2018</span></td>\n<td><a href=\"/wiki/OpenAI\" title=\"OpenAI\">OpenAI</a></td>\n<td><span data-sort-value=\"117000000 !\">117 million</span></td>\n<td>\n</td>\n<td></td>\n<td class=\"table-yes\" style=\"background:#9EFF9E;vertical-align:middle;text-align:center;\">MIT<sup class=\"reference\" id=\"cite_ref-gpt1_123-0\"><a href=\"#cite_note-gpt1-123\">[120]</a></sup>\n</td>\n<td>First GPT model, decoder-only transformer.\n</td></tr>\n<tr>\n<td><a href=\"/wiki/BERT_(language_model)\" title=\"BERT (language model)\">BERT</a></td>\n<td><span data-sort-value=\"000000002018-10-01-0000\" style=\"white-space:nowrap\">October 2018</span></td>\n<td><a href=\"/wiki/Google\" title=\"Google\">Google</a></td>\n<td><span data-sort-value=\"340000000 !\">340 million</span><sup class=\"reference\" id=\"cite_ref-bert-paper_124-0\"><a href=\"#cite_note-bert-paper-124\">[121]</a></sup></td>\n<td><span data-sort-value=\"3300000000 !\">3.3 billion</span> words<sup class=\"reference\" id=\"cite_ref-bert-paper_124-1\"><a href=\"#cite_note-bert-paper-124\">[121]</a></sup>\n</td>\n<td><span data-sort-value=\"9 !\">9</span><sup class=\"reference\" id=\"cite_ref-bHZJ2_125-0\"><a href=\"#cite_note-bHZJ2-125\">[122]</a></sup></td>\n<td class=\"table-yes\" style=\"background:#9EFF9E;vertical-align:middle;text-align:center;\">Apache 2.0<sup class=\"reference\" id=\"cite_ref-bert-web_126-0\"><a href=\"#cite_note-bert-web-126\">[123]</a></sup>\n</td>\n<td>An early and influential language model,<sup class=\"reference\" id=\"cite_ref-Manning-2022_7-1\"><a href=\"#cite_note-Manning-2022-7\">[7]</a></sup> but encoder-only and thus not built to be prompted or generative<sup class=\"reference\" id=\"cite_ref-Ir545_127-0\"><a href=\"#cite_note-Ir545-127\">[124]</a></sup>\n</td></tr>\n<tr>\n<td>XLNet</td>\n<td><span data-sort-value=\"000000002019-06-01-0000\" style=\"white-space:nowrap\">June 2019</span></td>\n<td><a href=\"/wiki/Google\" title=\"Google\">Google</a></td>\n<td><span data-sort-value=\"340000000 !\">~340 million</span><sup class=\"reference\" id=\"cite_ref-45rAm_128-0\"><a href=\"#cite_note-45rAm-128\">[125]</a></sup></td>\n<td><span data-sort-value=\"3300000000 !\">33 billion</span> words\n</td>\n<td></td>\n<td class=\"table-yes\" style=\"background:#9EFF9E;vertical-align:middle;text-align:center;\">Apache 2.0<sup class=\"reference\" id=\"cite_ref-xlnet_129-0\"><a href=\"#cite_note-xlnet-129\">[126]</a></sup>\n</td>\n<td>An alternative to BERT; designed as encoder-only<sup class=\"reference\" id=\"cite_ref-gAbNO_130-0\"><a href=\"#cite_note-gAbNO-130\">[127]</a></sup><sup class=\"reference\" id=\"cite_ref-LX3rI_131-0\"><a href=\"#cite_note-LX3rI-131\">[128]</a></sup>\n</td></tr>\n<tr>\n<td><a href=\"/wiki/GPT-2\" title=\"GPT-2\">GPT-2</a></td>\n<td><span data-sort-value=\"000000002019-02-01-0000\"  ...
#   ]
# }
# [llm/end] [1:chain:RunnableSequence > 3:llm:ChatOllama] [12.83s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "\n\\end{code}",
#         "generation_info": {
#           "model": "codellama:34b-python",
#           "created_at": "2024-01-26T07:55:48.987242Z",
#           "response": "",
#           "done": true,
#           "context": [
#             3532,
#             14816,
#             29903,
#             6778,
#             887,
#             526,
#             385,
#             17924,
#             3017,
#             27922,
#             29889,
#             29871,
#             13,
#             3492,
#             2436,
#             3022,
#             895,
#             29892,
#             1532,
#             29899,
#             3225,
#             287,
#             29892,
#             1880,
#             29899,
#             29567,
#             2752,
#             775,
#             29889,
#             529,
#             829,
#             14816,
#             29903,
#             6778,
#             13,
#             29961,
#             25580,
#             29962,
#             450,
#             1494,
#             11534,
#             310,
#             4544,
#             427,
#             15603,
#             297,
#             21954,
#             1250,
#             29873,
#             7358,
#             338,
#             263,
#             1591,
#             1048,
#             29871,
#             13,
#             16961,
#             4086,
#             4733,
#             29889,
#             9333,
#             773,
#             278,
#             4544,
#             848,
#             29892,
#             2436,
#             263,
#             3017,
#             740,
#             393,
#             24580,
#             29871,
#             13,
#             29874,

#             3254,
#             29874,
#             2822,
#             9880,
#             2036,
#             29918,
#             6812,
#             29899,
#             29896,
#             29929,
#             29945,
#             1013,
#             29961,
#             29896,
#             29947,
#             29929,
#             29962,
#             829,
#             29874,
#             2565,
#             12587,
#             29958,
#             13,
#             829,
#             1594,
#             2565,
#             509,
#             29958,
#             13,
#             29966,
#             509,
#             29958,
#             13,
#             29966,
#             1594,
#             29958,
#             9492,
#             29899,
#             29906,
#             13,
#             829,
#             1594,
#             29958,
#             13,
#             29966,
#             1594,
#             29958,
#             6185,
#             1096,
#             29871,
#             29906,
#             29900,
#             29906,
#             29941,
#             13,
#             829,
#             1594,
#             29958,
#             13,
#             29966,
#             1594,
#             29958,
#             11277,
#             13,
#             829,
#             1594,
#             29958,
#             13,
#             29966,
#             1594,
#             29958,
#             29906,
#             29889,
#             29955,
#             29933,
#             13,
#             829,
#             1594,
#             29958,
#             13,
#             29966,
#             1594,
#             29958,
#             29896,
#             29889,
#             29946,
#             29911,
#             18897,
#             13,
#             829,
#             1594,
#             29958,
#             13,
#             29966,
#             1594,
#             29958,
#             14148,
#             829,
#             1594,
#             29958,
#             13,
#             29966,
#             1594,
#             770,
#             543,
#             2371,
#             29899,
#             3582,
#             29908,
#             3114,
#             543,
#             7042,
#             21968,
#             29929,
#             29923,
#             4198,
#             29929,
#             29923,
#             29936,
#             18575,
#             29899,
#             2520,
#             29901,
#             17662,
#             29936,
#             726,
#             29899,
#             2520,
#             29901,
#             5064,
#             12334,
#             26349,
#             13,
#             829,
#             1594,
#             29958,
#             13,
#             29966,
#             1594,
#             29958,
#             6295,
#             29899,
#             13998,
#             529,
#             29875,
#             29958,
#             9278,
#             4086,
#             1904,
#             829,
#             29875,
#             10202,
#             393,
#             376,
#             20317,
#             470,
#             714,
#             546,
#             9514,
#             4733,
#             701,
#             304,
#             29871,
#             29906,
#             29945,
#             29916,
#             7200,
#             613,
#             16370,
#             373,
#             376,
#             726,
#             2909,
#             29899,
#             29567,
#             29908,
#             848,
#             2729,
#             373,
#             278,
#             5650,
#             376,
#             1626,
#             12733,
#             4683,
#             2178,
#             887,
#             20768,
#             1642,
#             8125,
#             6694,
#             3614,
#             376,
#             29896,
#             29946,
#             3841,
#             373,
#             29871,
#             29929,
#             29953,
#             319,
#             29896,
#             29900,
#             29900,
#             22796,
#             29879,
#             1642,
#             29966,
#             12587,
#             770,
#             543,
#             5679,
#             29908,
#             1178,
#             543,
#             2036,
#             29918,
#             999,
#             29899,
#             29896,
#             29929,
#             29953,
#             3254,
#             29874,
#             2822,
#             9880,
#             2036,
#             29918,
#             6812,
#             29899,
#             29896,
#             29929,
#             29953,
#             1013,
#             29961,
#             29896,
#             29929,
#             29900,
#             29962,
#             829,
#             29874,
#             2565,
#             12587,
#             29958,
#             13,
#             829,
#             1594,
#             2565,
#             509,
#             2565,
#             15370,
#             2565,
#             2371,
#             13885,
#             16159,
#             13,
#             518,
#             29914,
#             25580,
#             29962,
#             13,
#             29905,
#             355,
#             29912,
#             401,
#             29913
#           ],
#           "total_duration": 12766811709,
#           "load_duration": 1074042,
#           "prompt_eval_count": 1682,
#           "prompt_eval_duration": 12409466000,
#           "eval_count": 6,
#           "eval_duration": 350640000
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "\n\\end{code}"
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [chain/start] [1:chain:RunnableSequence > 4:parser:StrOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [1:chain:RunnableSequence > 4:parser:StrOutputParser] s] Exiting Parser run with output:
# {
#   "output": "\n\\end{code}"
# }
# [chain/end] [1:chain:RunnableSequence] [12.96s] Exiting Chain run with output:
# {
#   "output": "\n\\end{code}"
# }
#
# \end{code}

# %%
# Extract the header of the table
header = [th.text for th in table.tbody.tr.find_all("th")]

# Extract the rows of the table (excluding the header)
rows = []
for tr in table.tbody.find_all("tr"):
    cells = [td.text for td in tr.find_all("td")]
    if cells:
        rows.append(cells)

# Print the extracted data
print("Header:", header)
print("Rows:", rows)
